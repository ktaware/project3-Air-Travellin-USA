# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# create engine to airtraffic_db postgresql database
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/airtravel_db")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(autoload_with=engine)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['airlines', 'flights', 'airports', 'routes', 'all_flights']

# %%
# Save references to each table

# Map Airlines class
Airlines = Base.classes.airlines

# Map Airports class
Airports = Base.classes.airports

# Map Flights class
Flights = Base.classes.flights

# Map Routes class
All_Flights = Base.classes.all_flights

# Map Routes class
Routes = Base.classes.routes

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Inspect Tables
inspector = inspect(engine)

# %%
# Get a list of column names and types for Airlines Table
columns = inspector.get_columns('airlines')
for c in columns:
    print(c['name'], c["type"])
# Out:
# airline_name VARCHAR(70)
# airline_id VARCHAR(10)
# origin_country VARCHAR(70)
# active VARCHAR(5)

# %%
# Get a list of column names and types for Airports Table
columns = inspector.get_columns('airports')
for c in columns:
    print(c['name'], c["type"])
# Out:
# airport_name VARCHAR(70)
# city VARCHAR(70)
# country VARCHAR(70)
# airport_id VARCHAR(10)
# latitude VARCHAR(20)
# longitude VARCHAR(20)
# altitude INTEGER

# %%
# Get a list of column names and types for Flights Table
columns = inspector.get_columns('flights')
for c in columns:
    print(c['name'], c["type"])
# Out:
# index INTEGER
# year INTEGER
# month INTEGER
# day INTEGER
# sched_dep_time INTEGER
# sched_arr_time INTEGER
# airline_id VARCHAR(10)
# flight INTEGER
# tailnum VARCHAR(10)
# origin VARCHAR(10)
# dest VARCHAR(10)
# air_time DOUBLE_PRECISION
# distance INTEGER
# hour INTEGER
# minute INTEGER

# %%
# Get a list of column names and types for Routes Table
columns = inspector.get_columns('all_flights')
for c in columns:
    print(c['name'], c["type"])
# Out:
# index INTEGER
# year INTEGER
# dep_airport VARCHAR(10)
# des_airport VARCHAR(10)
# alid INTEGER
# airline_id VARCHAR(10)
# dom_fgn INTEGER
# scheduled INTEGER
# chartered INTEGER
# total INTEGER

# %%
# Get a list of column names and types for Routes Table
columns = inspector.get_columns('routes')
for c in columns:
    print(c['name'], c["type"])
# Out:
# index INTEGER
# airline_id VARCHAR(10)
# dep_airport_id VARCHAR(10)
# des_airport_id VARCHAR(10)
# stops INTEGER

# %% [markdown]
# # Exploratory Analysis

# %%
# Query id and name values for the airlines   
airlines_info = session.query(Airlines.airline_id, Airlines.airline_name, Airlines.origin_country, Airlines.active).all()
airlines_info
# Out:
# [('1T', '1Time Airline', 'South Africa', 'Y'),
#  ('Q5', '40-Mile Air', 'United States', 'Y'),
#  ('AN', 'Ansett Australia', 'Australia', 'Y'),
#  ('1B', 'Abacus International', 'Singapore', 'Y'),
#  ('W9', 'Abelag Aviation', 'Belgium', 'N'),
#  ('ZI', 'Aigle Azur', 'France', 'Y'),
#  ('AQ', 'Aloha Airlines', 'United States', 'Y'),
#  ('AA', 'American Airlines', 'United States', 'Y'),
#  ('OZ', 'Asiana Airlines', 'Republic of Korea', 'Y'),
#  ('4K', 'Askari Aviation', 'Pakistan', 'Y'),
#  ('8U', 'Afriqiyah Airways', 'Libya', 'Y'),
#  ('Q9', 'Afrinat International Airlines', 'Gambia', 'N'),
#  ('G4', 'Allegiant Air', 'United States', 'Y'),
#  ('K5', 'Aban Air', 'Iran', 'n'),
#  ('M3', 'ABSA - Aerolinhas Brasileiras', 'Brazil', 'Y'),
#  ('4', 'Antrak Air', 'Ghana', 'N'),
#  ('GB', 'Airborne Express', 'United States', 'N'),
#  ('8V', 'Astral Aviation', 'Kenya', 'Y'),
#  ('E4', 'Aero Asia International', 'Pakistan', 'N'),
#  ('YT', 'Air Togo', 'Togo', 'N'),
#  ('4G', 'Advance Leasing Company', 'United States', 'N'),
#  ('7A', 'Aztec Worldwide Airlines', 'United States', 'N'),
#  ('8T', 'Air Tindi', 'Canadian Territories', 'Y'),
#  ('ZY', 'Ada Air', 'Albania', 'Y'),
#  ('Z7', 'ADC Airlines', 'Nigeria', 'N'),
#  ('JP', 'Adria Airways', 'Slovenia', 'Y'),
#  ('UX', 'Air Europa', 'Spain', 'Y'),
#  ('EM', 'Aero Benin', 'Benin', 'Y'),
#  ('A3', 'Aegean Airlines', 'Greece', 'Y'),
#  ('KI', 'Air Atlantique', 'United Kingdom', 'N'),
#  ('PE', 'Air Europe', 'Italy', 'Y'),
#  ('KO', 'Alaska Central Express', 'United States', 'Y'),
#  ('5W', 'Astraeus', 'United Kingdom', 'Y'),
#  ('VV', 'Aerosvit Airlines', 'Ukraine', 'Y'),
#  ('I9', 'Air Italy', 'Italy', 'Y'),
#  ('WK', 'American Falcon', 'Argentina', 'N'),
#  ('QQ', 'Alliance Airlines', 'Australia', 'Y'),
#  ('FG', 'Ariana Afghan Airlines', 'Afghanistan', 'Y'),
#  ('SU', 'Aeroflot Russian Airlines', 'Russia', 'Y'),
#  ('JA', 'Air Bosna', 'Bosnia and Herzegovina', 'Y'),
#  ('AF', 'Air France', 'France', 'Y'),
#  ('SB', 'Air Caledonie International', 'France', 'Y'),
#  ('GN', 'Air Gabon', 'Gabon', 'N'),
#  ('2O', 'Air Salone', 'Sierra Leone', 'Y'),
#  ('2Q', 'Air Cargo Carriers', 'United States', 'Y'),
#  ('V7', 'Air Senegal International', 'Senegal', 'N'),
#  ('SW', 'Air Namibia', 'Namibia', 'Y'),
#  ('G8', 'Air Service Gabon', 'Gabon', 'N'),
#  ('5D', 'Aerolitoral', 'Mexico', 'Y'),
#  ('1A', 'Amadeus Global Travel Distribution', 'Spain', 'N'),
#  ('7T', 'Air Glaciers', 'Switzerland', 'Y'),
#  ('PL', 'Aeroper', 'Peru', 'Y'),
#  ('8A', 'Atlas Blue', 'Morocco', 'Y'),
#  ('GD', 'Air Alpha Greenland', 'Denmark', 'N'),
#  ('LD', 'Air Hong Kong', 'Hong Kong', 'N'),
#  ('HT', 'Aeromist-Kharkiv', 'Ukraine', 'N'),
#  ('J2', 'Azerbaijan Airlines', 'Azerbaijan', 'Y'),
#  ('U3', 'Avies', 'Estonia', 'Y'),
#  ('AP', 'Airbus Industrie', 'France', 'N'),
#  ('5A', 'Alpine Air Express', 'United States', 'N'),
#  ('ED', 'Airblue', 'Pakistan', 'Y'),
#  ('AB', 'Air Berlin', 'Germany', 'Y'),
#  ('AG', 'Air Contractors', 'Ireland', 'N'),
#  ('AI', 'Air India Limited', 'India', 'Y'),
#  ('ZB', 'Air Bourbon', 'Reunion', 'Y'),
#  ('CC', 'Air Atlanta Icelandic', 'Iceland', 'Y'),
#  ('RB', 'Air Srpska', 'Bosnia and Herzegovina', 'N'),
#  ('TN', 'Air Tahiti Nui', 'France', 'Y'),
#  ('W4', 'Aero Services Executive', 'France', 'N'),
#  ('IZ', 'Arkia Israel Airlines', 'Israel', 'Y'),
#  ('JM', 'Air Jamaica', 'Jamaica', 'Y'),
#  ('S2', 'Air Sahara', 'India', 'Y'),
#  ('KM', 'Air Malta', 'Malta', 'Y'),
#  ('M6', 'Amerijet International', 'United States', 'N'),
#  ('NQ', 'Air Japan', 'Japan', 'Y'),
#  ('4A', 'Air Kiribati', 'Kiribati', 'Y'),
#  ('EH', 'Air Nippon Network Co. Ltd.', 'Japan', 'N'),
#  ('HP', 'America West Airlines', 'United States', 'Y'),
#  ('ZW', 'Air Wisconsin', 'United States', 'Y'),
#  ('U9', 'Tatarstan Airlines', 'Russia', 'Y'),
#  ('VD', 'Air Libert', 'France', 'Y'),
#  ('TT', 'Air Lithuania', 'Lithuania', 'N'),
#  ('QM', 'Air Malawi', 'Malawi', 'Y'),
#  ('BM', 'Air Sicilia', 'Italy', 'Y'),
#  ('NX', 'Air Macau', 'Macao', 'Y'),
#  ('ZV', 'Air Midwest', 'United States', 'N'),
#  ('HM', 'Air Seychelles', 'Seychelles', 'Y'),
#  ('AM', 'AeroMéxico', 'Mexico', 'Y'),
#  ('NH', 'All Nippon Airways', 'Japan', 'Y'),
#  ('YW', 'Air Nostrum', 'Spain', 'Y'),
#  ('PX', 'Air Niugini', 'Papua New Guinea', 'Y'),
#  ('G9', 'Air Arabia', 'United Arab Emirates', 'Y'),
#  ('AC', 'Air Canada', 'Canada', 'Y'),
#  ('BT', 'Air Baltic', 'Latvia', 'Y'),
#  ('EL', 'Air Nippon', 'Japan', 'Y'),
#  ('TL', 'Airnorth', 'Australia', 'Y'),
#  ('4N', 'Air North Charter - Canada', 'Canada', 'Y'),
#  ('IW', 'AOM French Airlines', 'France', 'N'),
#  ('NZ', 'Air New Zealand', 'New Zealand', 'Y'),
#  ('J6', 'AVCOM', 'Russia', 'N'),
#  ('2D', 'Aero VIP', 'Argentina', 'N'),
#  ('6V', 'Air Vegas', 'United States', 'N'),
#  ('XM', 'Alitalia Express', 'Italy', 'Y'),
#  ('OE', 'Asia Overnight Express', 'Philippines', 'N'),
#  ('GV', 'Aero Flight', 'Germany', 'Y'),
#  ('JW', 'Arrow Air', 'United States', 'Y'),
#  ('W3', 'Arik Air', 'Nigeria', 'N'),
#  ('2B', 'Aerocondor', 'Portugal', 'Y'),
#  ('4C', 'Aires', ' S.A.', 'Y'),
#  ('AR', 'Aerolineas Argentinas', 'Argentina', 'Y'),
#  ('QN', 'Air Armenia', 'Armenia', 'N'),
#  ('AS', 'Alaska Airlines', 'ALASKA', 'Y'),
#  ('4D', 'Air Sinai', 'Egypt', 'Y'),
#  ('EV', 'Atlantic Southeast Airlines', 'United States', 'Y'),
#  ('OB', 'Astrakhan Airlines', 'Russia', 'Y'),
#  ('TC', 'Air Tanzania', 'Tanzania', 'Y'),
#  ('2J', 'Air Burkina', 'Burkina Faso', 'Y'),
#  ('HC', 'Aero-Tropics Air Services', 'Australia', 'N'),
#  ('FO', 'Airlines Of Tasmania', 'Australia', 'Y'),
#  ('PJ', 'Air Saint Pierre', 'France', 'Y'),
#  ('8C', 'Air Transport International', 'United States', 'N'),
#  ('OS', 'Austrian Airlines', 'Austria', 'Y'),
#  ('IQ', 'Augsburg Airways', 'Germany', 'Y'),
#  ('RU', 'AirBridge Cargo', 'Russia', 'N'),
#  ('MO', 'Abu Dhabi Amiri Flight', 'United Arab Emirates', 'Y'),
#  ('5N', 'Aeroflot-Nord', 'Russia', 'Y'),
#  ('GR', 'Aurigny Air Services', 'United Kingdom', 'Y'),
#  ('NO', 'Aus-Air', 'Australia', 'N'),
#  ('AU', 'Austral Lineas Aereas', 'Argentina', 'Y'),
#  ('AO', 'Australian Airlines', 'Australia', 'N'),
#  ('AV', 'Avianca - Aerovias Nacionales de Colombia', 'AVIANCA', 'Y'),
#  ('NF', 'Air Vanuatu', 'Vanuatu', 'Y'),
#  ('K8', 'Airlink Zambia', 'Zambia', 'N'),
#  ('B9', 'Air Bangladesh', 'Bangladesh', 'Y'),
#  ('DR', 'Air Mediterranee', 'France', 'Y'),
#  ('7E', 'Aeroline GmbH', 'Germany', 'Y'),
#  ('6G', 'Air Wales', 'United Kingdom', 'Y'),
#  ('TX', 'Air Caraïbes', 'France', 'Y'),
#  ('IX', 'Air India Express', 'India', 'Y'),
#  ('HJ', 'Asian Express Airlines', 'Australia', 'N'),
#  ('XT', 'Air Exel', 'Netherlands', 'Y'),
#  ('AK', 'AirAsia', 'Malaysia', 'Y'),
#  ('3G', 'Atlant-Soyuz Airlines', 'Russia', 'Y'),
#  ('AZ', 'Alitalia', 'Italy', 'Y'),
#  ('ZE', 'Arcus-Air Logistic', 'Germany', 'N'),
#  ('Z8', 'Amaszonas', 'Bolivia', 'Y'),
#  ('UM', 'Air Zimbabwe', 'Zimbabwe', 'Y'),
#  ('R7', 'Aserca Airlines', 'Venezuela', 'Y'),
#  ('FV', 'Rossiya-Russian Airlines', 'Russia', 'Y'),
#  ('RX', 'Aviaexpress', 'Hungary', 'N'),
#  ('MQ', 'American Eagle Airlines', 'United States', 'Y'),
#  ('FF', 'Airshop', 'Netherlands', 'N'),
#  ('ML', 'African Transport Trading and Investment Company', 'Sudan', 'N'),
#  ('VU', 'Air Ivoire', 'Ivory Coast', 'Y'),
#  ('BP', 'Air Botswana', 'Botswana', 'Y'),
#  ('GS', 'Air Foyle', 'United Kingdom', 'Y'),
#  ('VT', 'Air Tahiti', 'French Polynesia', 'Y'),
#  ('3N', 'Air Urga', 'Ukraine', 'N'),
#  ('VL', 'Air VIA', 'Bulgaria', 'Y'),
#  ('FK', 'Africa West', 'Togo', 'Y'),
#  ('G2', 'Avirex', 'Gabon', 'N'),
#  ('V8', 'ATRAN Cargo Airlines', 'Russian Federation', 'Y'),
#  ('VE', 'Avensa', 'Venezuela', 'N'),
#  ('V5', 'Avolar Aerolineas', 'Mexico', 'N'),
#  ('CA', 'Air China', 'China', 'Y'),
#  ('Q6', 'Aero Condor Peru', 'Peru', 'Y'),
#  ('5F', 'Arctic Circle Air Service', 'United States', 'N'),
#  ('QC', 'Air Corridor', 'Mozambique', 'N'),
#  ('NV', 'Air Central', 'Japan', 'N'),
#  ('CV', 'Air Chathams', 'New Zealand', 'Y'),
#  ('CW', 'Air Marshall Islands', 'Marshall Islands', 'Y'),
#  ('ZA', 'Access Air', 'United States', 'Y'),
#  ('AH', 'Air Algerie', 'Algeria', 'Y'),
#  ('ER', 'Astar Air Cargo', 'United States', 'N'),
#  ('HO', 'Antinea Airlines', 'Algeria', 'N'),
#  ('EN', 'Air Dolomiti', 'Italy', 'Y'),
#  ('D9', 'Aeroflot-Don', 'Russia', 'Y'),
#  ('NM', 'Air Madrid', 'Spain', 'Y'),
#  ('EE', 'Aero Airlines', 'Estonia', 'N'),
#  ('4F', 'Air City', 'Germany', 'N'),
#  ('EI', 'Aer Lingus', 'Ireland', 'Y'),
#  ('E8', 'Alpi Eagles', 'Italy', 'N'),
#  ('KY', 'Air S', 'Air S', 'N'),
#  ('PC', 'Air Fiji', 'Fiji', 'N'),
#  ('OF', 'Air Finland', 'Finland', 'Y'),
#  ('FJ', 'Air Pacific', 'Fiji', 'Y'),
#  ('RC', 'Atlantic Airways', 'Faroe Islands', 'Y'),
#  ('QH', 'Air Florida', 'United States', 'Y'),
#  ('NY', 'Air Iceland', 'Iceland', 'Y'),
#  ('2P', 'Air Philippines', 'Philippines', 'Y'),
#  ('ZX', 'Air Georgian', 'Canada', 'N'),
#  ('2U', 'Air Guinee Express', 'Guinea', 'Y'),
#  ('0A', 'Amber Air', 'Lithuania', 'N'),
#  ('DA', 'Air Georgia', 'Georgia', 'N'),
#  ('GL', 'Air Greenland', 'Denmark', 'Y'),
#  ('LL', 'Allegro', 'Mexico', 'N'),
#  ('5Y', 'Atlas Air', 'United States', 'Y'),
#  ('GG', 'Air Guyane', 'French Guiana', 'Y'),
#  ('H9', "Air D'Ayiti", 'Haiti', 'N'),
#  ('IP', 'Atyrau Air Ways', 'Kazakhstan', 'N'),
#  ('QK', 'Air Canada Jazz', 'Canada', 'Y'),
#  ('KK', 'Atlasjet', 'Turkey', 'Y'),
#  ('JS', 'Air Koryo', "Democratic People's Republic of Korea", 'Y'),
#  ('KC', 'Air Astana', 'Kazakhstan', 'Y'),
#  ('LV', 'Albanian Airlines', 'Albania', 'Y'),
#  ('D4', 'Alidaunia', 'Italy', 'N'),
#  ('CD', 'Alliance Air', 'India', 'N'),
#  ('XL', 'Aerolane', 'Ecuador', 'Y'),
#  ('A6', 'Air Alps Aviation', 'Austria', 'N'),
#  ('TD', 'Atlantis European Airways', 'Armenia', 'Y'),
#  ('L8', 'Air Luxor GB', 'Guinea-Bissau', 'N'),
#  ('LK', 'Air Luxor', 'Portugal', 'Y'),
#  ('MK', 'Air Mauritius', 'Mauritius', 'Y'),
#  ('MD', 'Air Madagascar', 'Madagascar', 'Y'),
#  ('9U', 'Air Moldova', 'Moldova', 'Y'),
#  ('M0', 'Aero Mongolia', 'Mongolia', 'N'),
#  ('A7', 'Air Plus Comet', 'Spain', 'Y'),
#  ('QO', 'Aeromexpress', 'Mexico', 'N'),
#  ('MR', 'Air Mauritanie', 'Mauritania', 'N'),
#  ('3S', 'Aeroland Airways', 'Greece', 'N'),
#  ('8D', 'Astair', 'Russian Federation', 'Y'),
#  ('F4', 'Albarka Air', 'Nigeria', 'N'),
#  ('AJ', 'Aero Contractors', 'Nigeria', 'Y'),
#  ('8Y', 'Air Burundi', 'Burundi', 'N'),
#  ('OT', 'Aeropelican Air Services', 'Australia', 'Y'),
#  ('AD', 'Air Paradise International', 'Indonesia', 'N'),
#  ('QD', 'Air Class Lineas Aereas', 'Uruguay', 'N'),
#  ('QS', 'African Safari Airways', 'Kenya', 'N'),
#  ('4Y', 'Airbus France', 'France', 'N'),
#  ('MC', 'Air Mobility Command', 'United States', 'N'),
#  ('RE', 'Aer Arann', 'Ireland', 'Y'),
#  ('UU', 'Air Austral', 'France', 'Y'),
#  ('6K', 'Asian Spirit', 'Philippines', 'Y'),
#  ('RK', 'Air Afrique', 'Ivory Coast', 'Y'),
#  ('A5', 'Airlinair', 'France', 'Y'),
#  ('QL', 'Aero Lanka', 'Sri Lanka', 'Y'),
#  ('MV', 'Armenian International Airways', 'Armenia', 'N'),
#  ('20', 'Air Salone', 'Sierra Leone', 'Y'),
#  ('U8', 'Armavia', 'Armenia', 'Y'),
#  ('BQ', 'Aeromar', 'Dominican Republic', 'N'),
#  ('P5', 'AeroRep', 'Colombia', 'Y'),
#  ('BF', 'Aero-Service', 'Republic of the Congo', 'Y'),
#  ('5L', 'Aerosur', 'Bolivia', 'Y'),
#  ('EX', 'Air Santo Domingo', 'Dominican Republic', 'N'),
#  ('JR', 'Aero California', 'Mexico', 'N'),
#  ('Z3', 'Avient Aviation', 'Zimbabwe', 'Y'),
#  ('GM', 'Air Slovakia', 'Slovakia', 'N'),
#  ('R3', 'Aircompany Yakutia', 'Russia', 'Y'),
#  ('VW', 'Aeromar', 'Mexico', 'Y'),
#  ('JY', 'Air Turks and Caicos', 'Turks and Caicos Islands', 'N'),
#  ('OR', 'Arkefly', 'Netherlands', 'Y'),
#  ('CG', 'Airlines PNG', 'Papua New Guinea', 'Y'),
#  ('TY', 'Air Cal', 'France', 'N'),
#  ('FL', 'AirTran Airways', 'United States', 'Y'),
#  ('TS', 'Air Transat', 'Canada', 'Y'),
#  ('EC', 'Avialeasing Aviation Company', 'Uzbekistan', 'Y'),
#  ('VO', 'Tyrolean Airways', 'Austria', 'Y'),
#  ('DW', 'Aero-Charter Ukraine', 'Ukraine', 'N'),
#  ('6U', 'Air Ukraine', 'Ukraine', 'N'),
#  ('2K', 'Aerolineas Galapagos (Aerogal)', 'Ecuador', 'Y'),
#  ('6R', 'Alrosa Mirny Air Enterprise', 'Russia', 'Y'),
#  ('8Q', 'Baker Aviation', 'United States', 'N'),
#  ('BA', 'British Airways', 'United Kingdom', 'Y'),
#  ('BG', 'Biman Bangladesh Airlines', 'Bangladesh', 'Y'),
#  ('B4', 'BACH Flugbetriebsges', 'Austria', 'N'),
#  ('BZ', 'Blue Dart Aviation', 'India', 'N'),
#  ('J4', 'Buffalo Airways', 'Canada', 'N'),
#  ('A8', 'Benin Golf Air', 'Benin', 'N'),
#  ('4T', 'Belair Airlines', 'Switzerland', 'Y'),
#  ('UP', 'Bahamasair', 'Bahamas', 'Y'),
#  ('E6', 'Bringer Air Cargo Taxi Aereo', 'Brazil', 'N'),
#  ('TH', 'BA Connect', 'United Kingdom', 'N'),
#  ('BS', 'British International Helicopters', 'United Kingdom', 'Y'),
#  ('PG', 'Bangkok Airways', 'Thailand', 'Y'),
#  ('KF', 'Blue1', 'Finland', 'Y'),
#  ('JV', 'Bearskin Lake Air Service', 'Canada', 'Y'),
#  ('B3', 'Bellview Airlines', 'Nigeria', 'Y'),
#  ('BD', 'bmi', 'United Kingdom', 'Y'),
#  ('WW', 'bmibaby', 'United Kingdom', 'Y'),
#  ('CH', 'Bemidji Airlines', 'United States', 'Y'),
#  ('5Z', 'Bismillah Airlines', 'Bangladesh', 'N'),
#  ('BO', 'Bouraq Indonesia Airlines', 'Indonesia', 'N'),
#  ('BV', 'Blue Panorama Airlines', 'Italy', 'Y'),
#  ('7R', 'BRA-Transportes Aereos', 'Brazil', 'N'),
#  ('8E', 'Bering Air', 'United States', 'Y'),
#  ('B2', 'Belavia Belarusian Airlines', 'Belarus', 'Y'),
#  ('K6', 'Bravo Air Congo', 'Democratic Republic of the Congo', 'N'),
#  ('BN', 'Braniff International Airways', 'United States', 'N'),
#  ('GQ', 'Big Sky Airlines', 'United States', 'N'),
#  ('V9', 'BAL Bashkirian Airlines', 'Russia', 'N'),
#  ('7P', 'Metro Batavia', 'Indonesia', 'Y'),
#  ('J8', 'Berjaya Air', 'Malaysia', 'Y'),
#  ('QW', 'Blue Wings', 'Germany', 'Y'),
#  ('DB', 'Brit Air', 'France', 'Y'),
#  ('E9', 'Boston-Maine Airways', 'United States', 'N'),
#  ('SN', 'Brussels Airlines', 'Belgium', 'Y'),
#  ('NT', 'Binter Canarias', 'Spain', 'Y'),
#  ('0B', 'Blue Air', 'Romania', 'Y'),
#  ('KJ', 'British Mediterranean Airways', 'United Kingdom', 'Y'),
#  ('FB', 'Bulgaria Air', 'Bulgaria', 'Y'),
#  ('8N', 'Barents AirLink', 'Sweden', 'Y'),
#  ('5C', 'CAL Cargo Air Lines', 'Israel', 'Y'),
#  ('AW', 'CHC Airways', 'Netherlands', 'N'),
#  ('XG', 'Calima Aviacion', 'Spain', 'Y'),
#  ('R9', 'Camai Air', 'United States', 'N'),
#  ('UY', 'Cameroon Airlines', 'Cameroon', 'N'),
#  ('C6', 'CanJet', 'Canada', 'N'),
#  ('CP', 'Canadian Airlines', 'Canada', 'Y'),
#  ('5T', 'Canadian North', 'Canada', 'Y'),
#  ('W2', 'Canadian Western Airlines', 'Canada', 'N'),
#  ('9K', 'Cape Air', 'United States', 'Y'),
#  ('PT', 'Capital Cargo International Airlines', 'United States', 'N'),
#  ('2G', 'Cargoitalia', 'Italy', 'N'),
#  ('W8', 'Cargojet Airways', 'Canada', 'N'),
#  ('BW', 'Caribbean Airlines', 'Trinidad and Tobago', 'Y'),
#  ('8B', 'Caribbean Star Airlines', 'Antigua and Barbuda', 'N'),
#  ('V3', 'Carpatair', 'Romania', 'Y'),
#  ('RV', 'Caspian Airlines', 'Iran', 'Y'),
#  ('CX', 'Cathay Pacific', 'Hong Kong SAR of China', 'Y'),
#  ('KX', 'Cayman Airways', 'Cayman Islands', 'Y'),
#  ('5J', 'Cebu Pacific', 'Philippines', 'Y'),
#  ('7N', 'Centavia', 'Serbia', 'N'),
#  ('C0', 'Centralwings', 'Poland', 'Y'),
#  ('J7', 'Centre-Avia', 'Russia', 'N'),
#  ('WE', 'Centurion Air Cargo', 'United States', 'N'),
#  ('OP', "Chalk's Ocean Airways", 'United States', 'N'),
#  ('MG', 'Champion Air', 'United States', 'N'),
#  ('2Z', 'Changan Airlines', 'China', 'N'),
#  ('S8', 'Chari Aviation Services', 'Chad', 'N'),
#  ('RP', 'Chautauqua Airlines', 'United States', 'Y'),
#  ('C8', 'Chicago Express', 'United States', 'N'),
#  ('CI', 'China Airlines', 'Taiwan', 'Y'),
#  ('CK', 'China Cargo Airlines', 'China', 'N'),
#  ('MU', 'China Eastern Airlines', 'China', 'Y'),
#  ('CJ', 'China Northern Airlines', 'China', 'N'),
#  ('WH', 'China Northwest Airlines', 'China', 'N'),
#  ('CZ', 'China Southern Airlines', 'China', 'Y'),
#  ('HR', 'China United Airlines', 'China', 'Y'),
#  ('XO', 'China Xinhua Airlines', 'China', 'N'),
#  ('3Q', 'Yunnan Airlines', 'China', 'Y'),
#  ('X7', 'Chitaavia', 'Russia', 'N'),
#  ('A2', 'Cielos Airlines', 'Peru', 'N'),
#  ('QI', 'Cimber Air', 'Denmark', 'Y'),
#  ('C9', 'Cirrus Airlines', 'Germany', 'Y'),
#  ('CF', 'City Airline', 'Sweden', 'Y'),
#  ('G3', 'City Connexion Airlines', 'Burundi', 'Y'),
#  ('WX', 'CityJet', 'Ireland', 'Y'),
#  ('CT', 'Civil Air Transport', 'Taiwan', 'N'),
#  ('6P', 'Club Air', 'Italy', 'N'),
#  ('BX', 'Coast Air', 'Norway', 'N'),
#  ('DQ', 'Coastal Air', 'United States', 'Y'),
#  ('9L', 'Colgan Air', 'United States', 'Y'),
#  ('OH', 'Comair', 'United States', 'Y'),
#  ('MN', 'Comair', 'South Africa', 'Y'),
#  ('C5', 'CommutAir', 'United States', 'Y'),
#  ('KR', 'Comores Airlines', 'Comoros', 'Y'),
#  ('GJ', 'Compania Mexicargo', 'Mexico', 'N'),
#  ('DE', 'Condor Flugdienst', 'Germany', 'Y'),
#  ('6A', 'Consorcio Aviaxsa', 'Mexico', 'Y'),
#  ('C3', 'Contact Air', 'Germany', 'Y'),
#  ('CO', 'Continental Airlines', 'United States', 'Y'),
#  ('CS', 'Continental Micronesia', 'United States', 'Y'),
#  ('V0', 'Conviasa', 'Venezuela', 'Y'),
#  ('CM', 'Copa Airlines', 'Panama', 'Y'),
#  ('SS', 'Corsairfly', 'France', 'Y'),
#  ('XK', 'Corse-Mediterranee', 'France', 'Y'),
#  ('F5', 'Cosmic Air', 'Nepal', 'N'),
#  ('OU', 'Croatia Airlines', 'Croatia', 'Y'),
#  ('QE', 'Crossair Europe', 'Switzerland', 'N'),
#  ('CU', 'Cubana de Aviación', 'Cuba', 'Y'),
#  ('CY', 'Cyprus Airways', 'Cyprus', 'Y'),
#  ('YK', 'Cyprus Turkish Airlines', 'Turkey', 'Y'),
#  ('OK', 'Czech Airlines', 'Czech Republic', 'Y'),
#  ('WD', 'DAS Air Cargo', 'Uganda', 'N'),
#  ('DX', 'DAT Danish Air Transport', 'Denmark', 'Y'),
#  ('ES', 'DHL International', 'Bahrain', 'N'),
#  ('L3', 'DHL de Guatemala', 'Guatemala', 'N'),
#  ('D3', 'Daallo Airlines', 'Djibouti', 'Y'),
#  ('N2', 'Dagestan Airlines', 'Russia', 'N'),
#  ('H8', 'Dalavia', 'Russia', 'Y'),
#  ('0D', 'Darwin Airline', 'Switzerland', 'Y'),
#  ('D5', 'Dauair', 'Germany', 'N'),
#  ('DL', 'Delta Air Lines', 'United States', 'Y'),
#  ('2A', 'Deutsche Bahn', 'Germany', 'Y'),
#  ('1I', 'Deutsche Rettungsflugwacht', 'Germany', 'N'),
#  ('D7', 'Dinar', 'Argentina', 'N'),
#  ('DH', 'Discovery Airways', 'United States', 'N'),
#  ('D8', 'Djibouti Airlines', 'Djibouti', 'Y'),
#  ('DO', 'Dominicana de Aviaci', 'Dominican Republic', 'Y'),
#  ('E3', 'Domodedovo Airlines', 'Russia', 'Y'),
#  ('KA', 'Dragonair', 'DRAGON', 'Y'),
#  ('KB', 'Druk Air', 'Bhutan', 'Y'),
#  ('DI', 'dba', 'Germany', 'Y'),
#  ('1C', 'Electronic Data Systems', 'Switzerland', 'N'),
#  ('BR', 'EVA Air', 'Taiwan', 'Y'),
#  ('H7', 'Eagle Air', 'Uganda', 'Y'),
#  ('QU', 'East African', 'Uganda', 'Y'),
#  ('S9', 'East African Safari Air', 'Kenya', 'N'),
#  ('T3', 'Eastern Airways', 'United Kingdom', 'Y'),
#  ('DK', 'Eastland Air', 'Australia', 'Y'),
#  ('MS', 'Egyptair', 'Egypt', 'Y'),
#  ('LY', 'El Al Israel Airlines', 'Israel', 'Y'),
#  ('UZ', 'El-Buraq Air Transport', 'Libya', 'Y'),
#  ('EK', 'Emirates', 'United Arab Emirates', 'Y'),
#  ('EU', 'Empresa Ecuatoriana De Aviacion', 'Ecuador', 'Y'),
#  ('E0', 'Eos Airlines', 'United States', 'N'),
#  ('B8', 'Eritrean Airlines', 'Eritrea', 'Y'),
#  ('E7', 'Estafeta Carga Aerea', 'Mexico', 'N'),
#  ('OV', 'Estonian Air', 'Estonia', 'Y'),
#  ('ET', 'Ethiopian Airlines', 'Ethiopia', 'Y'),
#  ('EY', 'Etihad Airways', 'United Arab Emirates', 'Y'),
#  ('RZ', 'Euro Exec Express', 'Sweden', 'Y'),
#  ('UI', 'Eurocypria Airlines', 'Cyprus', 'Y'),
#  ('K2', 'Eurolot', 'Poland', 'Y'),
#  ('3W', 'Euromanx Airways', 'Austria', 'N'),
#  ('EA', 'European Air Express', 'Germany', 'Y'),
#  ('QY', 'European Air Transport', 'Belgium', 'N'),
#  ('EW', 'Eurowings', 'Germany', 'Y'),
#  ('EZ', 'Evergreen International Airlines', 'United States', 'Y'),
#  ('JN', 'Excel Airways', 'United Kingdom', 'Y'),
#  ('MB', 'Execair Aviation', 'Canada', 'N'),
#  ('OW', 'Executive Airlines', 'United States', 'N'),
#  ('EO', 'Express One International', 'United States', 'Y'),
#  ('XE', 'ExpressJet', 'United States', 'Y'),
#  ('U2', 'easyJet', 'United Kingdom', 'Y'),
#  ('IH', 'Falcon Aviation', 'Sweden', 'N'),
#  ('EF', 'Far Eastern Air Transport', 'Taiwan', 'Y'),
#  ('F6', 'Faroejet', 'Faroe Islands', 'N'),
#  ('F3', 'Faso Airways', 'Burkina Faso', 'N'),
#  ('FX', 'Federal Express', 'United States', 'N'),
#  ('N8', 'Fika Salaama Airlines', 'Uganda', 'N'),
#  ('4S', 'Finalair Congo', 'Republic of the Congo', 'N'),
#  ('AY', 'Finnair', 'Finland', 'Y'),
#  ('FC', 'Finncomm Airlines', 'Finland', 'Y'),
#  ('FY', 'Firefly', 'Malaysia', 'Y'),
#  ('7F', 'First Air', 'Canada', 'Y'),
#  ('DP', 'First Choice Airways', 'United Kingdom', 'Y'),
#  ('8F', 'Fischer Air', 'Czech Republic', 'N'),
#  ('B5', 'Flightline', 'United Kingdom', 'Y'),
#  ('PA', 'Florida Coastal Airlines', 'United States', 'N'),
#  ('RF', 'Florida West International Airways', 'United States', 'Y'),
#  ('F2', 'Fly Air', 'Turkey', 'N'),
#  ('SH', 'Fly Me Sweden', 'Sweden', 'N'),
#  ('TE', 'FlyLal', 'Lithuania', 'Y'),
#  ('LF', 'FlyNordic', 'Sweden', 'Y'),
#  ('F7', 'Flybaboo', 'Switzerland', 'Y'),
#  ('BE', 'Flybe', 'United Kingdom', 'Y'),
#  ('VY', 'Formosa Airlines', 'Taiwan', 'Y'),
#  ('HK', 'Four Star Aviation / Four Star Cargo', 'United States', 'N'),
#  ('FP', 'Freedom Air', 'United States', 'Y'),
#  ('F9', 'Frontier Airlines', 'United States', 'Y'),
#  ('2F', 'Frontier Flying Service', 'United States', 'Y'),
#  ('FH', 'Futura International Airways', 'Spain', 'N'),
#  ('GT', 'GB Airways', 'United Kingdom', 'Y'),
#  ('7O', 'Galaxy Air', 'Kyrgyzstan', 'N'),
#  ('1G', 'Galileo International', 'United States', 'N'),
#  ('GC', 'Gambia International Airlines', 'Gambia', 'N'),
#  ('G7', 'Gandalf Airlines', 'Italy', 'N'),
#  ('GA', 'Garuda Indonesia', 'Indonesia', 'Y'),
#  ('A9', 'Georgian Airways', 'Georgia', 'Y'),
#  ('QB', 'Georgian National Airlines', 'Georgia', 'Y'),
#  ('ST', 'Germania', 'Germany', 'Y'),
#  ('4U', 'Germanwings', 'Germany', 'Y'),
#  ('GP', 'Gestair', 'Spain', 'N'),
#  ('G0', 'Ghana International Airlines', 'Ghana', 'Y'),
#  ('GK', 'Go One Airways', 'United Kingdom', 'N'),
#  ('DC', 'Golden Air', 'Sweden', 'Y'),
#  ('G1', 'Gorkha Airlines', 'Nepal', 'N'),
#  ('ZK', 'Great Lakes Airlines', 'United States', 'Y'),
#  ('IJ', 'Great Wall Airlines', 'China', 'N'),
#  ('TA', 'Grupo TACA', 'Costa Rica', 'Y'),
#  ('G6', 'Guine Bissaur Airlines', 'Guinea-Bissau', 'N'),
#  ('J9', 'Guinee Airlines', 'Guinea', 'N'),
#  ('GF', 'Gulf Air Bahrain', 'Bahrain', 'Y'),
#  ('H6', 'Hageland Aviation Services', 'United States', 'Y'),
#  ('HU', 'Hainan Airlines', 'China', 'Y'),
#  ('1R', 'Hainan Phoenix Information Systems', 'China', 'N'),
#  ('2T', 'Haiti Ambassador Airlines', 'Haiti', 'Y'),
#  ('4R', 'Hamburg International', 'Germany', 'Y'),
#  ('X3', 'TUIfly', 'Germany', 'Y'),
#  ('HF', 'Hapagfly', 'Germany', 'Y'),
#  ('HB', 'Harbor Airlines', 'United States', 'N'),
#  ('HQ', 'Harmony Airways', 'Canada', 'N'),
#  ('HA', 'Hawaiian Airlines', 'United States', 'Y'),
#  ('BH', 'Hawkair', 'Canada', 'Y'),
#  ('HN', 'Heavylift Cargo Airlines', 'Australia', 'N'),
#  ('8H', 'Heli France', 'France', 'Y'),
#  ('JB', 'Helijet', 'Canada', 'Y'),
#  ('ZU', 'Helios Airways', 'Cyprus', 'N'),
#  ('T4', 'Hellas Jet', 'Greece', 'Y'),
#  ('HW', 'Hello', 'Switzerland', 'Y'),
#  ('2L', 'Helvetic Airways', 'Switzerland', 'Y'),
#  ('DU', 'Hemus Air', 'Bulgaria', 'N'),
#  ('UD', "Hex'Air", 'France', 'Y'),
#  ('5K', 'Hi Fly', 'Portugal', 'N'),
#  ('HD', 'Hokkaido International Airlines', 'Japan', 'Y'),
#  ('H5', 'Hola Airlines', 'Spain', 'N'),
#  ('HX', 'Hong Kong Airlines', 'Hong Kong SAR of China', 'Y'),
#  ('UO', 'Hong Kong Express Airways', 'Hong Kong SAR of China', 'Y'),
#  ('HH', 'Hope Air', 'Canada', 'N'),
#  ('QX', 'Horizon Air', 'United States', 'Y'),
#  ('H4', 'Héli Sécurité Helicopter Airlines', 'France', 'N'),
#  ('II', 'IBC Airways', 'United States', 'N'),
#  ('1F', 'INFINI Travel Information', 'Japan', 'N'),
#  ('1U', 'ITA Software', 'United States', 'N'),
#  ('IB', 'Iberia Airlines', 'Spain', 'Y'),
#  ('FW', 'Ibex Airlines', 'Japan', 'Y'),
#  ('FI', 'Icelandair', 'Iceland', 'Y'),
#  ('IK', 'Imair Airlines', 'Azerbaijan', 'Y'),
#  ('6E', 'IndiGo Airlines', 'India', 'Y'),
#  ('IC', 'Indian Airlines', 'India', 'Y'),
#  ('QZ', 'Indonesia AirAsia', 'Indonesia', 'Y'),
#  ('IO', 'Indonesian Airlines', 'Indonesia', 'Y'),
#  ('D6', 'Interair South Africa', 'South Africa', 'Y'),
#  ('RS', 'Intercontinental de Aviaci', 'Colombia', 'N'),
#  ('ID', 'Interlink Airlines', 'South Africa', 'Y'),
#  ('6I', 'International Business Air', 'Sweden', 'N'),
#  ('3L', 'Intersky', 'Austria', 'Y'),
#  ('I4', 'Interstate Airline', 'Netherlands', 'N'),
#  ('IR', 'Iran Air', 'Iran', 'Y'),
#  ('EP', 'Iran Aseman Airlines', 'Iran', 'Y'),
#  ('IA', 'Iraqi Airways', 'Iraq', 'Y'),
#  ('IS', 'Island Airlines', 'United States', 'Y'),
#  ('2S', 'Island Express', 'United States', 'N'),
#  ('8L', 'Cargo Plus Aviation', 'United Arab Emirates', 'Y'),
#  ('CN', 'Islands Nationair', 'Papua New Guinea', 'N'),
#  ('IF', 'Islas Airways', 'Spain', 'Y'),
#  ('WC', 'Islena De Inversiones', 'Honduras', 'Y'),
#  ('6H', 'Israir', 'Israel', 'Y'),
#  ('9X', 'Itali Airlines', 'Italy', 'N'),
#  ('GI', 'Itek Air', 'Kyrgyzstan', 'Y'),
#  ('JC', 'JAL Express', 'Japan', 'Y'),
#  ('JO', 'JALways', 'Japan', 'Y'),
#  ('1M', 'JSC Transport Automated Information Systems', 'Russia', 'N'),
#  ('JL', 'Japan Airlines', 'Japan', 'Y'),
#  ('EG', 'Japan Asia Airways', 'Japan', 'Y'),
#  ('NU', 'Japan Transocean Air', 'Japan', 'Y'),
#  ('JU', 'Jat Airways', 'Serbia', 'N'),
#  ('VJ', 'Jatayu Airlines', 'Indonesia', 'N'),
#  ('7C', 'Jeju Air', 'Republic of Korea', 'Y'),
#  ('9W', 'Jet Airways', 'India', 'Y'),
#  ('QJ', 'Jet Airways', 'United States', 'Y'),
#  ('0J', 'Jetclub', 'Switzerland', 'N'),
#  ('3K', 'Jetstar Asia Airways', 'Singapore', 'Y'),
#  ('LS', 'Jet2.com', 'United Kingdom', 'Y'),
#  ('8J', 'Jet4You', 'Morocco', 'Y'),
#  ('B6', 'JetBlue Airways', 'United States', 'Y'),
#  ('JF', 'Jetairfly', 'Belgium', 'Y'),
#  ('SG', 'JetsGo', 'Canada', 'N'),
#  ('JQ', 'Jetstar Airways', 'Australia', 'Y'),
#  ('JX', 'Jett8 Airlines Cargo', 'Singapore', 'N'),
#  ('GX', 'Jetx Airlines', 'Iceland', 'N'),
#  ('R5', 'Jordan Aviation', 'Jordan', 'N'),
#  ('KD', 'KD Avia', 'Russia', 'Y'),
#  ('WA', 'KLM Cityhopper', 'Netherlands', 'Y'),
#  ('KL', 'KLM Royal Dutch Airlines', 'Netherlands', 'Y'),
#  ('K4', 'Kalitta Air', 'United States', 'N'),
#  ('RQ', 'Kam Air', 'Afghanistan', 'Y'),
#  ('E2', 'Kampuchea Airlines', 'Cambodia', 'N'),
#  ('V2', 'Karat', 'Russia', 'N'),
#  ('KV', 'Kavminvodyavia', 'Russia', 'Y'),
#  ('M5', 'Kenmore Air', 'United States', 'Y'),
#  ('KQ', 'Kenya Airways', 'Kenya', 'Y'),
#  ('IT', 'Kingfisher Airlines', 'India', 'Y'),
#  ('Y9', 'Kish Air', 'Iran', 'Y'),
#  ('KP', 'Kiwi International Air Lines', 'United States', 'N'),
#  ('7K', 'Kogalymavia Air Company', 'Russia', 'Y'),
#  ('KE', 'Korean Air', 'Republic of Korea', 'Y'),
#  ('7B', 'Krasnojarsky Airlines', 'Russia', 'Y'),
#  ('K9', 'Krylo Airlines', 'Russia', 'N'),
#  ('GW', 'Kuban Airlines', 'Russia', 'Y'),
#  ('KU', 'Kuwait Airways', 'Kuwait', 'Y'),
#  ('GO', 'Kuzu Airlines Cargo', 'Turkey', 'Y'),
#  ('N5', 'Kyrgyz Airlines', 'Kyrgyzstan', 'N'),
#  ('R8', 'Kyrgyzstan Airlines', 'Kyrgyzstan', 'N'),
#  ('LR', 'LACSA', 'Costa Rica', 'Y'),
#  ('KG', 'LAI - Linea Aerea IAACA', 'Venezuela', 'N'),
#  ('LA', 'LAN Airlines', 'Chile', 'Y'),
#  ('4M', 'LAN Argentina', 'Argentina', 'Y'),
#  ('LU', 'LAN Express', 'Chile', 'Y'),
#  ('LP', 'LAN Peru', 'Peru', 'Y'),
#  ('LO', 'LOT Polish Airlines', 'Poland', 'Y'),
#  ('LT', 'LTU International', 'Germany', 'N'),
#  ('N6', 'Lagun Air', 'Spain', 'N'),
#  ('QV', 'Lao Airlines', 'Lao Peoples Democratic Republic', 'Y'),
#  ('L7', 'Laoag International Airlines', 'Philippines', 'N'),
#  ('NG', 'Lauda Air', 'Austria', 'Y'),
#  ('LQ', 'Lebanese Air Transport', 'Lebanon', 'N'),
#  ('LI', 'Leeward Islands Air Transport', 'Antigua and Barbuda', 'Y'),
#  ('LN', 'Libyan Arab Airlines', 'Libya', 'Y'),
#  ('8z', 'Linea Aerea de Servicio Ejecutivo Regional', 'Venezuela', 'N'),
#  ('LM', 'Linhas A', 'Mozambique', 'Y'),
#  ('JT', 'Lion Mentari Airlines', 'Indonesia', 'Y'),
#  ('LB', 'Lloyd Aereo Boliviano', 'Bolivia', 'N'),
#  ('HE', 'Luftfahrtgesellschaft Walter', 'Germany', 'Y'),
#  ('LH', 'Lufthansa', 'Germany', 'Y'),
#  ('CL', 'Lufthansa CityLine', 'Germany', 'Y'),
#  ('L1', 'Lufthansa Systems', 'Germany', 'N'),
#  ('DV', 'Lufttaxi Fluggesellschaft', 'Germany', 'N'),
#  ('L5', 'Lufttransport', 'Norway', 'Y'),
#  ('LG', 'Luxair', 'Luxembourg', 'Y'),
#  ('5V', 'Lviv Airlines', 'Ukraine', 'N'),
#  ('L2', 'Lynden Air Cargo', 'United States', 'N'),
#  ('MJ', 'L', 'Argentina', 'Y'),
#  ('M7', 'MasAir', 'Mexico', 'Y'),
#  ('IN', 'MAT Macedonian Airlines', 'Macedonia', 'Y'),
#  ('OM', 'MIAT Mongolian Airlines', 'Mongolia', 'Y'),
#  ('DM', 'Maersk', 'Denmark', 'Y'),
#  ('W5', 'Mahan Air', 'Iran', 'Y'),
#  ('M2', 'Mahfooz Aviation', 'Gambia', 'N'),
#  ('MH', 'Malaysia Airlines', 'Malaysia', 'Y'),
#  ('TF', 'Malmö Aviation', 'Sweden', 'Y'),
#  ('MA', 'Malév', 'Hungary', 'Y'),
#  ('RI', 'Mandala Airlines', 'Indonesia', 'Y'),
#  ('AE', 'Mandarin Airlines', 'Taiwan', 'Y'),
#  ('JE', 'Mango', 'South Africa', 'Y'),
#  ('MP', 'Martinair', 'Netherlands', 'Y'),
#  ('Q4', 'Mastertop Linhas Aereas', 'Brazil', 'N'),
#  ('8M', 'Maxair', 'Sweden', 'Y'),
#  ('MY', 'Maxjet Airways', 'United States', 'N'),
#  ('MW', 'Maya Island Air', 'Belize', 'Y'),
#  ('IM', 'Menajet', 'Lebanon', 'N'),
#  ('IG', 'Meridiana', 'Italy', 'Y'),
#  ('MZ', 'Merpati Nusantara Airlines', 'Indonesia', 'Y'),
#  ('YV', 'Mesa Airlines', 'United States', 'Y'),
#  ('XJ', 'Mesaba Airlines', 'United States', 'Y'),
#  ('MX', 'Mexicana de Aviaci', 'Mexico', 'Y'),
#  ('ME', 'Middle East Airlines', 'Lebanon', 'Y'),
#  ('JI', 'Midway Airlines', 'United States', 'Y'),
#  ('YX', 'Midwest Airlines', 'United States', 'Y'),
#  ('2M', 'Moldavian Airlines', 'Moldova', 'Y'),
#  ('8I', 'Myway Airlines', 'Italy', 'Y'),
#  ('YM', 'Montenegro Airlines', 'Montenegro', 'Y'),
#  ('3R', 'Moskovia Airlines', 'Russia', 'Y'),
#  ('M9', 'Motor Sich', 'Ukraine', 'Y'),
#  ('N4', 'Mountain Air Company', 'Sierra Leone', 'N'),
#  ('VZ', 'MyTravel Airways', 'United Kingdom', 'Y'),
#  ('UB', 'Myanma Airways', 'Myanmar', 'Y'),
#  ('P9', 'Nas Air', 'Mali', 'N'),
#  ('UE', 'Nasair', 'Eritrea', 'Y'),
#  ('N7', 'National Airlines', 'United States', 'N'),
#  ('9O', 'National Airways Cameroon', 'Cameroon', 'N'),
#  ('NC', 'National Jet Systems', 'Australia', 'Y'),
#  ('CE', 'Nationwide Airlines', 'South Africa', 'Y'),
#  ('ON', 'Nauru Air Corporation', 'Nauru', 'Y'),
#  ('1N', 'Navitaire', 'United States', 'N'),
#  ('RA', 'Nepal Airlines', 'Nepal', 'Y'),
#  ('EJ', 'New England Airlines', 'United States', 'Y'),
#  ('2N', 'NextJet', 'Sweden', 'Y'),
#  ('HG', 'Niki', 'Austria', 'Y'),
#  ('KZ', 'Nippon Cargo Airlines', 'Japan', 'N'),
#  ('DD', 'Nok Air', 'Thailand', 'Y'),
#  ('JH', 'Nordeste Linhas Aereas Regionais', 'Brazil', 'N'),
#  ('6N', 'Nordic Regional', 'Sweden', 'N'),
#  ('N9', 'North Coast Aviation', 'Papua New Guinea', 'N'),
#  ('U7', 'Northern Dene Airways', 'Canada', 'Y'),
#  ('NW', 'Northwest Airlines', 'United States', 'Y'),
#  ('J3', 'Northwestern Air', 'Canada', 'Y'),
#  ('DY', 'Norwegian Air Shuttle', 'Norway', 'Y'),
#  ('BJ', 'Nouvel Air Tunisie', 'Tunisia', 'Y'),
#  ('M4', 'Nova Airline', 'Sudan', 'N'),
#  ('XY', 'Nas Air', 'Saudi Arabia', 'Y'),
#  ('UQ', "O'Connor Airlines", 'Australia', 'N'),
#  ('CR', 'OAG', 'United Kingdom', 'N'),
#  ('O8', 'Oasis Hong Kong Airlines', 'Hong Kong', 'Y'),
#  ('VC', 'Ocean Airlines', 'Italy', 'N'),
#  ('O6', 'Oceanair', 'Brazil', 'Y'),
#  ('O2', 'Oceanic Airlines', 'Guinea', 'Y'),
#  ('OA', 'Olympic Airlines', 'Greece', 'Y'),
#  ('WY', 'Oman Air', 'Oman', 'Y'),
#  ('OY', 'Omni Air International', 'United States', 'Y'),
#  ('N3', 'Omskavia Airline', 'Russia', 'N'),
#  ('R2', 'Orenburg Airlines', 'Russia', 'Y'),
#  ('OX', 'Orient Thai Airlines', 'Thailand', 'Y'),
#  ('OL', 'Ostfriesische Lufttransport', 'Germany', 'Y'),
#  ('OJ', 'Overland Airways', 'Nigeria', 'Y'),
#  ('O7', 'Ozjet Airlines', 'Australia', 'Y'),
#  ('PV', 'PAN Air', 'Spain', 'Y'),
#  ('9Q', 'PB Air', 'Thailand', 'Y'),
#  ('PU', 'PLUNA', 'Uruguay', 'Y'),
#  ('U4', 'PMTair', 'Cambodia', 'Y'),
#  ('Y5', 'Pace Airlines', 'United States', 'N'),
#  ('BL', 'Jetstar Pacific', 'Vietnam', 'Y'),
#  ('DJ', 'Pacific Blue', 'New Zealand', 'N'),
#  ('8P', 'Pacific Coastal Airline', 'Canada', 'Y'),
#  ('Q8', 'Pacific East Asia Cargo Airlines', 'Philippines', 'Y'),
#  ('PS', 'Pacific Southwest Airlines', 'United States', 'N'),
#  ('LW', 'Pacific Wings', 'United States', 'Y'),
#  ('PK', 'Pakistan International Airlines', 'Pakistan', 'Y'),
#  ('PF', 'Palestinian Airlines', 'Egypt', 'N'),
#  ('NR', 'Pamir Airways', 'Afghanistan', 'N'),
#  ('PQ', 'Panafrican Airways', 'Ivory Coast', 'N'),
#  ('P8', 'Pantanal Linhas Aéreas', 'Brazil', 'N'),
#  ('I7', 'Paramount Airways', 'India', 'Y'),
#  ('KS', 'Peninsula Airways', 'United States', 'Y'),
#  ('PR', 'Philippine Airlines', 'Philippines', 'Y'),
#  ('9R', 'Phuket Air', 'Thailand', 'N'),
#  ('PI', 'Piedmont Airlines (1948-1989)', 'United States', 'Y'),
#  ('9E', 'Pinnacle Airlines', 'United States', 'Y'),
#  ('PO', 'Polar Air Cargo', 'United States', 'N'),
#  ('PH', 'Polynesian Airlines', 'Samoa', 'Y'),
#  ('PD', 'Porter Airlines', 'Canada', 'Y'),
#  ('NI', 'Portugalia', 'Portugal', 'Y'),
#  ('BK', 'Potomac Air', 'United States', 'Y'),
#  ('PW', 'Precision Air', 'Tanzania', 'Y'),
#  ('TO', 'President Airlines', 'Cambodia', 'N'),
#  ('FE', 'Primaris Airlines', 'United States', 'N'),
#  ('P0', 'Proflight Commuter Services', 'Zambia', 'Y'),
#  ('QF', 'Qantas', 'Australia', 'Y'),
#  ('QR', 'Qatar Airways', 'Qatar', 'Y'),
#  ('R6', 'RACSA', 'Guatemala', 'Y'),
#  ('1D', 'Radixx Solutions International', 'United States', 'N'),
#  ('V4', 'Reem Air', 'Kyrgyzstan', 'N'),
#  ('FN', 'Regional Airlines', 'Morocco', 'Y'),
#  ('ZL', 'Regional Express', 'Australia', 'Y'),
#  ('3C', 'RegionsAir', 'United States', 'N'),
#  ('RW', 'Republic Airlines', 'United States', 'Y'),
#  ('RH', 'Republic Express Airlines', 'Indonesia', 'Y'),
#  ('C7', 'Rico Linhas A', 'Brazil', 'N'),
#  ('SL', 'Rio Sul Servi', 'Brazil', 'N'),
#  ('R4', 'Rossiya', 'Russia', 'Y'),
#  ('GZ', 'Air Rarotonga', 'Cook Islands', 'Y'),
#  ('RR', 'Royal Air Force', 'United Kingdom', 'N'),
#  ('AT', 'Royal Air Maroc', 'Morocco', 'Y'),
#  ('R0', 'Royal Airlines', 'Pakistan', 'N'),
#  ('BI', 'Royal Brunei Airlines', 'Brunei', 'Y'),
#  ('RJ', 'Royal Jordanian', 'Jordan', 'Y'),
#  ('WR', 'Royal Tongan Airlines', 'Tonga', 'N'),
#  ('P7', 'Russian Sky Airlines', 'Russia', 'N'),
#  ('WB', 'Rwandair Express', 'Rwanda', 'Y'),
#  ('RD', 'Ryan International Airlines', 'United States', 'Y'),
#  ('FR', 'Ryanair', 'Ireland', 'Y'),
#  ('YS', 'Régional', 'France', 'Y'),
#  ('S4', 'SATA International', 'Portugal', 'Y'),
#  ('SA', 'South African Airways', 'South Africa', 'Y'),
#  ('NL', 'Shaheen Air International', 'Pakistan', 'Y'),
#  ('SK', 'Scandinavian Airlines System', 'Sweden', 'Y'),
#  ('S7', 'S7 Airlines', 'Russia', 'Y'),
#  ('BB', 'Seaborne Airlines', 'United States', 'Y'),
#  ('UL', 'SriLankan Airlines', 'Sri Lanka', 'Y'),
#  ('SY', 'Sun Country Airlines', 'United States', 'Y'),
#  ('I6', 'Sky Eyes', 'Thailand', 'N'),
#  ('7G', 'Star Flyer', 'Japan', 'Y'),
#  ('FA', 'Safair', 'South Africa', 'N'),
#  ('SP', 'SATA Air Acores', 'Portugal', 'Y'),
#  ('SQ', 'Singapore Airlines', 'Singapore', 'Y'),
#  ('5M', 'Sibaviatrans', 'Russia', 'Y'),
#  ('SI', 'Skynet Airlines', 'Ireland', 'Y'),
#  ('XS', 'SITA', 'Belgium', 'N'),
#  ('SJ', 'Sriwijaya Air', 'Indonesia', 'Y'),
#  ('ZS', 'Sama Airlines', 'Saudi Arabia', 'Y'),
#  ('FT', 'Siem Reap Airways', 'Cambodia', 'Y'),
#  ('SX', 'Sky Work Airlines', 'Switzerland', 'N'),
#  ('SM', 'Swedline Express', 'Sweden', 'N'),
#  ('DG', 'South East Asian Airlines', 'Philippines', 'Y'),
#  ('5G', 'Skyservice Airlines', 'Canada', 'Y'),
#  ('FS', 'Servicios de Transportes A', 'Argentina', 'Y'),
#  ('SD', 'Sudan Airways', 'Sudan', 'Y'),
#  ('SV', 'Saudi Arabian Airlines', 'Saudi Arabia', 'Y'),
#  ('WN', 'Southwest Airlines', 'United States', 'Y'),
#  ('A4', 'Southern Winds Airlines', 'Argentina', 'Y'),
#  ('WG', 'Sunwing Airlines', 'Canada', 'N'),
#  ('LX', 'Swiss International Air Lines', 'Switzerland', 'Y'),
#  ('SR', 'Swissair', 'Switzerland', 'Y'),
#  ('WV', 'Swe Fly', 'Sweden', 'Y'),
#  ('XQ', 'SunExpress', 'Turkey', 'Y'),
#  ('AL', 'Skywalk Airlines', 'United States', 'Y'),
#  ('ZP', 'Silk Way Airlines', 'Azerbaijan', 'N'),
#  ('E5', 'Samara Airlines', 'Russia', 'N'),
#  ('SC', 'Shandong Airlines', 'China', 'Y'),
#  ('9S', 'Spring Airlines', 'China', 'Y'),
#  ('3U', 'Sichuan Airlines', 'China', 'Y'),
#  ('FM', 'Shanghai Airlines', 'China', 'Y'),
#  ('ZH', 'Shenzhen Airlines', 'China', 'Y'),
#  ('7L', "Sun D'Or", 'Israel', 'Y'),
#  ('NE', 'SkyEurope', 'Slovakia', 'Y'),
#  ('CQ', 'Sunshine Express Airlines', 'Australia', 'N'),
#  ('SO', 'Superior Aviation', 'United States', 'N'),
#  ('JK', 'Spanair', 'Spain', 'Y'),
#  ('1Z', 'Sabre Pacific', 'Australia', 'N'),
#  ('1S', 'Sabre', 'United States', 'N'),
#  ('1H', 'Siren-Travel', 'Russia', 'N'),
#  ('1Q', 'Sirena', 'Russia', 'N'),
#  ('1K', 'Southern Cross Distribution', 'Australia', 'N'),
#  ('2C', 'SNCF', 'France', 'N'),
#  ('NK', 'Spirit Airlines', 'United States', 'Y'),
#  ('S0', 'Slok Air Gambia', 'Gambia', 'N'),
#  ('S3', 'Santa Barbara Airlines', 'Venezuela', 'Y'),
#  ('H2', 'Sky Airline', 'Chile', 'Y'),
#  ('OO', 'SkyWest', 'United States', 'Y'),
#  ('JZ', 'Skyways Express', 'Sweden', 'Y'),
#  ('BC', 'Skymark Airlines', 'Japan', 'Y'),
#  ('LJ', 'Sierra National Airlines', 'Sierra Leone', 'N'),
#  ('MI', 'SilkAir', 'Singapore', 'Y'),
#  ('6Q', 'Slovak Airlines', 'Slovakia', 'N'),
#  ('PY', 'Surinam Airways', 'Suriname', 'Y'),
#  ('NB', 'Sterling Airlines', 'Denmark', 'Y'),
#  ('6J', 'Skynet Asia Airways', 'Japan', 'Y'),
#  ('IE', 'Solomon Airlines', 'Solomon Islands', 'Y'),
#  ('6W', 'Saratov Aviation Division', 'Russia', 'Y'),
#  ('HZ', 'Sat Airlines', 'Kazakhstan', 'Y'),
#  ('S5', 'Shuttle America', 'United States', 'Y'),
#  ('S6', 'Star Air', 'Denmark', 'N'),
#  ('EQ', 'TAME', 'Ecuador', 'Y'),
#  ('JJ', 'TAM Brazilian Airlines', 'Brazil', 'Y'),
#  ('TP', 'TAP Portugal', 'Portugal', 'Y'),
#  ('TU', 'Tunisair', 'Tunisia', 'Y'),
#  ('3V', 'TNT Airways', 'Belgium', 'N'),
#  ('T2', 'Thai Air Cargo', 'Thailand', 'Y'),
#  ('FQ', 'Thomas Cook Airlines', 'Belgium', 'Y'),
#  ('MT', 'Thomas Cook Airlines', 'United Kingdom', 'Y'),
#  ('TQ', 'Tandem Aero', 'Moldova', 'N'),
#  ('L9', 'Teamline Air', 'Austria', 'N'),
#  ('ZT', 'Titan Airways', 'United Kingdom', 'N'),
#  ('TR', 'Tiger Airways', 'Singapore', 'Y'),
#  ('TG', 'Thai Airways International', 'Thailand', 'Y'),
#  ('FD', 'Thai AirAsia', 'Thailand', 'Y'),
#  ('TK', 'Turkish Airlines', 'Turkey', 'Y'),
#  ('T7', 'Twin Jet', 'France', 'Y'),
#  ('9I', 'Thai Sky Airlines', 'Thailand', 'N'),
#  ('3P', 'Tiara Air', 'Aruba', 'Y'),
#  ('TI', 'Tol-Air Services', 'United States', 'N'),
#  ('BY', 'Thomsonfly', 'United Kingdom', 'Y'),
#  ('PM', 'Tropic Air', 'Belize', 'Y'),
#  ('QT', 'TAMPA', 'Colombia', 'Y'),
#  ('GE', 'TransAsia Airways', 'Taiwan', 'Y'),
#  ('HV', 'Transavia Holland', 'Netherlands', 'Y'),
#  ('VR', 'TACV', 'Portugal', 'Y'),
#  ('T9', 'TransMeridian Airlines', 'United States', 'N'),
#  ('9T', 'Transwest Air', 'Canada', 'Y'),
#  ('UN', 'Transaero Airlines', 'Russia', 'Y'),
#  ('T5', 'Turkmenistan Airlines', 'Turkmenistan', 'Y'),
#  ('UG', 'Tuninter', 'Tunisia', 'Y'),
#  ('T6', 'Tavrey Airlines', 'Ukraine', 'N'),
#  ('TW', 'Trans World Airlines', 'United States', 'N'),
#  ('6B', 'TUIfly Nordic', 'Sweden', 'Y'),
#  ('DT', 'TAAG Angola Airlines', 'Angola', 'Y'),
#  ('SF', 'Tassili Airlines', 'Algeria', 'N'),
#  ('PZ', 'TAM Mercosur', 'Paraguay', 'Y'),
#  ('AX', 'Trans States Airlines', 'United States', 'Y'),
#  ('1E', 'Travelsky Technology', 'China', 'N'),
#  ('2H', 'Thalys', 'Belgium', 'N'),
#  ('1L', 'Open Skies Consultative Commission', 'United States', 'N'),
#  ('RO', 'Tarom', 'Romania', 'Y'),
#  ('3T', 'Turan Air', 'Azerbaijan', 'Y'),
#  ('8R', 'TRIP Linhas A', 'Brazil', 'Y'),
#  ('U5', 'USA3000 Airlines', 'United States', 'Y'),
#  ('UA', 'United Airlines', 'United States', 'Y'),
#  ('U6', 'Ural Airlines', 'Russia', 'Y'),
#  ('UF', 'UM Airlines', 'Ukraine', 'Y'),
#  ('6Z', 'Ukrainian Cargo Airways', 'Ukraine', 'N'),
#  ('5X', 'United Parcel Service', 'United States', 'N'),
#  ('US', 'US Airways', 'United States', 'Y'),
#  ('UT', 'UTair Aviation', 'Russia', 'Y'),
#  ('HY', 'Uzbekistan Airways', 'Uzbekistan', 'Y'),
#  ('UH', 'US Helicopter Corporation', 'United States', 'Y'),
#  ('VA', 'V Australia Airlines', 'Australia', 'N'),
#  ('VF', 'Valuair', 'Singapore', 'Y'),
#  ('VN', 'Vietnam Airlines', 'Vietnam', 'Y'),
#  ('NN', 'VIM Airlines', 'Russia', 'Y'),
#  ('2R', 'VIA Rail Canada', 'Canada', 'N'),
#  ('Y4', 'Volaris', 'Mexico', 'Y'),
#  ('VI', 'Volga-Dnepr Airlines', 'Russia', 'Y'),
#  ('VX', 'Virgin America', 'United States', 'Y'),
#  ('TV', 'Virgin Express', 'Belgium', 'Y'),
#  ('VK', 'Virgin Nigeria Airways', 'Nigeria', 'Y'),
#  ('VS', 'Virgin Atlantic Airways', 'United Kingdom', 'Y'),
#  ('ZG', 'Viva Macau', 'Macao', 'Y'),
#  ('XF', 'Vladivostok Air', 'Russia', 'Y'),
#  ('LC', 'Varig Log', 'Brazil', 'Y'),
#  ('VM', 'Viaggio Air', 'Bulgaria', 'N'),
#  ('RG', 'VRG Linhas Aereas', 'Brazil', 'Y'),
#  ('VP', 'VASP', 'Brazil', 'Y'),
#  ('VG', 'VLM Airlines', 'Belgium', 'Y'),
#  ('7W', 'Wayraper', 'Peru', 'Y'),
#  ('WJ', 'WebJet Linhas A', 'Brazil', 'Y'),
#  ('2W', 'Welcome Air', 'Austria', 'Y'),
#  ('8O', 'West Coast Air', 'Canada', 'Y'),
#  ('WS', 'WestJet', 'Canada', 'Y'),
#  ('WF', 'Widerøe', 'Norway', 'Y'),
#  ('IV', 'Wind Jet', 'Italy', 'Y'),
#  ('W6', 'Wizz Air', 'Hungary', 'Y'),
#  ('8Z', 'Wizz Air Hungary', 'Bulgaria', 'Y'),
#  ('WO', 'World Airways', 'United States', 'Y'),
#  ('1P', 'Worldspan', 'United States', 'N'),
#  ('SE', 'XL Airways France', 'France', 'Y'),
#  ('MF', 'Xiamen Airlines', 'China', 'Y'),
#  ('XP', 'Xtra Airways', 'United States', 'N'),
#  ('YL', 'Yamal Airlines', 'Russia', 'Y'),
#  ('Y8', 'Yangtze River Express', 'China', 'N'),
#  ('IY', 'Yemenia', 'Yemen', 'Y'),
#  ('Q3', 'Zambian Airways', 'Zambia', 'N'),
#  ('3J', 'Zip', 'Canada', 'N'),
#  ('C4', 'Zimex Aviation', 'Switzerland', 'N'),
#  ('Z4', 'Zoom Airlines', 'Canada', 'Y'),
#  ('\\N', 'Tyrolean Airways', '\\N', 'Y'),
#  ('UK', 'buzz', '\\N', 'N'),
#  ('XW', 'Sky Express', 'Russia', 'Y'),
#  ('Y0', 'Yellow Air Taxi', 'United States', 'N'),
#  ('6T', 'Air Mandalay', 'Burma', 'Y'),
#  ('TB', 'TUI Airlines Belgium', 'Belgium', 'N'),
#  ('BU', 'Braathens', 'Norway', 'N'),
#  ('GH', 'Globus', 'Russia', 'Y'),
#  ('9Y', 'Air Kazakhstan', 'Kazakhstan', 'Y'),
#  ('JD', 'Japan Air System', 'Japan', 'Y'),
#  ('ZQ', 'Annsett New Zealand (NZA)', 'New Zealand', 'N'),
#  ('DS', 'EasyJet (DS)', 'Switzerland', 'Y'),
#  ('2I', 'Star Peru (2I)', 'Peru', 'Y'),
#  ('KW', 'Carnival Air Lines', 'United States', 'Y'),
#  ('4H', 'United Airways', 'Bangladesh', 'Y'),
#  ('M8', 'Trans Maldivian Airways', 'Maldives', 'N'),
#  ('5H', 'Fly540', 'Kenya', 'Y'),
#  ('WP', 'Island Air (WP)', 'United States', 'Y'),
#  ('OG', '1-2-go', 'Thailand', 'N'),
#  ('B7', 'Uni Air', 'Taiwan', 'Y'),
#  ('YD', 'Gomelavia', 'Belarus', 'Y'),
#  ('WZ', 'Red Wings', 'Russia', 'Y'),
#  ('11', 'TUIfly (X3)', 'Germany', 'Y'),
#  ('FU', 'Felix Airways', 'Yemen', 'Y'),
#  ('K1', 'Kostromskie avialinii', 'Russia', 'Y'),
#  ('XX', 'Greenfly', 'Spain', 'Y'),
#  ('7J', 'Tajik Air', 'Tajikistan', 'Y'),
#  ('TM', 'Air Mozambique', 'Mozambique', 'Y'),
#  ('--', 'ELK Airways', 'Estonia', 'Y'),
#  ('VH', 'Virgin Pacific', 'Fiji', 'Y'),
#  ('Z2', 'Zest Air', 'Philippines', 'Y'),
#  ('3O', 'Air Arabia Maroc', 'Morocco', 'Y'),
#  ('B1', 'Baltic Air lines', 'Latvia', 'Y'),
#  ('YC', 'Ciel Canadien', 'Canada', 'Y'),
#  ('3I', 'Air Comet Chile', 'Chile', 'Y'),
#  ('-.', 'Nazca', 'Peru', 'N'),
#  ('DN', 'Voronezhskie Airlanes', 'Russia', 'N'),
#  ('IL', 'Illinois Airways', 'United States', 'N'),
#  ('SZ', 'Salzburg arrows', 'Austria', 'Y'),
#  ('KT', 'California Western', 'United States', 'N'),
#  ('ZZ', 'Zz', 'Belgium', 'Y'),
#  ('A1', 'Atifly', 'United States', 'Y'),
#  ('CB', 'Suckling Airways', 'United Kingdom', 'N'),
#  ('RY', 'Reno Sky', 'United States', 'N'),
#  ('99', 'Ciao Air', 'Italy', 'Y'),
#  ('VB', 'Birmingham European', 'United Kingdom', 'N'),
#  ('5P', 'Pal airlines', 'Chile', 'Y'),
#  ('C1', 'CanXpress', 'Canada', 'Y'),
#  ('C2', 'CanXplorer', 'Canada', 'Y'),
#  ('QA', 'Click (Mexicana)', 'Mexico', 'Y'),
#  ('W1', 'World Experience Airline', 'Canada', 'Y'),
#  ('3E', 'Air Choice One', 'United States', 'Y'),
#  ('KN', 'China United', 'China', 'Y'),
#  ('4Q', 'Safi Airlines', 'Afghanistan', 'Y'),
#  ('1', 'Bobb Air Freight', 'Germany', 'Y'),
#  ('6D', 'Pelita', 'Indonesia', 'Y'),
#  ('J5', 'Alaska Seaplane Service', 'United States', 'Y'),
#  ('T8', 'TAN', 'Argentina', 'N'),
#  ('T0', 'TACA Peru', 'Peru', 'Y'),
#  ('7Q', 'Pan Am World Airways Dominicana', 'Dominican Republic', 'Y'),
#  ('V6', 'VIP Ecuador', 'Ecuador', 'Y'),
#  ('ЯП', 'Polar Airlines', 'Russia', 'Y'),
#  ('OC', 'Catovair', 'Mauritius', 'Y'),
#  ('7Z', 'Halcyonair', 'Cape Verde', 'Y'),
#  ('4P', 'Business Aviation', 'Congo (Kinshasa)', 'Y'),
#  ('UJ', 'AlMasria Universal Airlines', 'Egypt', 'Y'),
#  ('6Y', 'SmartLynx Airlines', 'Latvia', 'Y'),
#  ('K7', 'KoralBlue Airlines', 'Egypt', 'Y'),
#  ('7Y', 'Med Airways', 'Lebanon', 'Y'),
#  ('RL', 'Royal Falcon', 'Jordan', 'Y'),
#  ('4L', 'Euroline', 'Georgia', 'Y'),
#  ('ZF', 'Athens Airways', 'Greece', 'Y'),
#  ('VQ', 'Viking Hellas', 'Greece', 'Y'),
#  ('DZ', 'Starline.kz', 'Kazakhstan', 'Y'),
#  ('OQ', 'Chongqing Airlines', 'China', 'Y'),
#  ('PN', 'West Air China', 'China', 'Y'),
#  ('Y7', 'NordStar Airlines', 'Russia', 'Y'),
#  ('9H', 'MDLR Airlines', 'India', 'Y'),
#  ('Q2', 'Maldivian', 'Maldives', 'Y'),
#  ('XN', 'Xpressair', 'Indonesia', 'Y'),
#  ('5E', 'SGA Airlines', 'Thailand', 'Y'),
#  ('F8', 'Air2there', 'New Zealand', 'Y'),
#  ('??', 'Court Line', 'United Kingdom', 'N'),
#  ('++', 'Lombards Air', 'South Africa', 'N'),
#  ('-+', 'U.S. Air', 'United States', 'Y'),
#  ("\\\\'", 'Jayrow', 'Australia', 'Y'),
#  ('::', 'Llloyd Helicopters', 'Australia', 'N'),
#  (';;', 'Wilderness Air', 'Australia', 'Y'),
#  ('^^', 'Whitaker Air', 'Australia', 'Y'),
#  ('WQ', 'PanAm World Airways', 'United States', 'Y'),
#  ('YY', 'Virginwings', 'Germany', 'Y'),
#  ('WU', 'Wizz Air Ukraine', 'Ukraine', 'Y'),
#  ('47', '88', 'Cyprus', 'Y'),
#  ('H3', 'THREE', 'China', 'N'),
#  ('69', 'Royal European Airlines', 'United Kingdom', 'Y'),
#  ('&T', "Tom\\\\'s & co airliners", 'France', 'Y'),
#  ('X1', 'Nik Airways', 'Saudi Arabia', 'N'),
#  ('XZ', 'Congo Express', 'Congo (Kinshasa)', 'Y'),
#  ('FZ', 'Fly Dubai', 'United Arab Emirates', 'Y'),
#  ('D1', 'Domenican Airlines', 'Dominican Republic', 'Y'),
#  ('9A', 'Air Atlantic', 'Canada', 'N'),
#  ('YZ', 'LSM AIRLINES ', 'Russia', 'Y'),
#  ('YP', 'Aero Lloyd (YP)', 'Germany', 'N'),
#  ('UR', 'UTair-Express', 'Russia', 'Y'),
#  ('G5', 'Huaxia', 'China', 'Y'),
#  ...]

# %%
# Works but with sa row
# test = []

# # for i in session.query(Airlines).all():
# for i in session.query(Airlines).all():    
#     test.append(i.__dict__)
# test

# Works but with sa row
# result_dict = [u.__dict__ for u in session.query(Airlines).all()]
# result_dict

# Works, but just for individual columns
# id_as_dict = [dict(row) for row in session.query(Airlines.airline_id).all()]
# name_as_dict = [dict(row) for row in session.query(Airlines.airline_name).all()]
# id_as_dict
# name_as_dict

# %%
# define function to convert ORM data into dicts using column headers as keys
def columns_to_dict(self):
    dict_ = {}
    for key in self.__mapper__.c.keys():
        dict_[key] = getattr(self, key)
    return dict_

# %%
# for row in session.query(Airlines).all():
#     print(columns_to_dict(row))

airlines_dict = [columns_to_dict(row) for row in session.query(Airlines).all()]
airlines_dict
# Out:
# [{'airline_name': '1Time Airline',
#   'airline_id': '1T',
#   'origin_country': 'South Africa',
#   'active': 'Y'},
#  {'airline_name': '40-Mile Air',
#   'airline_id': 'Q5',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Ansett Australia',
#   'airline_id': 'AN',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Abacus International',
#   'airline_id': '1B',
#   'origin_country': 'Singapore',
#   'active': 'Y'},
#  {'airline_name': 'Abelag Aviation',
#   'airline_id': 'W9',
#   'origin_country': 'Belgium',
#   'active': 'N'},
#  {'airline_name': 'Aigle Azur',
#   'airline_id': 'ZI',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Aloha Airlines',
#   'airline_id': 'AQ',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'American Airlines',
#   'airline_id': 'AA',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Asiana Airlines',
#   'airline_id': 'OZ',
#   'origin_country': 'Republic of Korea',
#   'active': 'Y'},
#  {'airline_name': 'Askari Aviation',
#   'airline_id': '4K',
#   'origin_country': 'Pakistan',
#   'active': 'Y'},
#  {'airline_name': 'Afriqiyah Airways',
#   'airline_id': '8U',
#   'origin_country': 'Libya',
#   'active': 'Y'},
#  {'airline_name': 'Afrinat International Airlines',
#   'airline_id': 'Q9',
#   'origin_country': 'Gambia',
#   'active': 'N'},
#  {'airline_name': 'Allegiant Air',
#   'airline_id': 'G4',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Aban Air',
#   'airline_id': 'K5',
#   'origin_country': 'Iran',
#   'active': 'n'},
#  {'airline_name': 'ABSA - Aerolinhas Brasileiras',
#   'airline_id': 'M3',
#   'origin_country': 'Brazil',
#   'active': 'Y'},
#  {'airline_name': 'Antrak Air',
#   'airline_id': '4',
#   'origin_country': 'Ghana',
#   'active': 'N'},
#  {'airline_name': 'Airborne Express',
#   'airline_id': 'GB',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Astral Aviation',
#   'airline_id': '8V',
#   'origin_country': 'Kenya',
#   'active': 'Y'},
#  {'airline_name': 'Aero Asia International',
#   'airline_id': 'E4',
#   'origin_country': 'Pakistan',
#   'active': 'N'},
#  {'airline_name': 'Air Togo',
#   'airline_id': 'YT',
#   'origin_country': 'Togo',
#   'active': 'N'},
#  {'airline_name': 'Advance Leasing Company',
#   'airline_id': '4G',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Aztec Worldwide Airlines',
#   'airline_id': '7A',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Air Tindi',
#   'airline_id': '8T',
#   'origin_country': 'Canadian Territories',
#   'active': 'Y'},
#  {'airline_name': 'Ada Air',
#   'airline_id': 'ZY',
#   'origin_country': 'Albania',
#   'active': 'Y'},
#  {'airline_name': 'ADC Airlines',
#   'airline_id': 'Z7',
#   'origin_country': 'Nigeria',
#   'active': 'N'},
#  {'airline_name': 'Adria Airways',
#   'airline_id': 'JP',
#   'origin_country': 'Slovenia',
#   'active': 'Y'},
#  {'airline_name': 'Air Europa',
#   'airline_id': 'UX',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Aero Benin',
#   'airline_id': 'EM',
#   'origin_country': 'Benin',
#   'active': 'Y'},
#  {'airline_name': 'Aegean Airlines',
#   'airline_id': 'A3',
#   'origin_country': 'Greece',
#   'active': 'Y'},
#  {'airline_name': 'Air Atlantique',
#   'airline_id': 'KI',
#   'origin_country': 'United Kingdom',
#   'active': 'N'},
#  {'airline_name': 'Air Europe',
#   'airline_id': 'PE',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Alaska Central Express',
#   'airline_id': 'KO',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Astraeus',
#   'airline_id': '5W',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Aerosvit Airlines',
#   'airline_id': 'VV',
#   'origin_country': 'Ukraine',
#   'active': 'Y'},
#  {'airline_name': 'Air Italy',
#   'airline_id': 'I9',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'American Falcon',
#   'airline_id': 'WK',
#   'origin_country': 'Argentina',
#   'active': 'N'},
#  {'airline_name': 'Alliance Airlines',
#   'airline_id': 'QQ',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Ariana Afghan Airlines',
#   'airline_id': 'FG',
#   'origin_country': 'Afghanistan',
#   'active': 'Y'},
#  {'airline_name': 'Aeroflot Russian Airlines',
#   'airline_id': 'SU',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Air Bosna',
#   'airline_id': 'JA',
#   'origin_country': 'Bosnia and Herzegovina',
#   'active': 'Y'},
#  {'airline_name': 'Air France',
#   'airline_id': 'AF',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Air Caledonie International',
#   'airline_id': 'SB',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Air Gabon',
#   'airline_id': 'GN',
#   'origin_country': 'Gabon',
#   'active': 'N'},
#  {'airline_name': 'Air Salone',
#   'airline_id': '2O',
#   'origin_country': 'Sierra Leone',
#   'active': 'Y'},
#  {'airline_name': 'Air Cargo Carriers',
#   'airline_id': '2Q',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Senegal International',
#   'airline_id': 'V7',
#   'origin_country': 'Senegal',
#   'active': 'N'},
#  {'airline_name': 'Air Namibia',
#   'airline_id': 'SW',
#   'origin_country': 'Namibia',
#   'active': 'Y'},
#  {'airline_name': 'Air Service Gabon',
#   'airline_id': 'G8',
#   'origin_country': 'Gabon',
#   'active': 'N'},
#  {'airline_name': 'Aerolitoral',
#   'airline_id': '5D',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'Amadeus Global Travel Distribution',
#   'airline_id': '1A',
#   'origin_country': 'Spain',
#   'active': 'N'},
#  {'airline_name': 'Air Glaciers',
#   'airline_id': '7T',
#   'origin_country': 'Switzerland',
#   'active': 'Y'},
#  {'airline_name': 'Aeroper',
#   'airline_id': 'PL',
#   'origin_country': 'Peru',
#   'active': 'Y'},
#  {'airline_name': 'Atlas Blue',
#   'airline_id': '8A',
#   'origin_country': 'Morocco',
#   'active': 'Y'},
#  {'airline_name': 'Air Alpha Greenland',
#   'airline_id': 'GD',
#   'origin_country': 'Denmark',
#   'active': 'N'},
#  {'airline_name': 'Air Hong Kong',
#   'airline_id': 'LD',
#   'origin_country': 'Hong Kong',
#   'active': 'N'},
#  {'airline_name': 'Aeromist-Kharkiv',
#   'airline_id': 'HT',
#   'origin_country': 'Ukraine',
#   'active': 'N'},
#  {'airline_name': 'Azerbaijan Airlines',
#   'airline_id': 'J2',
#   'origin_country': 'Azerbaijan',
#   'active': 'Y'},
#  {'airline_name': 'Avies',
#   'airline_id': 'U3',
#   'origin_country': 'Estonia',
#   'active': 'Y'},
#  {'airline_name': 'Airbus Industrie',
#   'airline_id': 'AP',
#   'origin_country': 'France',
#   'active': 'N'},
#  {'airline_name': 'Alpine Air Express',
#   'airline_id': '5A',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Airblue',
#   'airline_id': 'ED',
#   'origin_country': 'Pakistan',
#   'active': 'Y'},
#  {'airline_name': 'Air Berlin',
#   'airline_id': 'AB',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Air Contractors',
#   'airline_id': 'AG',
#   'origin_country': 'Ireland',
#   'active': 'N'},
#  {'airline_name': 'Air India Limited',
#   'airline_id': 'AI',
#   'origin_country': 'India',
#   'active': 'Y'},
#  {'airline_name': 'Air Bourbon',
#   'airline_id': 'ZB',
#   'origin_country': 'Reunion',
#   'active': 'Y'},
#  {'airline_name': 'Air Atlanta Icelandic',
#   'airline_id': 'CC',
#   'origin_country': 'Iceland',
#   'active': 'Y'},
#  {'airline_name': 'Air Srpska',
#   'airline_id': 'RB',
#   'origin_country': 'Bosnia and Herzegovina',
#   'active': 'N'},
#  {'airline_name': 'Air Tahiti Nui',
#   'airline_id': 'TN',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Aero Services Executive',
#   'airline_id': 'W4',
#   'origin_country': 'France',
#   'active': 'N'},
#  {'airline_name': 'Arkia Israel Airlines',
#   'airline_id': 'IZ',
#   'origin_country': 'Israel',
#   'active': 'Y'},
#  {'airline_name': 'Air Jamaica',
#   'airline_id': 'JM',
#   'origin_country': 'Jamaica',
#   'active': 'Y'},
#  {'airline_name': 'Air Sahara',
#   'airline_id': 'S2',
#   'origin_country': 'India',
#   'active': 'Y'},
#  {'airline_name': 'Air Malta',
#   'airline_id': 'KM',
#   'origin_country': 'Malta',
#   'active': 'Y'},
#  {'airline_name': 'Amerijet International',
#   'airline_id': 'M6',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Air Japan',
#   'airline_id': 'NQ',
#   'origin_country': 'Japan',
#   'active': 'Y'},
#  {'airline_name': 'Air Kiribati',
#   'airline_id': '4A',
#   'origin_country': 'Kiribati',
#   'active': 'Y'},
#  {'airline_name': 'Air Nippon Network Co. Ltd.',
#   'airline_id': 'EH',
#   'origin_country': 'Japan',
#   'active': 'N'},
#  {'airline_name': 'America West Airlines',
#   'airline_id': 'HP',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Wisconsin',
#   'airline_id': 'ZW',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Tatarstan Airlines',
#   'airline_id': 'U9',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Air Libert',
#   'airline_id': 'VD',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Air Lithuania',
#   'airline_id': 'TT',
#   'origin_country': 'Lithuania',
#   'active': 'N'},
#  {'airline_name': 'Air Malawi',
#   'airline_id': 'QM',
#   'origin_country': 'Malawi',
#   'active': 'Y'},
#  {'airline_name': 'Air Sicilia',
#   'airline_id': 'BM',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Air Macau',
#   'airline_id': 'NX',
#   'origin_country': 'Macao',
#   'active': 'Y'},
#  {'airline_name': 'Air Midwest',
#   'airline_id': 'ZV',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Air Seychelles',
#   'airline_id': 'HM',
#   'origin_country': 'Seychelles',
#   'active': 'Y'},
#  {'airline_name': 'AeroMéxico',
#   'airline_id': 'AM',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'All Nippon Airways',
#   'airline_id': 'NH',
#   'origin_country': 'Japan',
#   'active': 'Y'},
#  {'airline_name': 'Air Nostrum',
#   'airline_id': 'YW',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Air Niugini',
#   'airline_id': 'PX',
#   'origin_country': 'Papua New Guinea',
#   'active': 'Y'},
#  {'airline_name': 'Air Arabia',
#   'airline_id': 'G9',
#   'origin_country': 'United Arab Emirates',
#   'active': 'Y'},
#  {'airline_name': 'Air Canada',
#   'airline_id': 'AC',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Air Baltic',
#   'airline_id': 'BT',
#   'origin_country': 'Latvia',
#   'active': 'Y'},
#  {'airline_name': 'Air Nippon',
#   'airline_id': 'EL',
#   'origin_country': 'Japan',
#   'active': 'Y'},
#  {'airline_name': 'Airnorth',
#   'airline_id': 'TL',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Air North Charter - Canada',
#   'airline_id': '4N',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'AOM French Airlines',
#   'airline_id': 'IW',
#   'origin_country': 'France',
#   'active': 'N'},
#  {'airline_name': 'Air New Zealand',
#   'airline_id': 'NZ',
#   'origin_country': 'New Zealand',
#   'active': 'Y'},
#  {'airline_name': 'AVCOM',
#   'airline_id': 'J6',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Aero VIP',
#   'airline_id': '2D',
#   'origin_country': 'Argentina',
#   'active': 'N'},
#  {'airline_name': 'Air Vegas',
#   'airline_id': '6V',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Alitalia Express',
#   'airline_id': 'XM',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Asia Overnight Express',
#   'airline_id': 'OE',
#   'origin_country': 'Philippines',
#   'active': 'N'},
#  {'airline_name': 'Aero Flight',
#   'airline_id': 'GV',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Arrow Air',
#   'airline_id': 'JW',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Arik Air',
#   'airline_id': 'W3',
#   'origin_country': 'Nigeria',
#   'active': 'N'},
#  {'airline_name': 'Aerocondor',
#   'airline_id': '2B',
#   'origin_country': 'Portugal',
#   'active': 'Y'},
#  {'airline_name': 'Aires',
#   'airline_id': '4C',
#   'origin_country': ' S.A.',
#   'active': 'Y'},
#  {'airline_name': 'Aerolineas Argentinas',
#   'airline_id': 'AR',
#   'origin_country': 'Argentina',
#   'active': 'Y'},
#  {'airline_name': 'Air Armenia',
#   'airline_id': 'QN',
#   'origin_country': 'Armenia',
#   'active': 'N'},
#  {'airline_name': 'Alaska Airlines',
#   'airline_id': 'AS',
#   'origin_country': 'ALASKA',
#   'active': 'Y'},
#  {'airline_name': 'Air Sinai',
#   'airline_id': '4D',
#   'origin_country': 'Egypt',
#   'active': 'Y'},
#  {'airline_name': 'Atlantic Southeast Airlines',
#   'airline_id': 'EV',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Astrakhan Airlines',
#   'airline_id': 'OB',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Air Tanzania',
#   'airline_id': 'TC',
#   'origin_country': 'Tanzania',
#   'active': 'Y'},
#  {'airline_name': 'Air Burkina',
#   'airline_id': '2J',
#   'origin_country': 'Burkina Faso',
#   'active': 'Y'},
#  {'airline_name': 'Aero-Tropics Air Services',
#   'airline_id': 'HC',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Airlines Of Tasmania',
#   'airline_id': 'FO',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Air Saint Pierre',
#   'airline_id': 'PJ',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Air Transport International',
#   'airline_id': '8C',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Austrian Airlines',
#   'airline_id': 'OS',
#   'origin_country': 'Austria',
#   'active': 'Y'},
#  {'airline_name': 'Augsburg Airways',
#   'airline_id': 'IQ',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'AirBridge Cargo',
#   'airline_id': 'RU',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Abu Dhabi Amiri Flight',
#   'airline_id': 'MO',
#   'origin_country': 'United Arab Emirates',
#   'active': 'Y'},
#  {'airline_name': 'Aeroflot-Nord',
#   'airline_id': '5N',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Aurigny Air Services',
#   'airline_id': 'GR',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Aus-Air',
#   'airline_id': 'NO',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Austral Lineas Aereas',
#   'airline_id': 'AU',
#   'origin_country': 'Argentina',
#   'active': 'Y'},
#  {'airline_name': 'Australian Airlines',
#   'airline_id': 'AO',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Avianca - Aerovias Nacionales de Colombia',
#   'airline_id': 'AV',
#   'origin_country': 'AVIANCA',
#   'active': 'Y'},
#  {'airline_name': 'Air Vanuatu',
#   'airline_id': 'NF',
#   'origin_country': 'Vanuatu',
#   'active': 'Y'},
#  {'airline_name': 'Airlink Zambia',
#   'airline_id': 'K8',
#   'origin_country': 'Zambia',
#   'active': 'N'},
#  {'airline_name': 'Air Bangladesh',
#   'airline_id': 'B9',
#   'origin_country': 'Bangladesh',
#   'active': 'Y'},
#  {'airline_name': 'Air Mediterranee',
#   'airline_id': 'DR',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Aeroline GmbH',
#   'airline_id': '7E',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Air Wales',
#   'airline_id': '6G',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Air Caraïbes',
#   'airline_id': 'TX',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Air India Express',
#   'airline_id': 'IX',
#   'origin_country': 'India',
#   'active': 'Y'},
#  {'airline_name': 'Asian Express Airlines',
#   'airline_id': 'HJ',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Air Exel',
#   'airline_id': 'XT',
#   'origin_country': 'Netherlands',
#   'active': 'Y'},
#  {'airline_name': 'AirAsia',
#   'airline_id': 'AK',
#   'origin_country': 'Malaysia',
#   'active': 'Y'},
#  {'airline_name': 'Atlant-Soyuz Airlines',
#   'airline_id': '3G',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Alitalia',
#   'airline_id': 'AZ',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Arcus-Air Logistic',
#   'airline_id': 'ZE',
#   'origin_country': 'Germany',
#   'active': 'N'},
#  {'airline_name': 'Amaszonas',
#   'airline_id': 'Z8',
#   'origin_country': 'Bolivia',
#   'active': 'Y'},
#  {'airline_name': 'Air Zimbabwe',
#   'airline_id': 'UM',
#   'origin_country': 'Zimbabwe',
#   'active': 'Y'},
#  {'airline_name': 'Aserca Airlines',
#   'airline_id': 'R7',
#   'origin_country': 'Venezuela',
#   'active': 'Y'},
#  {'airline_name': 'Rossiya-Russian Airlines',
#   'airline_id': 'FV',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Aviaexpress',
#   'airline_id': 'RX',
#   'origin_country': 'Hungary',
#   'active': 'N'},
#  {'airline_name': 'American Eagle Airlines',
#   'airline_id': 'MQ',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Airshop',
#   'airline_id': 'FF',
#   'origin_country': 'Netherlands',
#   'active': 'N'},
#  {'airline_name': 'African Transport Trading and Investment Company',
#   'airline_id': 'ML',
#   'origin_country': 'Sudan',
#   'active': 'N'},
#  {'airline_name': 'Air Ivoire',
#   'airline_id': 'VU',
#   'origin_country': 'Ivory Coast',
#   'active': 'Y'},
#  {'airline_name': 'Air Botswana',
#   'airline_id': 'BP',
#   'origin_country': 'Botswana',
#   'active': 'Y'},
#  {'airline_name': 'Air Foyle',
#   'airline_id': 'GS',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Air Tahiti',
#   'airline_id': 'VT',
#   'origin_country': 'French Polynesia',
#   'active': 'Y'},
#  {'airline_name': 'Air Urga',
#   'airline_id': '3N',
#   'origin_country': 'Ukraine',
#   'active': 'N'},
#  {'airline_name': 'Air VIA',
#   'airline_id': 'VL',
#   'origin_country': 'Bulgaria',
#   'active': 'Y'},
#  {'airline_name': 'Africa West',
#   'airline_id': 'FK',
#   'origin_country': 'Togo',
#   'active': 'Y'},
#  {'airline_name': 'Avirex',
#   'airline_id': 'G2',
#   'origin_country': 'Gabon',
#   'active': 'N'},
#  {'airline_name': 'ATRAN Cargo Airlines',
#   'airline_id': 'V8',
#   'origin_country': 'Russian Federation',
#   'active': 'Y'},
#  {'airline_name': 'Avensa',
#   'airline_id': 'VE',
#   'origin_country': 'Venezuela',
#   'active': 'N'},
#  {'airline_name': 'Avolar Aerolineas',
#   'airline_id': 'V5',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Air China',
#   'airline_id': 'CA',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'Aero Condor Peru',
#   'airline_id': 'Q6',
#   'origin_country': 'Peru',
#   'active': 'Y'},
#  {'airline_name': 'Arctic Circle Air Service',
#   'airline_id': '5F',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Air Corridor',
#   'airline_id': 'QC',
#   'origin_country': 'Mozambique',
#   'active': 'N'},
#  {'airline_name': 'Air Central',
#   'airline_id': 'NV',
#   'origin_country': 'Japan',
#   'active': 'N'},
#  {'airline_name': 'Air Chathams',
#   'airline_id': 'CV',
#   'origin_country': 'New Zealand',
#   'active': 'Y'},
#  {'airline_name': 'Air Marshall Islands',
#   'airline_id': 'CW',
#   'origin_country': 'Marshall Islands',
#   'active': 'Y'},
#  {'airline_name': 'Access Air',
#   'airline_id': 'ZA',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Algerie',
#   'airline_id': 'AH',
#   'origin_country': 'Algeria',
#   'active': 'Y'},
#  {'airline_name': 'Astar Air Cargo',
#   'airline_id': 'ER',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Antinea Airlines',
#   'airline_id': 'HO',
#   'origin_country': 'Algeria',
#   'active': 'N'},
#  {'airline_name': 'Air Dolomiti',
#   'airline_id': 'EN',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Aeroflot-Don',
#   'airline_id': 'D9',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Air Madrid',
#   'airline_id': 'NM',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Aero Airlines',
#   'airline_id': 'EE',
#   'origin_country': 'Estonia',
#   'active': 'N'},
#  {'airline_name': 'Air City',
#   'airline_id': '4F',
#   'origin_country': 'Germany',
#   'active': 'N'},
#  {'airline_name': 'Aer Lingus',
#   'airline_id': 'EI',
#   'origin_country': 'Ireland',
#   'active': 'Y'},
#  {'airline_name': 'Alpi Eagles',
#   'airline_id': 'E8',
#   'origin_country': 'Italy',
#   'active': 'N'},
#  {'airline_name': 'Air S',
#   'airline_id': 'KY',
#   'origin_country': 'Air S',
#   'active': 'N'},
#  {'airline_name': 'Air Fiji',
#   'airline_id': 'PC',
#   'origin_country': 'Fiji',
#   'active': 'N'},
#  {'airline_name': 'Air Finland',
#   'airline_id': 'OF',
#   'origin_country': 'Finland',
#   'active': 'Y'},
#  {'airline_name': 'Air Pacific',
#   'airline_id': 'FJ',
#   'origin_country': 'Fiji',
#   'active': 'Y'},
#  {'airline_name': 'Atlantic Airways',
#   'airline_id': 'RC',
#   'origin_country': 'Faroe Islands',
#   'active': 'Y'},
#  {'airline_name': 'Air Florida',
#   'airline_id': 'QH',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Iceland',
#   'airline_id': 'NY',
#   'origin_country': 'Iceland',
#   'active': 'Y'},
#  {'airline_name': 'Air Philippines',
#   'airline_id': '2P',
#   'origin_country': 'Philippines',
#   'active': 'Y'},
#  {'airline_name': 'Air Georgian',
#   'airline_id': 'ZX',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Air Guinee Express',
#   'airline_id': '2U',
#   'origin_country': 'Guinea',
#   'active': 'Y'},
#  {'airline_name': 'Amber Air',
#   'airline_id': '0A',
#   'origin_country': 'Lithuania',
#   'active': 'N'},
#  {'airline_name': 'Air Georgia',
#   'airline_id': 'DA',
#   'origin_country': 'Georgia',
#   'active': 'N'},
#  {'airline_name': 'Air Greenland',
#   'airline_id': 'GL',
#   'origin_country': 'Denmark',
#   'active': 'Y'},
#  {'airline_name': 'Allegro',
#   'airline_id': 'LL',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Atlas Air',
#   'airline_id': '5Y',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Guyane',
#   'airline_id': 'GG',
#   'origin_country': 'French Guiana',
#   'active': 'Y'},
#  {'airline_name': "Air D'Ayiti",
#   'airline_id': 'H9',
#   'origin_country': 'Haiti',
#   'active': 'N'},
#  {'airline_name': 'Atyrau Air Ways',
#   'airline_id': 'IP',
#   'origin_country': 'Kazakhstan',
#   'active': 'N'},
#  {'airline_name': 'Air Canada Jazz',
#   'airline_id': 'QK',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Atlasjet',
#   'airline_id': 'KK',
#   'origin_country': 'Turkey',
#   'active': 'Y'},
#  {'airline_name': 'Air Koryo',
#   'airline_id': 'JS',
#   'origin_country': "Democratic People's Republic of Korea",
#   'active': 'Y'},
#  {'airline_name': 'Air Astana',
#   'airline_id': 'KC',
#   'origin_country': 'Kazakhstan',
#   'active': 'Y'},
#  {'airline_name': 'Albanian Airlines',
#   'airline_id': 'LV',
#   'origin_country': 'Albania',
#   'active': 'Y'},
#  {'airline_name': 'Alidaunia',
#   'airline_id': 'D4',
#   'origin_country': 'Italy',
#   'active': 'N'},
#  {'airline_name': 'Alliance Air',
#   'airline_id': 'CD',
#   'origin_country': 'India',
#   'active': 'N'},
#  {'airline_name': 'Aerolane',
#   'airline_id': 'XL',
#   'origin_country': 'Ecuador',
#   'active': 'Y'},
#  {'airline_name': 'Air Alps Aviation',
#   'airline_id': 'A6',
#   'origin_country': 'Austria',
#   'active': 'N'},
#  {'airline_name': 'Atlantis European Airways',
#   'airline_id': 'TD',
#   'origin_country': 'Armenia',
#   'active': 'Y'},
#  {'airline_name': 'Air Luxor GB',
#   'airline_id': 'L8',
#   'origin_country': 'Guinea-Bissau',
#   'active': 'N'},
#  {'airline_name': 'Air Luxor',
#   'airline_id': 'LK',
#   'origin_country': 'Portugal',
#   'active': 'Y'},
#  {'airline_name': 'Air Mauritius',
#   'airline_id': 'MK',
#   'origin_country': 'Mauritius',
#   'active': 'Y'},
#  {'airline_name': 'Air Madagascar',
#   'airline_id': 'MD',
#   'origin_country': 'Madagascar',
#   'active': 'Y'},
#  {'airline_name': 'Air Moldova',
#   'airline_id': '9U',
#   'origin_country': 'Moldova',
#   'active': 'Y'},
#  {'airline_name': 'Aero Mongolia',
#   'airline_id': 'M0',
#   'origin_country': 'Mongolia',
#   'active': 'N'},
#  {'airline_name': 'Air Plus Comet',
#   'airline_id': 'A7',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Aeromexpress',
#   'airline_id': 'QO',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Air Mauritanie',
#   'airline_id': 'MR',
#   'origin_country': 'Mauritania',
#   'active': 'N'},
#  {'airline_name': 'Aeroland Airways',
#   'airline_id': '3S',
#   'origin_country': 'Greece',
#   'active': 'N'},
#  {'airline_name': 'Astair',
#   'airline_id': '8D',
#   'origin_country': 'Russian Federation',
#   'active': 'Y'},
#  {'airline_name': 'Albarka Air',
#   'airline_id': 'F4',
#   'origin_country': 'Nigeria',
#   'active': 'N'},
#  {'airline_name': 'Aero Contractors',
#   'airline_id': 'AJ',
#   'origin_country': 'Nigeria',
#   'active': 'Y'},
#  {'airline_name': 'Air Burundi',
#   'airline_id': '8Y',
#   'origin_country': 'Burundi',
#   'active': 'N'},
#  {'airline_name': 'Aeropelican Air Services',
#   'airline_id': 'OT',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Air Paradise International',
#   'airline_id': 'AD',
#   'origin_country': 'Indonesia',
#   'active': 'N'},
#  {'airline_name': 'Air Class Lineas Aereas',
#   'airline_id': 'QD',
#   'origin_country': 'Uruguay',
#   'active': 'N'},
#  {'airline_name': 'African Safari Airways',
#   'airline_id': 'QS',
#   'origin_country': 'Kenya',
#   'active': 'N'},
#  {'airline_name': 'Airbus France',
#   'airline_id': '4Y',
#   'origin_country': 'France',
#   'active': 'N'},
#  {'airline_name': 'Air Mobility Command',
#   'airline_id': 'MC',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Aer Arann',
#   'airline_id': 'RE',
#   'origin_country': 'Ireland',
#   'active': 'Y'},
#  {'airline_name': 'Air Austral',
#   'airline_id': 'UU',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Asian Spirit',
#   'airline_id': '6K',
#   'origin_country': 'Philippines',
#   'active': 'Y'},
#  {'airline_name': 'Air Afrique',
#   'airline_id': 'RK',
#   'origin_country': 'Ivory Coast',
#   'active': 'Y'},
#  {'airline_name': 'Airlinair',
#   'airline_id': 'A5',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Aero Lanka',
#   'airline_id': 'QL',
#   'origin_country': 'Sri Lanka',
#   'active': 'Y'},
#  {'airline_name': 'Armenian International Airways',
#   'airline_id': 'MV',
#   'origin_country': 'Armenia',
#   'active': 'N'},
#  {'airline_name': 'Air Salone',
#   'airline_id': '20',
#   'origin_country': 'Sierra Leone',
#   'active': 'Y'},
#  {'airline_name': 'Armavia',
#   'airline_id': 'U8',
#   'origin_country': 'Armenia',
#   'active': 'Y'},
#  {'airline_name': 'Aeromar',
#   'airline_id': 'BQ',
#   'origin_country': 'Dominican Republic',
#   'active': 'N'},
#  {'airline_name': 'AeroRep',
#   'airline_id': 'P5',
#   'origin_country': 'Colombia',
#   'active': 'Y'},
#  {'airline_name': 'Aero-Service',
#   'airline_id': 'BF',
#   'origin_country': 'Republic of the Congo',
#   'active': 'Y'},
#  {'airline_name': 'Aerosur',
#   'airline_id': '5L',
#   'origin_country': 'Bolivia',
#   'active': 'Y'},
#  {'airline_name': 'Air Santo Domingo',
#   'airline_id': 'EX',
#   'origin_country': 'Dominican Republic',
#   'active': 'N'},
#  {'airline_name': 'Aero California',
#   'airline_id': 'JR',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Avient Aviation',
#   'airline_id': 'Z3',
#   'origin_country': 'Zimbabwe',
#   'active': 'Y'},
#  {'airline_name': 'Air Slovakia',
#   'airline_id': 'GM',
#   'origin_country': 'Slovakia',
#   'active': 'N'},
#  {'airline_name': 'Aircompany Yakutia',
#   'airline_id': 'R3',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Aeromar',
#   'airline_id': 'VW',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'Air Turks and Caicos',
#   'airline_id': 'JY',
#   'origin_country': 'Turks and Caicos Islands',
#   'active': 'N'},
#  {'airline_name': 'Arkefly',
#   'airline_id': 'OR',
#   'origin_country': 'Netherlands',
#   'active': 'Y'},
#  {'airline_name': 'Airlines PNG',
#   'airline_id': 'CG',
#   'origin_country': 'Papua New Guinea',
#   'active': 'Y'},
#  {'airline_name': 'Air Cal',
#   'airline_id': 'TY',
#   'origin_country': 'France',
#   'active': 'N'},
#  {'airline_name': 'AirTran Airways',
#   'airline_id': 'FL',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Air Transat',
#   'airline_id': 'TS',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Avialeasing Aviation Company',
#   'airline_id': 'EC',
#   'origin_country': 'Uzbekistan',
#   'active': 'Y'},
#  {'airline_name': 'Tyrolean Airways',
#   'airline_id': 'VO',
#   'origin_country': 'Austria',
#   'active': 'Y'},
#  {'airline_name': 'Aero-Charter Ukraine',
#   'airline_id': 'DW',
#   'origin_country': 'Ukraine',
#   'active': 'N'},
#  {'airline_name': 'Air Ukraine',
#   'airline_id': '6U',
#   'origin_country': 'Ukraine',
#   'active': 'N'},
#  {'airline_name': 'Aerolineas Galapagos (Aerogal)',
#   'airline_id': '2K',
#   'origin_country': 'Ecuador',
#   'active': 'Y'},
#  {'airline_name': 'Alrosa Mirny Air Enterprise',
#   'airline_id': '6R',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Baker Aviation',
#   'airline_id': '8Q',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'British Airways',
#   'airline_id': 'BA',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Biman Bangladesh Airlines',
#   'airline_id': 'BG',
#   'origin_country': 'Bangladesh',
#   'active': 'Y'},
#  {'airline_name': 'BACH Flugbetriebsges',
#   'airline_id': 'B4',
#   'origin_country': 'Austria',
#   'active': 'N'},
#  {'airline_name': 'Blue Dart Aviation',
#   'airline_id': 'BZ',
#   'origin_country': 'India',
#   'active': 'N'},
#  {'airline_name': 'Buffalo Airways',
#   'airline_id': 'J4',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Benin Golf Air',
#   'airline_id': 'A8',
#   'origin_country': 'Benin',
#   'active': 'N'},
#  {'airline_name': 'Belair Airlines',
#   'airline_id': '4T',
#   'origin_country': 'Switzerland',
#   'active': 'Y'},
#  {'airline_name': 'Bahamasair',
#   'airline_id': 'UP',
#   'origin_country': 'Bahamas',
#   'active': 'Y'},
#  {'airline_name': 'Bringer Air Cargo Taxi Aereo',
#   'airline_id': 'E6',
#   'origin_country': 'Brazil',
#   'active': 'N'},
#  {'airline_name': 'BA Connect',
#   'airline_id': 'TH',
#   'origin_country': 'United Kingdom',
#   'active': 'N'},
#  {'airline_name': 'British International Helicopters',
#   'airline_id': 'BS',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Bangkok Airways',
#   'airline_id': 'PG',
#   'origin_country': 'Thailand',
#   'active': 'Y'},
#  {'airline_name': 'Blue1',
#   'airline_id': 'KF',
#   'origin_country': 'Finland',
#   'active': 'Y'},
#  {'airline_name': 'Bearskin Lake Air Service',
#   'airline_id': 'JV',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Bellview Airlines',
#   'airline_id': 'B3',
#   'origin_country': 'Nigeria',
#   'active': 'Y'},
#  {'airline_name': 'bmi',
#   'airline_id': 'BD',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'bmibaby',
#   'airline_id': 'WW',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Bemidji Airlines',
#   'airline_id': 'CH',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Bismillah Airlines',
#   'airline_id': '5Z',
#   'origin_country': 'Bangladesh',
#   'active': 'N'},
#  {'airline_name': 'Bouraq Indonesia Airlines',
#   'airline_id': 'BO',
#   'origin_country': 'Indonesia',
#   'active': 'N'},
#  {'airline_name': 'Blue Panorama Airlines',
#   'airline_id': 'BV',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'BRA-Transportes Aereos',
#   'airline_id': '7R',
#   'origin_country': 'Brazil',
#   'active': 'N'},
#  {'airline_name': 'Bering Air',
#   'airline_id': '8E',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Belavia Belarusian Airlines',
#   'airline_id': 'B2',
#   'origin_country': 'Belarus',
#   'active': 'Y'},
#  {'airline_name': 'Bravo Air Congo',
#   'airline_id': 'K6',
#   'origin_country': 'Democratic Republic of the Congo',
#   'active': 'N'},
#  {'airline_name': 'Braniff International Airways',
#   'airline_id': 'BN',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Big Sky Airlines',
#   'airline_id': 'GQ',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'BAL Bashkirian Airlines',
#   'airline_id': 'V9',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Metro Batavia',
#   'airline_id': '7P',
#   'origin_country': 'Indonesia',
#   'active': 'Y'},
#  {'airline_name': 'Berjaya Air',
#   'airline_id': 'J8',
#   'origin_country': 'Malaysia',
#   'active': 'Y'},
#  {'airline_name': 'Blue Wings',
#   'airline_id': 'QW',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Brit Air',
#   'airline_id': 'DB',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Boston-Maine Airways',
#   'airline_id': 'E9',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Brussels Airlines',
#   'airline_id': 'SN',
#   'origin_country': 'Belgium',
#   'active': 'Y'},
#  {'airline_name': 'Binter Canarias',
#   'airline_id': 'NT',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Blue Air',
#   'airline_id': '0B',
#   'origin_country': 'Romania',
#   'active': 'Y'},
#  {'airline_name': 'British Mediterranean Airways',
#   'airline_id': 'KJ',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Bulgaria Air',
#   'airline_id': 'FB',
#   'origin_country': 'Bulgaria',
#   'active': 'Y'},
#  {'airline_name': 'Barents AirLink',
#   'airline_id': '8N',
#   'origin_country': 'Sweden',
#   'active': 'Y'},
#  {'airline_name': 'CAL Cargo Air Lines',
#   'airline_id': '5C',
#   'origin_country': 'Israel',
#   'active': 'Y'},
#  {'airline_name': 'CHC Airways',
#   'airline_id': 'AW',
#   'origin_country': 'Netherlands',
#   'active': 'N'},
#  {'airline_name': 'Calima Aviacion',
#   'airline_id': 'XG',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Camai Air',
#   'airline_id': 'R9',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Cameroon Airlines',
#   'airline_id': 'UY',
#   'origin_country': 'Cameroon',
#   'active': 'N'},
#  {'airline_name': 'CanJet',
#   'airline_id': 'C6',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Canadian Airlines',
#   'airline_id': 'CP',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Canadian North',
#   'airline_id': '5T',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Canadian Western Airlines',
#   'airline_id': 'W2',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Cape Air',
#   'airline_id': '9K',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Capital Cargo International Airlines',
#   'airline_id': 'PT',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Cargoitalia',
#   'airline_id': '2G',
#   'origin_country': 'Italy',
#   'active': 'N'},
#  {'airline_name': 'Cargojet Airways',
#   'airline_id': 'W8',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Caribbean Airlines',
#   'airline_id': 'BW',
#   'origin_country': 'Trinidad and Tobago',
#   'active': 'Y'},
#  {'airline_name': 'Caribbean Star Airlines',
#   'airline_id': '8B',
#   'origin_country': 'Antigua and Barbuda',
#   'active': 'N'},
#  {'airline_name': 'Carpatair',
#   'airline_id': 'V3',
#   'origin_country': 'Romania',
#   'active': 'Y'},
#  {'airline_name': 'Caspian Airlines',
#   'airline_id': 'RV',
#   'origin_country': 'Iran',
#   'active': 'Y'},
#  {'airline_name': 'Cathay Pacific',
#   'airline_id': 'CX',
#   'origin_country': 'Hong Kong SAR of China',
#   'active': 'Y'},
#  {'airline_name': 'Cayman Airways',
#   'airline_id': 'KX',
#   'origin_country': 'Cayman Islands',
#   'active': 'Y'},
#  {'airline_name': 'Cebu Pacific',
#   'airline_id': '5J',
#   'origin_country': 'Philippines',
#   'active': 'Y'},
#  {'airline_name': 'Centavia',
#   'airline_id': '7N',
#   'origin_country': 'Serbia',
#   'active': 'N'},
#  {'airline_name': 'Centralwings',
#   'airline_id': 'C0',
#   'origin_country': 'Poland',
#   'active': 'Y'},
#  {'airline_name': 'Centre-Avia',
#   'airline_id': 'J7',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Centurion Air Cargo',
#   'airline_id': 'WE',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': "Chalk's Ocean Airways",
#   'airline_id': 'OP',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Champion Air',
#   'airline_id': 'MG',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Changan Airlines',
#   'airline_id': '2Z',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'Chari Aviation Services',
#   'airline_id': 'S8',
#   'origin_country': 'Chad',
#   'active': 'N'},
#  {'airline_name': 'Chautauqua Airlines',
#   'airline_id': 'RP',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Chicago Express',
#   'airline_id': 'C8',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'China Airlines',
#   'airline_id': 'CI',
#   'origin_country': 'Taiwan',
#   'active': 'Y'},
#  {'airline_name': 'China Cargo Airlines',
#   'airline_id': 'CK',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'China Eastern Airlines',
#   'airline_id': 'MU',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'China Northern Airlines',
#   'airline_id': 'CJ',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'China Northwest Airlines',
#   'airline_id': 'WH',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'China Southern Airlines',
#   'airline_id': 'CZ',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'China United Airlines',
#   'airline_id': 'HR',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'China Xinhua Airlines',
#   'airline_id': 'XO',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'Yunnan Airlines',
#   'airline_id': '3Q',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'Chitaavia',
#   'airline_id': 'X7',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Cielos Airlines',
#   'airline_id': 'A2',
#   'origin_country': 'Peru',
#   'active': 'N'},
#  {'airline_name': 'Cimber Air',
#   'airline_id': 'QI',
#   'origin_country': 'Denmark',
#   'active': 'Y'},
#  {'airline_name': 'Cirrus Airlines',
#   'airline_id': 'C9',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'City Airline',
#   'airline_id': 'CF',
#   'origin_country': 'Sweden',
#   'active': 'Y'},
#  {'airline_name': 'City Connexion Airlines',
#   'airline_id': 'G3',
#   'origin_country': 'Burundi',
#   'active': 'Y'},
#  {'airline_name': 'CityJet',
#   'airline_id': 'WX',
#   'origin_country': 'Ireland',
#   'active': 'Y'},
#  {'airline_name': 'Civil Air Transport',
#   'airline_id': 'CT',
#   'origin_country': 'Taiwan',
#   'active': 'N'},
#  {'airline_name': 'Club Air',
#   'airline_id': '6P',
#   'origin_country': 'Italy',
#   'active': 'N'},
#  {'airline_name': 'Coast Air',
#   'airline_id': 'BX',
#   'origin_country': 'Norway',
#   'active': 'N'},
#  {'airline_name': 'Coastal Air',
#   'airline_id': 'DQ',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Colgan Air',
#   'airline_id': '9L',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Comair',
#   'airline_id': 'OH',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Comair',
#   'airline_id': 'MN',
#   'origin_country': 'South Africa',
#   'active': 'Y'},
#  {'airline_name': 'CommutAir',
#   'airline_id': 'C5',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Comores Airlines',
#   'airline_id': 'KR',
#   'origin_country': 'Comoros',
#   'active': 'Y'},
#  {'airline_name': 'Compania Mexicargo',
#   'airline_id': 'GJ',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Condor Flugdienst',
#   'airline_id': 'DE',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Consorcio Aviaxsa',
#   'airline_id': '6A',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'Contact Air',
#   'airline_id': 'C3',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Continental Airlines',
#   'airline_id': 'CO',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Continental Micronesia',
#   'airline_id': 'CS',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Conviasa',
#   'airline_id': 'V0',
#   'origin_country': 'Venezuela',
#   'active': 'Y'},
#  {'airline_name': 'Copa Airlines',
#   'airline_id': 'CM',
#   'origin_country': 'Panama',
#   'active': 'Y'},
#  {'airline_name': 'Corsairfly',
#   'airline_id': 'SS',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Corse-Mediterranee',
#   'airline_id': 'XK',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Cosmic Air',
#   'airline_id': 'F5',
#   'origin_country': 'Nepal',
#   'active': 'N'},
#  {'airline_name': 'Croatia Airlines',
#   'airline_id': 'OU',
#   'origin_country': 'Croatia',
#   'active': 'Y'},
#  {'airline_name': 'Crossair Europe',
#   'airline_id': 'QE',
#   'origin_country': 'Switzerland',
#   'active': 'N'},
#  {'airline_name': 'Cubana de Aviación',
#   'airline_id': 'CU',
#   'origin_country': 'Cuba',
#   'active': 'Y'},
#  {'airline_name': 'Cyprus Airways',
#   'airline_id': 'CY',
#   'origin_country': 'Cyprus',
#   'active': 'Y'},
#  {'airline_name': 'Cyprus Turkish Airlines',
#   'airline_id': 'YK',
#   'origin_country': 'Turkey',
#   'active': 'Y'},
#  {'airline_name': 'Czech Airlines',
#   'airline_id': 'OK',
#   'origin_country': 'Czech Republic',
#   'active': 'Y'},
#  {'airline_name': 'DAS Air Cargo',
#   'airline_id': 'WD',
#   'origin_country': 'Uganda',
#   'active': 'N'},
#  {'airline_name': 'DAT Danish Air Transport',
#   'airline_id': 'DX',
#   'origin_country': 'Denmark',
#   'active': 'Y'},
#  {'airline_name': 'DHL International',
#   'airline_id': 'ES',
#   'origin_country': 'Bahrain',
#   'active': 'N'},
#  {'airline_name': 'DHL de Guatemala',
#   'airline_id': 'L3',
#   'origin_country': 'Guatemala',
#   'active': 'N'},
#  {'airline_name': 'Daallo Airlines',
#   'airline_id': 'D3',
#   'origin_country': 'Djibouti',
#   'active': 'Y'},
#  {'airline_name': 'Dagestan Airlines',
#   'airline_id': 'N2',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Dalavia',
#   'airline_id': 'H8',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Darwin Airline',
#   'airline_id': '0D',
#   'origin_country': 'Switzerland',
#   'active': 'Y'},
#  {'airline_name': 'Dauair',
#   'airline_id': 'D5',
#   'origin_country': 'Germany',
#   'active': 'N'},
#  {'airline_name': 'Delta Air Lines',
#   'airline_id': 'DL',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Deutsche Bahn',
#   'airline_id': '2A',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Deutsche Rettungsflugwacht',
#   'airline_id': '1I',
#   'origin_country': 'Germany',
#   'active': 'N'},
#  {'airline_name': 'Dinar',
#   'airline_id': 'D7',
#   'origin_country': 'Argentina',
#   'active': 'N'},
#  {'airline_name': 'Discovery Airways',
#   'airline_id': 'DH',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Djibouti Airlines',
#   'airline_id': 'D8',
#   'origin_country': 'Djibouti',
#   'active': 'Y'},
#  {'airline_name': 'Dominicana de Aviaci',
#   'airline_id': 'DO',
#   'origin_country': 'Dominican Republic',
#   'active': 'Y'},
#  {'airline_name': 'Domodedovo Airlines',
#   'airline_id': 'E3',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Dragonair',
#   'airline_id': 'KA',
#   'origin_country': 'DRAGON',
#   'active': 'Y'},
#  {'airline_name': 'Druk Air',
#   'airline_id': 'KB',
#   'origin_country': 'Bhutan',
#   'active': 'Y'},
#  {'airline_name': 'dba',
#   'airline_id': 'DI',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Electronic Data Systems',
#   'airline_id': '1C',
#   'origin_country': 'Switzerland',
#   'active': 'N'},
#  {'airline_name': 'EVA Air',
#   'airline_id': 'BR',
#   'origin_country': 'Taiwan',
#   'active': 'Y'},
#  {'airline_name': 'Eagle Air',
#   'airline_id': 'H7',
#   'origin_country': 'Uganda',
#   'active': 'Y'},
#  {'airline_name': 'East African',
#   'airline_id': 'QU',
#   'origin_country': 'Uganda',
#   'active': 'Y'},
#  {'airline_name': 'East African Safari Air',
#   'airline_id': 'S9',
#   'origin_country': 'Kenya',
#   'active': 'N'},
#  {'airline_name': 'Eastern Airways',
#   'airline_id': 'T3',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Eastland Air',
#   'airline_id': 'DK',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Egyptair',
#   'airline_id': 'MS',
#   'origin_country': 'Egypt',
#   'active': 'Y'},
#  {'airline_name': 'El Al Israel Airlines',
#   'airline_id': 'LY',
#   'origin_country': 'Israel',
#   'active': 'Y'},
#  {'airline_name': 'El-Buraq Air Transport',
#   'airline_id': 'UZ',
#   'origin_country': 'Libya',
#   'active': 'Y'},
#  {'airline_name': 'Emirates',
#   'airline_id': 'EK',
#   'origin_country': 'United Arab Emirates',
#   'active': 'Y'},
#  {'airline_name': 'Empresa Ecuatoriana De Aviacion',
#   'airline_id': 'EU',
#   'origin_country': 'Ecuador',
#   'active': 'Y'},
#  {'airline_name': 'Eos Airlines',
#   'airline_id': 'E0',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Eritrean Airlines',
#   'airline_id': 'B8',
#   'origin_country': 'Eritrea',
#   'active': 'Y'},
#  {'airline_name': 'Estafeta Carga Aerea',
#   'airline_id': 'E7',
#   'origin_country': 'Mexico',
#   'active': 'N'},
#  {'airline_name': 'Estonian Air',
#   'airline_id': 'OV',
#   'origin_country': 'Estonia',
#   'active': 'Y'},
#  {'airline_name': 'Ethiopian Airlines',
#   'airline_id': 'ET',
#   'origin_country': 'Ethiopia',
#   'active': 'Y'},
#  {'airline_name': 'Etihad Airways',
#   'airline_id': 'EY',
#   'origin_country': 'United Arab Emirates',
#   'active': 'Y'},
#  {'airline_name': 'Euro Exec Express',
#   'airline_id': 'RZ',
#   'origin_country': 'Sweden',
#   'active': 'Y'},
#  {'airline_name': 'Eurocypria Airlines',
#   'airline_id': 'UI',
#   'origin_country': 'Cyprus',
#   'active': 'Y'},
#  {'airline_name': 'Eurolot',
#   'airline_id': 'K2',
#   'origin_country': 'Poland',
#   'active': 'Y'},
#  {'airline_name': 'Euromanx Airways',
#   'airline_id': '3W',
#   'origin_country': 'Austria',
#   'active': 'N'},
#  {'airline_name': 'European Air Express',
#   'airline_id': 'EA',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'European Air Transport',
#   'airline_id': 'QY',
#   'origin_country': 'Belgium',
#   'active': 'N'},
#  {'airline_name': 'Eurowings',
#   'airline_id': 'EW',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Evergreen International Airlines',
#   'airline_id': 'EZ',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Excel Airways',
#   'airline_id': 'JN',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Execair Aviation',
#   'airline_id': 'MB',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Executive Airlines',
#   'airline_id': 'OW',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Express One International',
#   'airline_id': 'EO',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'ExpressJet',
#   'airline_id': 'XE',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'easyJet',
#   'airline_id': 'U2',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Falcon Aviation',
#   'airline_id': 'IH',
#   'origin_country': 'Sweden',
#   'active': 'N'},
#  {'airline_name': 'Far Eastern Air Transport',
#   'airline_id': 'EF',
#   'origin_country': 'Taiwan',
#   'active': 'Y'},
#  {'airline_name': 'Faroejet',
#   'airline_id': 'F6',
#   'origin_country': 'Faroe Islands',
#   'active': 'N'},
#  {'airline_name': 'Faso Airways',
#   'airline_id': 'F3',
#   'origin_country': 'Burkina Faso',
#   'active': 'N'},
#  {'airline_name': 'Federal Express',
#   'airline_id': 'FX',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Fika Salaama Airlines',
#   'airline_id': 'N8',
#   'origin_country': 'Uganda',
#   'active': 'N'},
#  {'airline_name': 'Finalair Congo',
#   'airline_id': '4S',
#   'origin_country': 'Republic of the Congo',
#   'active': 'N'},
#  {'airline_name': 'Finnair',
#   'airline_id': 'AY',
#   'origin_country': 'Finland',
#   'active': 'Y'},
#  {'airline_name': 'Finncomm Airlines',
#   'airline_id': 'FC',
#   'origin_country': 'Finland',
#   'active': 'Y'},
#  {'airline_name': 'Firefly',
#   'airline_id': 'FY',
#   'origin_country': 'Malaysia',
#   'active': 'Y'},
#  {'airline_name': 'First Air',
#   'airline_id': '7F',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'First Choice Airways',
#   'airline_id': 'DP',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Fischer Air',
#   'airline_id': '8F',
#   'origin_country': 'Czech Republic',
#   'active': 'N'},
#  {'airline_name': 'Flightline',
# ...
#  {'airline_name': 'United Parcel Service',
#   'airline_id': '5X',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'US Airways',
#   'airline_id': 'US',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'UTair Aviation',
#   'airline_id': 'UT',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Uzbekistan Airways',
#   'airline_id': 'HY',
#   'origin_country': 'Uzbekistan',
#   'active': 'Y'},
#  {'airline_name': 'US Helicopter Corporation',
#   'airline_id': 'UH',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'V Australia Airlines',
#   'airline_id': 'VA',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Valuair',
#   'airline_id': 'VF',
#   'origin_country': 'Singapore',
#   'active': 'Y'},
#  {'airline_name': 'Vietnam Airlines',
#   'airline_id': 'VN',
#   'origin_country': 'Vietnam',
#   'active': 'Y'},
#  {'airline_name': 'VIM Airlines',
#   'airline_id': 'NN',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'VIA Rail Canada',
#   'airline_id': '2R',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Volaris',
#   'airline_id': 'Y4',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'Volga-Dnepr Airlines',
#   'airline_id': 'VI',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Virgin America',
#   'airline_id': 'VX',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Virgin Express',
#   'airline_id': 'TV',
#   'origin_country': 'Belgium',
#   'active': 'Y'},
#  {'airline_name': 'Virgin Nigeria Airways',
#   'airline_id': 'VK',
#   'origin_country': 'Nigeria',
#   'active': 'Y'},
#  {'airline_name': 'Virgin Atlantic Airways',
#   'airline_id': 'VS',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': 'Viva Macau',
#   'airline_id': 'ZG',
#   'origin_country': 'Macao',
#   'active': 'Y'},
#  {'airline_name': 'Vladivostok Air',
#   'airline_id': 'XF',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Varig Log',
#   'airline_id': 'LC',
#   'origin_country': 'Brazil',
#   'active': 'Y'},
#  {'airline_name': 'Viaggio Air',
#   'airline_id': 'VM',
#   'origin_country': 'Bulgaria',
#   'active': 'N'},
#  {'airline_name': 'VRG Linhas Aereas',
#   'airline_id': 'RG',
#   'origin_country': 'Brazil',
#   'active': 'Y'},
#  {'airline_name': 'VASP',
#   'airline_id': 'VP',
#   'origin_country': 'Brazil',
#   'active': 'Y'},
#  {'airline_name': 'VLM Airlines',
#   'airline_id': 'VG',
#   'origin_country': 'Belgium',
#   'active': 'Y'},
#  {'airline_name': 'Wayraper',
#   'airline_id': '7W',
#   'origin_country': 'Peru',
#   'active': 'Y'},
#  {'airline_name': 'WebJet Linhas A',
#   'airline_id': 'WJ',
#   'origin_country': 'Brazil',
#   'active': 'Y'},
#  {'airline_name': 'Welcome Air',
#   'airline_id': '2W',
#   'origin_country': 'Austria',
#   'active': 'Y'},
#  {'airline_name': 'West Coast Air',
#   'airline_id': '8O',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'WestJet',
#   'airline_id': 'WS',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Widerøe',
#   'airline_id': 'WF',
#   'origin_country': 'Norway',
#   'active': 'Y'},
#  {'airline_name': 'Wind Jet',
#   'airline_id': 'IV',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Wizz Air',
#   'airline_id': 'W6',
#   'origin_country': 'Hungary',
#   'active': 'Y'},
#  {'airline_name': 'Wizz Air Hungary',
#   'airline_id': '8Z',
#   'origin_country': 'Bulgaria',
#   'active': 'Y'},
#  {'airline_name': 'World Airways',
#   'airline_id': 'WO',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Worldspan',
#   'airline_id': '1P',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'XL Airways France',
#   'airline_id': 'SE',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Xiamen Airlines',
#   'airline_id': 'MF',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'Xtra Airways',
#   'airline_id': 'XP',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Yamal Airlines',
#   'airline_id': 'YL',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Yangtze River Express',
#   'airline_id': 'Y8',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'Yemenia',
#   'airline_id': 'IY',
#   'origin_country': 'Yemen',
#   'active': 'Y'},
#  {'airline_name': 'Zambian Airways',
#   'airline_id': 'Q3',
#   'origin_country': 'Zambia',
#   'active': 'N'},
#  {'airline_name': 'Zip',
#   'airline_id': '3J',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'Zimex Aviation',
#   'airline_id': 'C4',
#   'origin_country': 'Switzerland',
#   'active': 'N'},
#  {'airline_name': 'Zoom Airlines',
#   'airline_id': 'Z4',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Tyrolean Airways',
#   'airline_id': '\\N',
#   'origin_country': '\\N',
#   'active': 'Y'},
#  {'airline_name': 'buzz',
#   'airline_id': 'UK',
#   'origin_country': '\\N',
#   'active': 'N'},
#  {'airline_name': 'Sky Express',
#   'airline_id': 'XW',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Yellow Air Taxi',
#   'airline_id': 'Y0',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Air Mandalay',
#   'airline_id': '6T',
#   'origin_country': 'Burma',
#   'active': 'Y'},
#  {'airline_name': 'TUI Airlines Belgium',
#   'airline_id': 'TB',
#   'origin_country': 'Belgium',
#   'active': 'N'},
#  {'airline_name': 'Braathens',
#   'airline_id': 'BU',
#   'origin_country': 'Norway',
#   'active': 'N'},
#  {'airline_name': 'Globus',
#   'airline_id': 'GH',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Air Kazakhstan',
#   'airline_id': '9Y',
#   'origin_country': 'Kazakhstan',
#   'active': 'Y'},
#  {'airline_name': 'Japan Air System',
#   'airline_id': 'JD',
#   'origin_country': 'Japan',
#   'active': 'Y'},
#  {'airline_name': 'Annsett New Zealand (NZA)',
#   'airline_id': 'ZQ',
#   'origin_country': 'New Zealand',
#   'active': 'N'},
#  {'airline_name': 'EasyJet (DS)',
#   'airline_id': 'DS',
#   'origin_country': 'Switzerland',
#   'active': 'Y'},
#  {'airline_name': 'Star Peru (2I)',
#   'airline_id': '2I',
#   'origin_country': 'Peru',
#   'active': 'Y'},
#  {'airline_name': 'Carnival Air Lines',
#   'airline_id': 'KW',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'United Airways',
#   'airline_id': '4H',
#   'origin_country': 'Bangladesh',
#   'active': 'Y'},
#  {'airline_name': 'Trans Maldivian Airways',
#   'airline_id': 'M8',
#   'origin_country': 'Maldives',
#   'active': 'N'},
#  {'airline_name': 'Fly540',
#   'airline_id': '5H',
#   'origin_country': 'Kenya',
#   'active': 'Y'},
#  {'airline_name': 'Island Air (WP)',
#   'airline_id': 'WP',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': '1-2-go',
#   'airline_id': 'OG',
#   'origin_country': 'Thailand',
#   'active': 'N'},
#  {'airline_name': 'Uni Air',
#   'airline_id': 'B7',
#   'origin_country': 'Taiwan',
#   'active': 'Y'},
#  {'airline_name': 'Gomelavia',
#   'airline_id': 'YD',
#   'origin_country': 'Belarus',
#   'active': 'Y'},
#  {'airline_name': 'Red Wings',
#   'airline_id': 'WZ',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'TUIfly (X3)',
#   'airline_id': '11',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Felix Airways',
#   'airline_id': 'FU',
#   'origin_country': 'Yemen',
#   'active': 'Y'},
#  {'airline_name': 'Kostromskie avialinii',
#   'airline_id': 'K1',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Greenfly',
#   'airline_id': 'XX',
#   'origin_country': 'Spain',
#   'active': 'Y'},
#  {'airline_name': 'Tajik Air',
#   'airline_id': '7J',
#   'origin_country': 'Tajikistan',
#   'active': 'Y'},
#  {'airline_name': 'Air Mozambique',
#   'airline_id': 'TM',
#   'origin_country': 'Mozambique',
#   'active': 'Y'},
#  {'airline_name': 'ELK Airways',
#   'airline_id': '--',
#   'origin_country': 'Estonia',
#   'active': 'Y'},
#  {'airline_name': 'Virgin Pacific',
#   'airline_id': 'VH',
#   'origin_country': 'Fiji',
#   'active': 'Y'},
#  {'airline_name': 'Zest Air',
#   'airline_id': 'Z2',
#   'origin_country': 'Philippines',
#   'active': 'Y'},
#  {'airline_name': 'Air Arabia Maroc',
#   'airline_id': '3O',
#   'origin_country': 'Morocco',
#   'active': 'Y'},
#  {'airline_name': 'Baltic Air lines',
#   'airline_id': 'B1',
#   'origin_country': 'Latvia',
#   'active': 'Y'},
#  {'airline_name': 'Ciel Canadien',
#   'airline_id': 'YC',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Air Comet Chile',
#   'airline_id': '3I',
#   'origin_country': 'Chile',
#   'active': 'Y'},
#  {'airline_name': 'Nazca',
#   'airline_id': '-.',
#   'origin_country': 'Peru',
#   'active': 'N'},
#  {'airline_name': 'Voronezhskie Airlanes',
#   'airline_id': 'DN',
#   'origin_country': 'Russia',
#   'active': 'N'},
#  {'airline_name': 'Illinois Airways',
#   'airline_id': 'IL',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Salzburg arrows',
#   'airline_id': 'SZ',
#   'origin_country': 'Austria',
#   'active': 'Y'},
#  {'airline_name': 'California Western',
#   'airline_id': 'KT',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Zz',
#   'airline_id': 'ZZ',
#   'origin_country': 'Belgium',
#   'active': 'Y'},
#  {'airline_name': 'Atifly',
#   'airline_id': 'A1',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Suckling Airways',
#   'airline_id': 'CB',
#   'origin_country': 'United Kingdom',
#   'active': 'N'},
#  {'airline_name': 'Reno Sky',
#   'airline_id': 'RY',
#   'origin_country': 'United States',
#   'active': 'N'},
#  {'airline_name': 'Ciao Air',
#   'airline_id': '99',
#   'origin_country': 'Italy',
#   'active': 'Y'},
#  {'airline_name': 'Birmingham European',
#   'airline_id': 'VB',
#   'origin_country': 'United Kingdom',
#   'active': 'N'},
#  {'airline_name': 'Pal airlines',
#   'airline_id': '5P',
#   'origin_country': 'Chile',
#   'active': 'Y'},
#  {'airline_name': 'CanXpress',
#   'airline_id': 'C1',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'CanXplorer',
#   'airline_id': 'C2',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Click (Mexicana)',
#   'airline_id': 'QA',
#   'origin_country': 'Mexico',
#   'active': 'Y'},
#  {'airline_name': 'World Experience Airline',
#   'airline_id': 'W1',
#   'origin_country': 'Canada',
#   'active': 'Y'},
#  {'airline_name': 'Air Choice One',
#   'airline_id': '3E',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'China United',
#   'airline_id': 'KN',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'Safi Airlines',
#   'airline_id': '4Q',
#   'origin_country': 'Afghanistan',
#   'active': 'Y'},
#  {'airline_name': 'Bobb Air Freight',
#   'airline_id': '1',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Pelita',
#   'airline_id': '6D',
#   'origin_country': 'Indonesia',
#   'active': 'Y'},
#  {'airline_name': 'Alaska Seaplane Service',
#   'airline_id': 'J5',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'TAN',
#   'airline_id': 'T8',
#   'origin_country': 'Argentina',
#   'active': 'N'},
#  {'airline_name': 'TACA Peru',
#   'airline_id': 'T0',
#   'origin_country': 'Peru',
#   'active': 'Y'},
#  {'airline_name': 'Pan Am World Airways Dominicana',
#   'airline_id': '7Q',
#   'origin_country': 'Dominican Republic',
#   'active': 'Y'},
#  {'airline_name': 'VIP Ecuador',
#   'airline_id': 'V6',
#   'origin_country': 'Ecuador',
#   'active': 'Y'},
#  {'airline_name': 'Polar Airlines',
#   'airline_id': 'ЯП',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Catovair',
#   'airline_id': 'OC',
#   'origin_country': 'Mauritius',
#   'active': 'Y'},
#  {'airline_name': 'Halcyonair',
#   'airline_id': '7Z',
#   'origin_country': 'Cape Verde',
#   'active': 'Y'},
#  {'airline_name': 'Business Aviation',
#   'airline_id': '4P',
#   'origin_country': 'Congo (Kinshasa)',
#   'active': 'Y'},
#  {'airline_name': 'AlMasria Universal Airlines',
#   'airline_id': 'UJ',
#   'origin_country': 'Egypt',
#   'active': 'Y'},
#  {'airline_name': 'SmartLynx Airlines',
#   'airline_id': '6Y',
#   'origin_country': 'Latvia',
#   'active': 'Y'},
#  {'airline_name': 'KoralBlue Airlines',
#   'airline_id': 'K7',
#   'origin_country': 'Egypt',
#   'active': 'Y'},
#  {'airline_name': 'Med Airways',
#   'airline_id': '7Y',
#   'origin_country': 'Lebanon',
#   'active': 'Y'},
#  {'airline_name': 'Royal Falcon',
#   'airline_id': 'RL',
#   'origin_country': 'Jordan',
#   'active': 'Y'},
#  {'airline_name': 'Euroline',
#   'airline_id': '4L',
#   'origin_country': 'Georgia',
#   'active': 'Y'},
#  {'airline_name': 'Athens Airways',
#   'airline_id': 'ZF',
#   'origin_country': 'Greece',
#   'active': 'Y'},
#  {'airline_name': 'Viking Hellas',
#   'airline_id': 'VQ',
#   'origin_country': 'Greece',
#   'active': 'Y'},
#  {'airline_name': 'Starline.kz',
#   'airline_id': 'DZ',
#   'origin_country': 'Kazakhstan',
#   'active': 'Y'},
#  {'airline_name': 'Chongqing Airlines',
#   'airline_id': 'OQ',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'West Air China',
#   'airline_id': 'PN',
#   'origin_country': 'China',
#   'active': 'Y'},
#  {'airline_name': 'NordStar Airlines',
#   'airline_id': 'Y7',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'MDLR Airlines',
#   'airline_id': '9H',
#   'origin_country': 'India',
#   'active': 'Y'},
#  {'airline_name': 'Maldivian',
#   'airline_id': 'Q2',
#   'origin_country': 'Maldives',
#   'active': 'Y'},
#  {'airline_name': 'Xpressair',
#   'airline_id': 'XN',
#   'origin_country': 'Indonesia',
#   'active': 'Y'},
#  {'airline_name': 'SGA Airlines',
#   'airline_id': '5E',
#   'origin_country': 'Thailand',
#   'active': 'Y'},
#  {'airline_name': 'Air2there',
#   'airline_id': 'F8',
#   'origin_country': 'New Zealand',
#   'active': 'Y'},
#  {'airline_name': 'Court Line',
#   'airline_id': '??',
#   'origin_country': 'United Kingdom',
#   'active': 'N'},
#  {'airline_name': 'Lombards Air',
#   'airline_id': '++',
#   'origin_country': 'South Africa',
#   'active': 'N'},
#  {'airline_name': 'U.S. Air',
#   'airline_id': '-+',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Jayrow',
#   'airline_id': "\\\\'",
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Llloyd Helicopters',
#   'airline_id': '::',
#   'origin_country': 'Australia',
#   'active': 'N'},
#  {'airline_name': 'Wilderness Air',
#   'airline_id': ';;',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'Whitaker Air',
#   'airline_id': '^^',
#   'origin_country': 'Australia',
#   'active': 'Y'},
#  {'airline_name': 'PanAm World Airways',
#   'airline_id': 'WQ',
#   'origin_country': 'United States',
#   'active': 'Y'},
#  {'airline_name': 'Virginwings',
#   'airline_id': 'YY',
#   'origin_country': 'Germany',
#   'active': 'Y'},
#  {'airline_name': 'Wizz Air Ukraine',
#   'airline_id': 'WU',
#   'origin_country': 'Ukraine',
#   'active': 'Y'},
#  {'airline_name': '88',
#   'airline_id': '47',
#   'origin_country': 'Cyprus',
#   'active': 'Y'},
#  {'airline_name': 'THREE',
#   'airline_id': 'H3',
#   'origin_country': 'China',
#   'active': 'N'},
#  {'airline_name': 'Royal European Airlines',
#   'airline_id': '69',
#   'origin_country': 'United Kingdom',
#   'active': 'Y'},
#  {'airline_name': "Tom\\\\'s & co airliners",
#   'airline_id': '&T',
#   'origin_country': 'France',
#   'active': 'Y'},
#  {'airline_name': 'Nik Airways',
#   'airline_id': 'X1',
#   'origin_country': 'Saudi Arabia',
#   'active': 'N'},
#  {'airline_name': 'Congo Express',
#   'airline_id': 'XZ',
#   'origin_country': 'Congo (Kinshasa)',
#   'active': 'Y'},
#  {'airline_name': 'Fly Dubai',
#   'airline_id': 'FZ',
#   'origin_country': 'United Arab Emirates',
#   'active': 'Y'},
#  {'airline_name': 'Domenican Airlines',
#   'airline_id': 'D1',
#   'origin_country': 'Dominican Republic',
#   'active': 'Y'},
#  {'airline_name': 'Air Atlantic',
#   'airline_id': '9A',
#   'origin_country': 'Canada',
#   'active': 'N'},
#  {'airline_name': 'LSM AIRLINES ',
#   'airline_id': 'YZ',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Aero Lloyd (YP)',
#   'airline_id': 'YP',
#   'origin_country': 'Germany',
#   'active': 'N'},
#  {'airline_name': 'UTair-Express',
#   'airline_id': 'UR',
#   'origin_country': 'Russia',
#   'active': 'Y'},
#  {'airline_name': 'Huaxia',
#   'airline_id': 'G5',
#   'origin_country': 'China',
#   'active': 'Y'},
#  ...]

# %%
airports_dict = [columns_to_dict(row) for row in session.query(Airports).all()]
airports_dict
# Out:
# [{'airport_name': 'Goroka Airport',
#   'city': 'Goroka',
#   'country': 'Papua New Guinea',
#   'airport_id': 'GKA',
#   'latitude': '-6.081689835',
#   'longitude': '145.3919983',
#   'altitude': 5282},
#  {'airport_name': 'Madang Airport',
#   'city': 'Madang',
#   'country': 'Papua New Guinea',
#   'airport_id': 'MAG',
#   'latitude': '-5.207079887',
#   'longitude': '145.7890015',
#   'altitude': 20},
#  {'airport_name': 'Mount Hagen Kagamuga Airport',
#   'city': 'Mount Hagen',
#   'country': 'Papua New Guinea',
#   'airport_id': 'HGU',
#   'latitude': '-5.826789856',
#   'longitude': '144.2960052',
#   'altitude': 5388},
#  {'airport_name': 'Nadzab Airport',
#   'city': 'Nadzab',
#   'country': 'Papua New Guinea',
#   'airport_id': 'LAE',
#   'latitude': '-6.569803',
#   'longitude': '146.725977',
#   'altitude': 239},
#  {'airport_name': 'Port Moresby Jacksons International Airport',
#   'city': 'Port Moresby',
#   'country': 'Papua New Guinea',
#   'airport_id': 'POM',
#   'latitude': '-9.443380356',
#   'longitude': '147.2200012',
#   'altitude': 146},
#  {'airport_name': 'Wewak International Airport',
#   'city': 'Wewak',
#   'country': 'Papua New Guinea',
#   'airport_id': 'WWK',
#   'latitude': '-3.583830118',
#   'longitude': '143.6690063',
#   'altitude': 19},
#  {'airport_name': 'Narsarsuaq Airport',
#   'city': 'Narssarssuaq',
#   'country': 'Greenland',
#   'airport_id': 'UAK',
#   'latitude': '61.16049957',
#   'longitude': '-45.42599869',
#   'altitude': 112},
#  {'airport_name': 'Godthaab / Nuuk Airport',
#   'city': 'Godthaab',
#   'country': 'Greenland',
#   'airport_id': 'GOH',
#   'latitude': '64.19090271',
#   'longitude': '-51.67810059',
#   'altitude': 283},
#  {'airport_name': 'Kangerlussuaq Airport',
#   'city': 'Sondrestrom',
#   'country': 'Greenland',
#   'airport_id': 'SFJ',
#   'latitude': '67.0122219',
#   'longitude': '-50.71160316',
#   'altitude': 165},
#  {'airport_name': 'Thule Air Base',
#   'city': 'Thule',
#   'country': 'Greenland',
#   'airport_id': 'THU',
#   'latitude': '76.53119659',
#   'longitude': '-68.70320129',
#   'altitude': 251},
#  {'airport_name': 'Akureyri Airport',
#   'city': 'Akureyri',
#   'country': 'Iceland',
#   'airport_id': 'AEY',
#   'latitude': '65.66000366',
#   'longitude': '-18.0727005',
#   'altitude': 6},
#  {'airport_name': 'Egilsstaðir Airport',
#   'city': 'Egilsstadir',
#   'country': 'Iceland',
#   'airport_id': 'EGS',
#   'latitude': '65.28330231',
#   'longitude': '-14.40139961',
#   'altitude': 76},
#  {'airport_name': 'Hornafjörður Airport',
#   'city': 'Hofn',
#   'country': 'Iceland',
#   'airport_id': 'HFN',
#   'latitude': '64.295601',
#   'longitude': '-15.2272',
#   'altitude': 24},
#  {'airport_name': 'Húsavík Airport',
#   'city': 'Husavik',
#   'country': 'Iceland',
#   'airport_id': 'HZK',
#   'latitude': '65.952301',
#   'longitude': '-17.426001',
#   'altitude': 48},
#  {'airport_name': 'Ísafjörður Airport',
#   'city': 'Isafjordur',
#   'country': 'Iceland',
#   'airport_id': 'IFJ',
#   'latitude': '66.05809784',
#   'longitude': '-23.13529968',
#   'altitude': 8},
#  {'airport_name': 'Keflavik International Airport',
#   'city': 'Keflavik',
#   'country': 'Iceland',
#   'airport_id': 'KEF',
#   'latitude': '63.98500061',
#   'longitude': '-22.60560036',
#   'altitude': 171},
#  {'airport_name': 'Patreksfjörður Airport',
#   'city': 'Patreksfjordur',
#   'country': 'Iceland',
#   'airport_id': 'PFJ',
#   'latitude': '65.555801',
#   'longitude': '-23.965',
#   'altitude': 11},
#  {'airport_name': 'Reykjavik Airport',
#   'city': 'Reykjavik',
#   'country': 'Iceland',
#   'airport_id': 'RKV',
#   'latitude': '64.12999725',
#   'longitude': '-21.94059944',
#   'altitude': 48},
#  {'airport_name': 'Siglufjörður Airport',
#   'city': 'Siglufjordur',
#   'country': 'Iceland',
#   'airport_id': 'SIJ',
#   'latitude': '66.133301',
#   'longitude': '-18.9167',
#   'altitude': 10},
#  {'airport_name': 'Vestmannaeyjar Airport',
#   'city': 'Vestmannaeyjar',
#   'country': 'Iceland',
#   'airport_id': 'VEY',
#   'latitude': '63.42430115',
#   'longitude': '-20.27890015',
#   'altitude': 326},
#  {'airport_name': 'Sault Ste Marie Airport',
#   'city': 'Sault Sainte Marie',
#   'country': 'Canada',
#   'airport_id': 'YAM',
#   'latitude': '46.48500061',
#   'longitude': '-84.50939941',
#   'altitude': 630},
#  {'airport_name': 'St. Anthony Airport',
#   'city': 'St. Anthony',
#   'country': 'Canada',
#   'airport_id': 'YAY',
#   'latitude': '51.39189911',
#   'longitude': '-56.08309937',
#   'altitude': 108},
#  {'airport_name': 'Tofino / Long Beach Airport',
#   'city': 'Tofino',
#   'country': 'Canada',
#   'airport_id': 'YAZ',
#   'latitude': '49.079833',
#   'longitude': '-125.775583',
#   'altitude': 80},
#  {'airport_name': 'Kugaaruk Airport',
#   'city': 'Pelly Bay',
#   'country': 'Canada',
#   'airport_id': 'YBB',
#   'latitude': '68.534401',
#   'longitude': '-89.808098',
#   'altitude': 56},
#  {'airport_name': 'Baie Comeau Airport',
#   'city': 'Baie Comeau',
#   'country': 'Canada',
#   'airport_id': 'YBC',
#   'latitude': '49.13249969',
#   'longitude': '-68.20439911',
#   'altitude': 71},
#  {'airport_name': 'CFB Bagotville',
#   'city': 'Bagotville',
#   'country': 'Canada',
#   'airport_id': 'YBG',
#   'latitude': '48.33060074',
#   'longitude': '-70.99639893',
#   'altitude': 522},
#  {'airport_name': 'Baker Lake Airport',
#   'city': 'Baker Lake',
#   'country': 'Canada',
#   'airport_id': 'YBK',
#   'latitude': '64.29889679',
#   'longitude': '-96.07779694',
#   'altitude': 59},
#  {'airport_name': 'Campbell River Airport',
#   'city': 'Campbell River',
#   'country': 'Canada',
#   'airport_id': 'YBL',
#   'latitude': '49.95080185',
#   'longitude': '-125.2710037',
#   'altitude': 346},
#  {'airport_name': 'Brandon Municipal Airport',
#   'city': 'Brandon',
#   'country': 'Canada',
#   'airport_id': 'YBR',
#   'latitude': '49.91',
#   'longitude': '-99.951897',
#   'altitude': 1343},
#  {'airport_name': 'Cambridge Bay Airport',
#   'city': 'Cambridge Bay',
#   'country': 'Canada',
#   'airport_id': 'YCB',
#   'latitude': '69.10810089',
#   'longitude': '-105.1380005',
#   'altitude': 90},
#  {'airport_name': 'Nanaimo Airport',
#   'city': 'Nanaimo',
#   'country': 'Canada',
#   'airport_id': 'YCD',
#   'latitude': '49.05497022',
#   'longitude': '-123.8698626',
#   'altitude': 92},
#  {'airport_name': 'Castlegar/West Kootenay Regional Airport',
#   'city': 'Castlegar',
#   'country': 'Canada',
#   'airport_id': 'YCG',
#   'latitude': '49.29639816',
#   'longitude': '-117.6320038',
#   'altitude': 1624},
#  {'airport_name': 'Miramichi Airport',
#   'city': 'Chatham',
#   'country': 'Canada',
#   'airport_id': 'YCH',
#   'latitude': '47.007801',
#   'longitude': '-65.449203',
#   'altitude': 108},
#  {'airport_name': 'Charlo Airport',
#   'city': 'Charlo',
#   'country': 'Canada',
#   'airport_id': 'YCL',
#   'latitude': '47.990799',
#   'longitude': '-66.330299',
#   'altitude': 132},
#  {'airport_name': 'Kugluktuk Airport',
#   'city': 'Coppermine',
#   'country': 'Canada',
#   'airport_id': 'YCO',
#   'latitude': '67.816704',
#   'longitude': '-115.143997',
#   'altitude': 74},
#  {'airport_name': 'Coronation Airport',
#   'city': 'Coronation',
#   'country': 'Canada',
#   'airport_id': 'YCT',
#   'latitude': '52.07500076',
#   'longitude': '-111.4449997',
#   'altitude': 2595},
#  {'airport_name': 'Chilliwack Airport',
#   'city': 'Chilliwack',
#   'country': 'Canada',
#   'airport_id': 'YCW',
#   'latitude': '49.15280151',
#   'longitude': '-121.939003',
#   'altitude': 32},
#  {'airport_name': 'Clyde River Airport',
#   'city': 'Clyde River',
#   'country': 'Canada',
#   'airport_id': 'YCY',
#   'latitude': '70.48609924',
#   'longitude': '-68.51670074',
#   'altitude': 87},
#  {'airport_name': 'Coral Harbour Airport',
#   'city': 'Coral Harbour',
#   'country': 'Canada',
#   'airport_id': 'YZS',
#   'latitude': '64.19329834',
#   'longitude': '-83.35939789',
#   'altitude': 210},
#  {'airport_name': 'Dawson City Airport',
#   'city': 'Dawson',
#   'country': 'Canada',
#   'airport_id': 'YDA',
#   'latitude': '64.04309845',
#   'longitude': '-139.128006',
#   'altitude': 1215},
#  {'airport_name': 'Burwash Airport',
#   'city': 'Burwash',
#   'country': 'Canada',
#   'airport_id': 'YDB',
#   'latitude': '61.37110138',
#   'longitude': '-139.0410004',
#   'altitude': 2647},
#  {'airport_name': 'Deer Lake Airport',
#   'city': 'Deer Lake',
#   'country': 'Canada',
#   'airport_id': 'YDF',
#   'latitude': '49.21080017',
#   'longitude': '-57.39139938',
#   'altitude': 72},
#  {'airport_name': 'Dease Lake Airport',
#   'city': 'Dease Lake',
#   'country': 'Canada',
#   'airport_id': 'YDL',
#   'latitude': '58.42219925',
#   'longitude': '-130.0319977',
#   'altitude': 2600},
#  {'airport_name': 'Dauphin Barker Airport',
#   'city': 'Dauphin',
#   'country': 'Canada',
#   'airport_id': 'YDN',
#   'latitude': '51.10079956',
#   'longitude': '-100.052002',
#   'altitude': 999},
#  {'airport_name': 'Dawson Creek Airport',
#   'city': 'Dawson Creek',
#   'country': 'Canada',
#   'airport_id': 'YDQ',
#   'latitude': '55.74229813',
#   'longitude': '-120.1829987',
#   'altitude': 2148},
#  {'airport_name': 'Edmonton International Airport',
#   'city': 'Edmonton',
#   'country': 'Canada',
#   'airport_id': 'YEG',
#   'latitude': '53.30970001',
#   'longitude': '-113.5800018',
#   'altitude': 2373},
#  {'airport_name': 'Arviat Airport',
#   'city': 'Eskimo Point',
#   'country': 'Canada',
#   'airport_id': 'YEK',
#   'latitude': '61.09420013',
#   'longitude': '-94.07080078',
#   'altitude': 32},
#  {'airport_name': 'Estevan Airport',
#   'city': 'Estevan',
#   'country': 'Canada',
#   'airport_id': 'YEN',
#   'latitude': '49.21030045',
#   'longitude': '-102.9660034',
#   'altitude': 1905},
#  {'airport_name': 'Edson Airport',
#   'city': 'Edson',
#   'country': 'Canada',
#   'airport_id': 'YET',
#   'latitude': '53.57889938',
#   'longitude': '-116.4649963',
#   'altitude': 3043},
#  {'airport_name': 'Eureka Airport',
#   'city': 'Eureka',
#   'country': 'Canada',
#   'airport_id': 'YEU',
#   'latitude': '79.99469757',
#   'longitude': '-85.81420136',
#   'altitude': 256},
#  {'airport_name': 'Inuvik Mike Zubko Airport',
#   'city': 'Inuvik',
#   'country': 'Canada',
#   'airport_id': 'YEV',
#   'latitude': '68.30419922',
#   'longitude': '-133.4830017',
#   'altitude': 224},
#  {'airport_name': 'Iqaluit Airport',
#   'city': 'Iqaluit',
#   'country': 'Canada',
#   'airport_id': 'YFB',
#   'latitude': '63.756402',
#   'longitude': '-68.555801',
#   'altitude': 110},
#  {'airport_name': 'Fredericton Airport',
#   'city': 'Fredericton',
#   'country': 'Canada',
#   'airport_id': 'YFC',
#   'latitude': '45.8689003',
#   'longitude': '-66.53720093',
#   'altitude': 68},
#  {'airport_name': 'Forestville Airport',
#   'city': 'Forestville',
#   'country': 'Canada',
#   'airport_id': 'YFE',
#   'latitude': '48.74610138',
#   'longitude': '-69.09719849',
#   'altitude': 293},
#  {'airport_name': 'Flin Flon Airport',
#   'city': 'Flin Flon',
#   'country': 'Canada',
#   'airport_id': 'YFO',
#   'latitude': '54.67810059',
#   'longitude': '-101.6819992',
#   'altitude': 997},
#  {'airport_name': 'Fort Resolution Airport',
#   'city': 'Fort Resolution',
#   'country': 'Canada',
#   'airport_id': 'YFR',
#   'latitude': '61.18080139',
#   'longitude': '-113.6900024',
#   'altitude': 526},
#  {'airport_name': 'Fort Simpson Airport',
#   'city': 'Fort Simpson',
#   'country': 'Canada',
#   'airport_id': 'YFS',
#   'latitude': '61.7602005',
#   'longitude': '-121.2369995',
#   'altitude': 555},
#  {'airport_name': 'Kingston Norman Rogers Airport',
#   'city': 'Kingston',
#   'country': 'Canada',
#   'airport_id': 'YGK',
#   'latitude': '44.22529984',
#   'longitude': '-76.59690094',
#   'altitude': 305},
#  {'airport_name': 'La Grande Rivière Airport',
#   'city': 'La Grande Riviere',
#   'country': 'Canada',
#   'airport_id': 'YGL',
#   'latitude': '53.62530136',
#   'longitude': '-77.70420074',
#   'altitude': 639},
#  {'airport_name': 'Gaspé (Michel-Pouliot) Airport',
#   'city': 'Gaspe',
#   'country': 'Canada',
#   'airport_id': 'YGP',
#   'latitude': '48.77529907',
#   'longitude': '-64.47859955',
#   'altitude': 112},
#  {'airport_name': 'Geraldton Greenstone Regional Airport',
#   'city': 'Geraldton',
#   'country': 'Canada',
#   'airport_id': 'YGQ',
#   'latitude': '49.77830124',
#   'longitude': '-86.93939972',
#   'altitude': 1144},
#  {'airport_name': 'Îles-de-la-Madeleine Airport',
#   'city': 'Iles De La Madeleine',
#   'country': 'Canada',
#   'airport_id': 'YGR',
#   'latitude': '47.42470169',
#   'longitude': '-61.77809906',
#   'altitude': 35},
#  {'airport_name': 'Hudson Bay Airport',
#   'city': 'Hudson Bay',
#   'country': 'Canada',
#   'airport_id': 'YHB',
#   'latitude': '52.81669998',
#   'longitude': '-102.310997',
#   'altitude': 1175},
#  {'airport_name': 'Dryden Regional Airport',
#   'city': 'Dryden',
#   'country': 'Canada',
#   'airport_id': 'YHD',
#   'latitude': '49.831699',
#   'longitude': '-92.744202',
#   'altitude': 1354},
#  {'airport_name': 'Ulukhaktok Holman Airport',
#   'city': 'Holman Island',
#   'country': 'Canada',
#   'airport_id': 'YHI',
#   'latitude': '70.76280212',
#   'longitude': '-117.8059998',
#   'altitude': 117},
#  {'airport_name': 'Gjoa Haven Airport',
#   'city': 'Gjoa Haven',
#   'country': 'Canada',
#   'airport_id': 'YHK',
#   'latitude': '68.63559723',
#   'longitude': '-95.84970093',
#   'altitude': 152},
#  {'airport_name': 'John C. Munro Hamilton International Airport',
#   'city': 'Hamilton',
#   'country': 'Canada',
#   'airport_id': 'YHM',
#   'latitude': '43.17359924',
#   'longitude': '-79.93499756',
#   'altitude': 780},
#  {'airport_name': 'Montréal / Saint-Hubert Airport',
#   'city': 'Montreal',
#   'country': 'Canada',
#   'airport_id': 'YHU',
#   'latitude': '45.51750183',
#   'longitude': '-73.41690063',
#   'altitude': 90},
#  {'airport_name': 'Hay River / Merlyn Carter Airport',
#   'city': 'Hay River',
#   'country': 'Canada',
#   'airport_id': 'YHY',
#   'latitude': '60.83969879',
#   'longitude': '-115.7829971',
#   'altitude': 541},
#  {'airport_name': 'Halifax / Stanfield International Airport',
#   'city': 'Halifax',
#   'country': 'Canada',
#   'airport_id': 'YHZ',
#   'latitude': '44.88079834',
#   'longitude': '-63.50859833',
#   'altitude': 477},
#  {'airport_name': 'Atikokan Municipal Airport',
#   'city': 'Atikokan',
#   'country': 'Canada',
#   'airport_id': 'YIB',
#   'latitude': '48.77389908',
#   'longitude': '-91.63860321',
#   'altitude': 1408},
#  {'airport_name': 'Pond Inlet Airport',
#   'city': 'Pond Inlet',
#   'country': 'Canada',
#   'airport_id': 'YIO',
#   'latitude': '72.6832962',
#   'longitude': '-77.96669769',
#   'altitude': 181},
#  {'airport_name': 'St Jean Airport',
#   'city': 'St. Jean',
#   'country': 'Canada',
#   'airport_id': 'YJN',
#   'latitude': '45.29439926',
#   'longitude': '-73.28109741',
#   'altitude': 136},
#  {'airport_name': 'Stephenville Airport',
#   'city': 'Stephenville',
#   'country': 'Canada',
#   'airport_id': 'YJT',
#   'latitude': '48.5442009',
#   'longitude': '-58.54999924',
#   'altitude': 84},
#  {'airport_name': 'Kamloops Airport',
#   'city': 'Kamloops',
#   'country': 'Canada',
#   'airport_id': 'YKA',
#   'latitude': '50.70220184',
#   'longitude': '-120.4440002',
#   'altitude': 1133},
#  {'airport_name': 'Waterloo Airport',
#   'city': 'Waterloo',
#   'country': 'Canada',
#   'airport_id': 'YKF',
#   'latitude': '43.46080017',
#   'longitude': '-80.37860107',
#   'altitude': 1055},
#  {'airport_name': 'Schefferville Airport',
#   'city': 'Schefferville',
#   'country': 'Canada',
#   'airport_id': 'YKL',
#   'latitude': '54.80530167',
#   'longitude': '-66.80529785',
#   'altitude': 1709},
#  {'airport_name': 'Kindersley Airport',
#   'city': 'Kindersley',
#   'country': 'Canada',
#   'airport_id': 'YKY',
#   'latitude': '51.51750183',
#   'longitude': '-109.1809998',
#   'altitude': 2277},
#  {'airport_name': 'Buttonville Municipal Airport',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'airport_id': 'YKZ',
#   'latitude': '43.86220169',
#   'longitude': '-79.37000275',
#   'altitude': 650},
#  {'airport_name': 'Chapleau Airport',
#   'city': 'Chapleau',
#   'country': 'Canada',
#   'airport_id': 'YLD',
#   'latitude': '47.81999969',
#   'longitude': '-83.34670258',
#   'altitude': 1470},
#  {'airport_name': 'Meadow Lake Airport',
#   'city': 'Meadow Lake',
#   'country': 'Canada',
#   'airport_id': 'YLJ',
#   'latitude': '54.12530136',
#   'longitude': '-108.5230026',
#   'altitude': 1576},
#  {'airport_name': 'Lloydminster Airport',
#   'city': 'Lloydminster',
#   'country': 'Canada',
#   'airport_id': 'YLL',
#   'latitude': '53.30920029',
#   'longitude': '-110.072998',
#   'altitude': 2193},
#  {'airport_name': 'Alert Airport',
#   'city': 'Alert',
#   'country': 'Canada',
#   'airport_id': 'YLT',
#   'latitude': '82.51779938',
#   'longitude': '-62.2806015',
#   'altitude': 100},
#  {'airport_name': 'Kelowna International Airport',
#   'city': 'Kelowna',
#   'country': 'Canada',
#   'airport_id': 'YLW',
#   'latitude': '49.95610046',
#   'longitude': '-119.3779984',
#   'altitude': 1421},
#  {'airport_name': 'Mayo Airport',
#   'city': 'Mayo',
#   'country': 'Canada',
#   'airport_id': 'YMA',
#   'latitude': '63.61640167',
#   'longitude': '-135.8679962',
#   'altitude': 1653},
#  {'airport_name': 'Moose Jaw Air Vice Marshal C. M. McEwen Airport',
#   'city': 'Moose Jaw',
#   'country': 'Canada',
#   'airport_id': 'YMJ',
#   'latitude': '50.33029938',
#   'longitude': '-105.5589981',
#   'altitude': 1892},
#  {'airport_name': 'Fort McMurray Airport',
#   'city': 'Fort Mcmurray',
#   'country': 'Canada',
#   'airport_id': 'YMM',
#   'latitude': '56.65330124',
#   'longitude': '-111.2220001',
#   'altitude': 1211},
#  {'airport_name': 'Moosonee Airport',
#   'city': 'Moosonee',
#   'country': 'Canada',
#   'airport_id': 'YMO',
#   'latitude': '51.29109955',
#   'longitude': '-80.60780334',
#   'altitude': 30},
#  {'airport_name': 'Maniwaki Airport',
#   'city': 'Maniwaki',
#   'country': 'Canada',
#   'airport_id': 'YMW',
#   'latitude': '46.27280045',
#   'longitude': '-75.99060059',
#   'altitude': 656},
#  {'airport_name': 'Montreal International (Mirabel) Airport',
#   'city': 'Montreal',
#   'country': 'Canada',
#   'airport_id': 'YMX',
#   'latitude': '45.679501',
#   'longitude': '-74.038696',
#   'altitude': 270},
#  {'airport_name': 'Natashquan Airport',
#   'city': 'Natashquan',
#   'country': 'Canada',
#   'airport_id': 'YNA',
#   'latitude': '50.18999863',
#   'longitude': '-61.78919983',
#   'altitude': 39},
#  {'airport_name': 'Ottawa / Gatineau Airport',
#   'city': 'Gatineau',
#   'country': 'Canada',
#   'airport_id': 'YND',
#   'latitude': '45.52170181',
#   'longitude': '-75.56359863',
#   'altitude': 211},
#  {'airport_name': 'Matagami Airport',
#   'city': 'Matagami',
#   'country': 'Canada',
#   'airport_id': 'YNM',
#   'latitude': '49.76169968',
#   'longitude': '-77.80280304',
#   'altitude': 918},
#  {'airport_name': 'Old Crow Airport',
#   'city': 'Old Crow',
#   'country': 'Canada',
#   'airport_id': 'YOC',
#   'latitude': '67.57060242',
#   'longitude': '-139.8390045',
#   'altitude': 824},
#  {'airport_name': 'CFB Cold Lake',
#   'city': 'Cold Lake',
#   'country': 'Canada',
#   'airport_id': 'YOD',
#   'latitude': '54.40499878',
#   'longitude': '-110.2789993',
#   'altitude': 1775},
#  {'airport_name': 'High Level Airport',
#   'city': 'High Level',
#   'country': 'Canada',
#   'airport_id': 'YOJ',
#   'latitude': '58.62139893',
#   'longitude': '-117.1650009',
#   'altitude': 1110},
#  {'airport_name': 'Ottawa Macdonald-Cartier International Airport',
#   'city': 'Ottawa',
#   'country': 'Canada',
#   'airport_id': 'YOW',
#   'latitude': '45.32249832',
#   'longitude': '-75.66919708',
#   'altitude': 374},
#  {'airport_name': 'Prince Albert Glass Field',
#   'city': 'Prince Albert',
#   'country': 'Canada',
#   'airport_id': 'YPA',
#   'latitude': '53.21419907',
#   'longitude': '-105.6729965',
#   'altitude': 1405},
#  {'airport_name': 'Peace River Airport',
#   'city': 'Peace River',
#   'country': 'Canada',
#   'airport_id': 'YPE',
#   'latitude': '56.226898',
#   'longitude': '-117.446999',
#   'altitude': 1873},
#  {'airport_name': 'Southport Airport',
#   'city': 'Portage-la-prairie',
#   'country': 'Canada',
#   'airport_id': 'YPG',
#   'latitude': '49.903099',
#   'longitude': '-98.273817',
#   'altitude': 885},
#  {'airport_name': 'Pickle Lake Airport',
#   'city': 'Pickle Lake',
#   'country': 'Canada',
#   'airport_id': 'YPL',
#   'latitude': '51.44639969',
#   'longitude': '-90.21420288',
#   'altitude': 1267},
#  {'airport_name': 'Port Menier Airport',
#   'city': 'Port Menier',
#   'country': 'Canada',
#   'airport_id': 'YPN',
#   'latitude': '49.83639908',
#   'longitude': '-64.28859711',
#   'altitude': 167},
#  {'airport_name': 'Peterborough Airport',
#   'city': 'Peterborough',
#   'country': 'Canada',
#   'airport_id': 'YPQ',
#   'latitude': '44.22999954',
#   'longitude': '-78.36329651',
#   'altitude': 628},
#  {'airport_name': 'Prince Rupert Airport',
#   'city': 'Prince Pupert',
#   'country': 'Canada',
#   'airport_id': 'YPR',
#   'latitude': '54.28609848',
#   'longitude': '-130.4450073',
#   'altitude': 116},
#  {'airport_name': 'Fort Chipewyan Airport',
#   'city': 'Fort Chipewyan',
#   'country': 'Canada',
#   'airport_id': 'YPY',
#   'latitude': '58.76720047',
#   'longitude': '-111.1169968',
#   'altitude': 761},
#  {'airport_name': 'Muskoka Airport',
#   'city': 'Muskoka',
#   'country': 'Canada',
#   'airport_id': 'YQA',
#   'latitude': '44.97470093',
#   'longitude': '-79.30329895',
#   'altitude': 925},
#  {'airport_name': 'Quebec Jean Lesage International Airport',
#   'city': 'Quebec',
#   'country': 'Canada',
#   'airport_id': 'YQB',
#   'latitude': '46.7911',
#   'longitude': '-71.393303',
#   'altitude': 244},
#  {'airport_name': 'Red Deer Regional Airport',
#   'city': 'Red Deer Industrial',
#   'country': 'Canada',
#   'airport_id': 'YQF',
#   'latitude': '52.18220139',
#   'longitude': '-113.8939972',
#   'altitude': 2968},
#  {'airport_name': 'Windsor Airport',
#   'city': 'Windsor',
#   'country': 'Canada',
#   'airport_id': 'YQG',
#   'latitude': '42.27560043',
#   'longitude': '-82.95559692',
#   'altitude': 622},
#  {'airport_name': 'Watson Lake Airport',
#   'city': 'Watson Lake',
#   'country': 'Canada',
#   'airport_id': 'YQH',
#   'latitude': '60.11640167',
#   'longitude': '-128.8220062',
#   'altitude': 2255},
#  {'airport_name': 'Kenora Airport',
#   'city': 'Kenora',
#   'country': 'Canada',
#   'airport_id': 'YQK',
#   'latitude': '49.78829956',
#   'longitude': '-94.36309814',
#   'altitude': 1332},
#  {'airport_name': 'Lethbridge County Airport',
#   'city': 'Lethbridge',
#   'country': 'Canada',
#   'airport_id': 'YQL',
#   'latitude': '49.63029861',
#   'longitude': '-112.8000031',
#   'altitude': 3048},
#  {'airport_name': 'Greater Moncton International Airport',
#   'city': 'Moncton',
#   'country': 'Canada',
#   'airport_id': 'YQM',
#   'latitude': '46.11220169',
#   'longitude': '-64.6785965',
#   'altitude': 232},
#  {'airport_name': 'Comox Airport',
#   'city': 'Comox',
#   'country': 'Canada',
#   'airport_id': 'YQQ',
#   'latitude': '49.71080017',
#   'longitude': '-124.887001',
#   'altitude': 84},
#  {'airport_name': 'Regina International Airport',
#   'city': 'Regina',
#   'country': 'Canada',
#   'airport_id': 'YQR',
#   'latitude': '50.43190002',
#   'longitude': '-104.6660004',
#   'altitude': 1894},
#  {'airport_name': 'Thunder Bay Airport',
#   'city': 'Thunder Bay',
#   'country': 'Canada',
#   'airport_id': 'YQT',
#   'latitude': '48.37189865',
#   'longitude': '-89.32389832',
#   'altitude': 653},
#  {'airport_name': 'Grande Prairie Airport',
#   'city': 'Grande Prairie',
#   'country': 'Canada',
#   'airport_id': 'YQU',
#   'latitude': '55.17969894',
#   'longitude': '-118.8850021',
#   'altitude': 2195},
#  {'airport_name': 'Yorkton Municipal Airport',
#   'city': 'Yorkton',
#   'country': 'Canada',
#   'airport_id': 'YQV',
#   'latitude': '51.26470184',
#   'longitude': '-102.461998',
#   'altitude': 1635},
#  {'airport_name': 'North Battleford Airport',
#   'city': 'North Battleford',
#   'country': 'Canada',
#   'airport_id': 'YQW',
#   'latitude': '52.76919937',
#   'longitude': '-108.2440033',
#   'altitude': 1799},
#  {'airport_name': 'Gander International Airport',
#   'city': 'Gander',
#   'country': 'Canada',
#   'airport_id': 'YQX',
#   'latitude': '48.93690109',
#   'longitude': '-54.56809998',
#   'altitude': 496},
#  {'airport_name': 'Sydney / J.A. Douglas McCurdy Airport',
#   'city': 'Sydney',
#   'country': 'Canada',
#   'airport_id': 'YQY',
#   'latitude': '46.1614',
#   'longitude': '-60.047798',
#   'altitude': 203},
#  {'airport_name': 'Quesnel Airport',
#   'city': 'Quesnel',
#   'country': 'Canada',
#   'airport_id': 'YQZ',
#   'latitude': '53.02610016',
#   'longitude': '-122.5100021',
#   'altitude': 1789},
#  {'airport_name': 'Resolute Bay Airport',
#   'city': 'Resolute',
#   'country': 'Canada',
#   'airport_id': 'YRB',
#   'latitude': '74.71690369',
#   'longitude': '-94.9693985',
#   'altitude': 215},
#  {'airport_name': 'Rivière-du-Loup Airport',
#   'city': 'Riviere Du Loup',
#   'country': 'Canada',
#   'airport_id': 'YRI',
#   'latitude': '47.76440048',
#   'longitude': '-69.58470154',
#   'altitude': 427},
#  {'airport_name': 'Roberval Airport',
#   'city': 'Roberval',
#   'country': 'Canada',
#   'airport_id': 'YRJ',
#   'latitude': '48.52000046',
#   'longitude': '-72.26560211',
#   'altitude': 586},
#  {'airport_name': 'Rocky Mountain House Airport',
#   'city': 'Rocky Mountain House',
#   'country': 'Canada',
#   'airport_id': 'YRM',
#   'latitude': '52.42969894',
#   'longitude': '-114.9039993',
#   'altitude': 3244},
#  {'airport_name': 'Rankin Inlet Airport',
#   'city': 'Rankin Inlet',
#   'country': 'Canada',
#   'airport_id': 'YRT',
#   'latitude': '62.81140137',
#   'longitude': '-92.11579895',
#   'altitude': 94},
#  {'airport_name': 'Sudbury Airport',
#   'city': 'Sudbury',
#   'country': 'Canada',
#   'airport_id': 'YSB',
#   'latitude': '46.625',
#   'longitude': '-80.79889679',
#   'altitude': 1141},
#  {'airport_name': 'Sherbrooke Airport',
#   'city': 'Sherbrooke',
#   'country': 'Canada',
#   'airport_id': 'YSC',
#   'latitude': '45.43859863',
#   'longitude': '-71.69139862',
#   'altitude': 792},
#  {'airport_name': 'Saint John Airport',
#   'city': 'St. John',
#   'country': 'Canada',
#   'airport_id': 'YSJ',
#   'latitude': '45.31610107',
#   'longitude': '-65.89029694',
#   'altitude': 357},
#  {'airport_name': 'Fort Smith Airport',
#   'city': 'Fort Smith',
#   'country': 'Canada',
#   'airport_id': 'YSM',
#   'latitude': '60.02030182',
#   'longitude': '-111.961998',
#   'altitude': 671},
#  {'airport_name': 'Nanisivik Airport',
#   'city': 'Nanisivik',
#   'country': 'Canada',
#   'airport_id': 'YSR',
#   'latitude': '72.982201',
#   'longitude': '-84.613602',
#   'altitude': 2106},
#  {'airport_name': 'Summerside Airport',
#   'city': 'Summerside',
#   'country': 'Canada',
#   'airport_id': 'YSU',
#   'latitude': '46.44060135',
#   'longitude': '-63.83359909',
#   'altitude': 56},
#  {'airport_name': 'Sachs Harbour (David Nasogaluak Jr. Saaryuaq) Airport',
#   'city': 'Sachs Harbour',
#   'country': 'Canada',
#   'airport_id': 'YSY',
#   'latitude': '71.99389648',
#   'longitude': '-125.2429962',
#   'altitude': 282},
#  {'airport_name': 'Cape Dorset Airport',
#   'city': 'Cape Dorset',
#   'country': 'Canada',
#   'airport_id': 'YTE',
#   'latitude': '64.23000336',
#   'longitude': '-76.52670288',
#   'altitude': 164},
#  {'airport_name': 'Thompson Airport',
#   'city': 'Thompson',
#   'country': 'Canada',
#   'airport_id': 'YTH',
#   'latitude': '55.80110168',
#   'longitude': '-97.86419678',
#   'altitude': 729},
#  {'airport_name': 'CFB Trenton',
#   'city': 'Trenton',
#   'country': 'Canada',
#   'airport_id': 'YTR',
#   'latitude': '44.1189003',
#   'longitude': '-77.52809906',
#   'altitude': 283},
#  {'airport_name': 'Timmins/Victor M. Power',
#   'city': 'Timmins',
#   'country': 'Canada',
#   'airport_id': 'YTS',
#   'latitude': '48.56969833',
#   'longitude': '-81.37670136',
#   'altitude': 967},
#  {'airport_name': 'Billy Bishop Toronto City Centre Airport',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'airport_id': 'YTZ',
#   'latitude': '43.627499',
#   'longitude': '-79.396202',
#   'altitude': 252},
#  {'airport_name': 'Tuktoyaktuk Airport',
#   'city': 'Tuktoyaktuk',
#   'country': 'Canada',
#   'airport_id': 'YUB',
#   'latitude': '69.4332962',
#   'longitude': '-133.026001',
#   'altitude': 15},
#  {'airport_name': 'Montreal / Pierre Elliott Trudeau International Airport',
#   'city': 'Montreal',
#   'country': 'Canada',
#   'airport_id': 'YUL',
#   'latitude': '45.47060013',
#   'longitude': '-73.74079895',
#   'altitude': 118},
#  {'airport_name': 'Repulse Bay Airport',
#   'city': 'Repulse Bay',
#   'country': 'Canada',
#   'airport_id': 'YUT',
#   'latitude': '66.52140045',
#   'longitude': '-86.22470093',
#   'altitude': 80},
#  {'airport_name': 'Hall Beach Airport',
#   'city': 'Hall Beach',
#   'country': 'Canada',
#   'airport_id': 'YUX',
#   'latitude': '68.77610016',
#   'longitude': '-81.2425',
#   'altitude': 30},
#  {'airport_name': 'Rouyn Noranda Airport',
#   'city': 'Rouyn',
#   'country': 'Canada',
#   'airport_id': 'YUY',
#   'latitude': '48.20610046',
#   'longitude': '-78.83560181',
#   'altitude': 988},
#  {'airport_name': 'La Ronge Airport',
#   'city': 'La Ronge',
#   'country': 'Canada',
#   'airport_id': 'YVC',
#   'latitude': '55.15140152',
#   'longitude': '-105.262001',
#   'altitude': 1242},
#  {'airport_name': 'Vermilion Airport',
#   'city': 'Vermillion',
#   'country': 'Canada',
#   'airport_id': 'YVG',
#   'latitude': '53.35580063',
#   'longitude': '-110.8239975',
#   'altitude': 2025},
#  {'airport_name': 'Qikiqtarjuaq Airport',
#   'city': 'Broughton Island',
#   'country': 'Canada',
#   'airport_id': 'YVM',
#   'latitude': '67.54579926',
#   'longitude': '-64.03140259',
#   'altitude': 21},
#  {'airport_name': "Val-d'Or Airport",
#   'city': "Val D'or",
#   'country': 'Canada',
#   'airport_id': 'YVO',
#   'latitude': '48.05329895',
#   'longitude': '-77.78279877',
#   'altitude': 1107},
#  {'airport_name': 'Kuujjuaq Airport',
#   'city': 'Quujjuaq',
#   'country': 'Canada',
#   'airport_id': 'YVP',
#   'latitude': '58.09609985',
#   'longitude': '-68.42690277',
#   'altitude': 129},
#  {'airport_name': 'Norman Wells Airport',
#   'city': 'Norman Wells',
#   'country': 'Canada',
#   'airport_id': 'YVQ',
#   'latitude': '65.28160095',
#   'longitude': '-126.7979965',
#   'altitude': 238},
#  {'airport_name': 'Vancouver International Airport',
#   'city': 'Vancouver',
#   'country': 'Canada',
#   'airport_id': 'YVR',
#   'latitude': '49.19390106',
#   'longitude': '-123.1839981',
#   'altitude': 14},
#  {'airport_name': 'Buffalo Narrows Airport',
#   'city': 'Buffalo Narrows',
#   'country': 'Canada',
#   'airport_id': 'YVT',
#   'latitude': '55.84189987',
#   'longitude': '-108.4179993',
#   'altitude': 1423},
#  {'airport_name': 'Wiarton Airport',
#   'city': 'Wiarton',
#   'country': 'Canada',
#   'airport_id': 'YVV',
#   'latitude': '44.7458',
#   'longitude': '-81.107201',
#   'altitude': 729},
#  {'airport_name': 'Petawawa Airport',
#   'city': 'Petawawa',
#   'country': 'Canada',
#   'airport_id': 'YWA',
#   'latitude': '45.95220184',
#   'longitude': '-77.31919861',
#   'altitude': 427},
#  {'airport_name': 'Winnipeg / James Armstrong Richardson International Airport',
#   'city': 'Winnipeg',
#   'country': 'Canada',
#   'airport_id': 'YWG',
#   'latitude': '49.90999985',
#   'longitude': '-97.23989868',
#   'altitude': 783},
#  {'airport_name': 'Wabush Airport',
#   'city': 'Wabush',
#   'country': 'Canada',
#   'airport_id': 'YWK',
#   'latitude': '52.9219017',
#   'longitude': '-66.86440277',
#   'altitude': 1808},
#  {'airport_name': 'Williams Lake Airport',
#   'city': 'Williams Lake',
#   'country': 'Canada',
#   'airport_id': 'YWL',
#   'latitude': '52.18310165',
#   'longitude': '-122.0540009',
#   'altitude': 3085},
#  {'airport_name': 'Wrigley Airport',
#   'city': 'Wrigley',
#   'country': 'Canada',
#   'airport_id': 'YWY',
#   'latitude': '63.20940018',
#   'longitude': '-123.4369965',
#   'altitude': 489},
#  {'airport_name': 'Cranbrook/Canadian Rockies International Airport',
#   'city': 'Cranbrook',
#   'country': 'Canada',
#   'airport_id': 'YXC',
#   'latitude': '49.6108017',
#   'longitude': '-115.7819977',
#   'altitude': 3082},
#  {'airport_name': 'Edmonton City Centre (Blatchford Field) Airport',
#   'city': 'Edmonton',
#   'country': 'Canada',
#   'airport_id': 'YXD',
#   'latitude': '53.57249832',
#   'longitude': '-113.5210037',
#   'altitude': 2202},
#  {'airport_name': 'Saskatoon John G. Diefenbaker International Airport',
#   'city': 'Saskatoon',
#   'country': 'Canada',
#   'airport_id': 'YXE',
#   'latitude': '52.17079926',
#   'longitude': '-106.6999969',
#   'altitude': 1653},
#  {'airport_name': 'Medicine Hat Airport',
#   'city': 'Medicine Hat',
#   'country': 'Canada',
#   'airport_id': 'YXH',
#   'latitude': '50.01890182',
#   'longitude': '-110.7210007',
#   'altitude': 2352},
#  {'airport_name': 'Fort St John Airport',
#   'city': 'Fort Saint John',
#   'country': 'Canada',
#   'airport_id': 'YXJ',
#   'latitude': '56.23809814',
#   'longitude': '-120.7399979',
#   'altitude': 2280},
#  {'airport_name': 'Sioux Lookout Airport',
#   'city': 'Sioux Lookout',
#   'country': 'Canada',
#   'airport_id': 'YXL',
#   'latitude': '50.11389923',
#   'longitude': '-91.90529633',
#   'altitude': 1258},
#  {'airport_name': 'Pangnirtung Airport',
#   'city': 'Pangnirtung',
#   'country': 'Canada',
#   'airport_id': 'YXP',
#   'latitude': '66.14499664',
#   'longitude': '-65.71360016',
#   'altitude': 75},
#  {'airport_name': 'Earlton (Timiskaming Regional) Airport',
#   'city': 'Earlton',
#   'country': 'Canada',
#   'airport_id': 'YXR',
#   'latitude': '47.69740065',
#   'longitude': '-79.84734535',
#   'altitude': 800},
#  {'airport_name': 'Prince George Airport',
#   'city': 'Prince George',
#   'country': 'Canada',
#   'airport_id': 'YXS',
#   'latitude': '53.88940048',
#   'longitude': '-122.6790009',
#   'altitude': 2267},
#  {'airport_name': 'Northwest Regional Airport Terrace-Kitimat',
#   'city': 'Terrace',
#   'country': 'Canada',
#   'airport_id': 'YXT',
#   'latitude': '54.468498',
#   'longitude': '-128.576009',
#   'altitude': 713},
#  {'airport_name': 'London Airport',
#   'city': 'London',
#   'country': 'Canada',
#   'airport_id': 'YXU',
#   'latitude': '43.035599',
#   'longitude': '-81.1539',
#   'altitude': 912},
#  {'airport_name': 'Abbotsford Airport',
#   'city': 'Abbotsford',
#   'country': 'Canada',
#   'airport_id': 'YXX',
#   'latitude': '49.02529907',
#   'longitude': '-122.3610001',
#   'altitude': 195},
#  {'airport_name': 'Whitehorse / Erik Nielsen International Airport',
#   'city': 'Whitehorse',
#   'country': 'Canada',
#   'airport_id': 'YXY',
#   'latitude': '60.70959854',
#   'longitude': '-135.0670013',
#   'altitude': 2317},
#  {'airport_name': 'North Bay Jack Garland Airport',
#   'city': 'North Bay',
#   'country': 'Canada',
#   'airport_id': 'YYB',
#   'latitude': '46.363602',
#   'longitude': '-79.422798',
#   'altitude': 1215},
#  {'airport_name': 'Calgary International Airport',
#   'city': 'Calgary',
#   'country': 'Canada',
#   'airport_id': 'YYC',
#   'latitude': '51.11389923',
#   'longitude': '-114.0199966',
#   'altitude': 3557},
#  {'airport_name': 'Smithers Airport',
#   'city': 'Smithers',
#   'country': 'Canada',
#   'airport_id': 'YYD',
#   'latitude': '54.8246994',
#   'longitude': '-127.1829987',
#   'altitude': 1712},
#  {'airport_name': 'Fort Nelson Airport',
#   'city': 'Fort Nelson',
#   'country': 'Canada',
#   'airport_id': 'YYE',
#   'latitude': '58.83639908',
#   'longitude': '-122.5970001',
#   'altitude': 1253},
#  {'airport_name': 'Penticton Airport',
#   'city': 'Penticton',
#   'country': 'Canada',
#   'airport_id': 'YYF',
#   'latitude': '49.46310043',
#   'longitude': '-119.6019974',
#   'altitude': 1129},
#  {'airport_name': 'Charlottetown Airport',
#   'city': 'Charlottetown',
#   'country': 'Canada',
#   'airport_id': 'YYG',
#   'latitude': '46.29000092',
#   'longitude': '-63.12110138',
#   'altitude': 160},
#  {'airport_name': 'Taloyoak Airport',
#   'city': 'Spence Bay',
#   'country': 'Canada',
#   'airport_id': 'YYH',
#   'latitude': '69.54669952',
#   'longitude': '-93.5766983',
#   'altitude': 92},
#  {'airport_name': 'Victoria International Airport',
#   'city': 'Victoria',
#   'country': 'Canada',
#   'airport_id': 'YYJ',
#   'latitude': '48.64690018',
#   'longitude': '-123.4260025',
#   'altitude': 63},
#  {'airport_name': 'Lynn Lake Airport',
#   'city': 'Lynn Lake',
#   'country': 'Canada',
#   'airport_id': 'YYL',
#   'latitude': '56.86389923',
#   'longitude': '-101.0759964',
#   'altitude': 1170},
#  {'airport_name': 'Swift Current Airport',
#   'city': 'Swift Current',
#   'country': 'Canada',
#   'airport_id': 'YYN',
#   'latitude': '50.29190063',
#   'longitude': '-107.6910019',
#   'altitude': 2680},
#  {'airport_name': 'Churchill Airport',
#   'city': 'Churchill',
#   'country': 'Canada',
#   'airport_id': 'YYQ',
#   'latitude': '58.73920059',
#   'longitude': '-94.06500244',
#   'altitude': 94},
#  {'airport_name': 'Goose Bay Airport',
#   'city': 'Goose Bay',
#   'country': 'Canada',
#   'airport_id': 'YYR',
#   'latitude': '53.31919861',
#   'longitude': '-60.42580032',
#   'altitude': 160},
#  {'airport_name': "St. John's International Airport",
#   'city': "St. John's",
#   'country': 'Canada',
#   'airport_id': 'YYT',
#   'latitude': '47.61859894',
#   'longitude': '-52.75189972',
#   'altitude': 461},
#  {'airport_name': 'Kapuskasing Airport',
#   'city': 'Kapuskasing',
#   'country': 'Canada',
#   'airport_id': 'YYU',
#   'latitude': '49.41389847',
#   'longitude': '-82.46749878',
#   'altitude': 743},
#  {'airport_name': 'Armstrong Airport',
#   'city': 'Armstrong',
#   'country': 'Canada',
#   'airport_id': 'YYW',
#   'latitude': '50.29029846',
#   'longitude': '-88.90969849',
#   'altitude': 1058},
#  {'airport_name': 'Mont Joli Airport',
#   'city': 'Mont Joli',
#   'country': 'Canada',
#   'airport_id': 'YYY',
#   'latitude': '48.60860062',
#   'longitude': '-68.20809937',
#   'altitude': 172},
#  {'airport_name': 'Lester B. Pearson International Airport',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'airport_id': 'YYZ',
#   'latitude': '43.67720032',
#   'longitude': '-79.63059998',
#   'altitude': 569},
#  {'airport_name': 'Downsview Airport',
#   'city': 'Toronto',
#   'country': 'Canada',
#   'airport_id': 'YZD',
#   'latitude': '43.74250031',
#   'longitude': '-79.46559906',
#   'altitude': 652},
#  {'airport_name': 'Gore Bay Manitoulin Airport',
#   'city': 'Gore Bay',
#   'country': 'Canada',
#   'airport_id': 'YZE',
#   'latitude': '45.88529968',
#   'longitude': '-82.56780243',
#   'altitude': 635},
#  {'airport_name': 'Yellowknife Airport',
#   'city': 'Yellowknife',
#   'country': 'Canada',
#   'airport_id': 'YZF',
#   'latitude': '62.46279907',
#   'longitude': '-114.4400024',
#   'altitude': 675},
#  {'airport_name': 'Slave Lake Airport',
#   'city': 'Slave Lake',
#   'country': 'Canada',
#   'airport_id': 'YZH',
#   'latitude': '55.29309845',
#   'longitude': '-114.7770004',
#   'altitude': 1912},
#  {'airport_name': 'Sandspit Airport',
#   'city': 'Sandspit',
#   'country': 'Canada',
#   'airport_id': 'YZP',
#   'latitude': '53.25429916',
#   'longitude': '-131.8139954',
#   'altitude': 21},
#  {'airport_name': 'Chris Hadfield Airport',
#   'city': 'Sarnia',
#   'country': 'Canada',
#   'airport_id': 'YZR',
#   'latitude': '42.99940109',
#   'longitude': '-82.30889893',
#   'altitude': 594},
#  {'airport_name': 'Port Hardy Airport',
#   'city': 'Port Hardy',
#   'country': 'Canada',
#   'airport_id': 'YZT',
#   'latitude': '50.68059921',
#   'longitude': '-127.3669968',
#   'altitude': 71},
#  {'airport_name': 'Whitecourt Airport',
#   'city': 'Whitecourt',
#   'country': 'Canada',
#   'airport_id': 'YZU',
#   'latitude': '54.14390182',
#   'longitude': '-115.7870026',
#   'altitude': 2567},
#  {'airport_name': 'Sept-Îles Airport',
#   'city': 'Sept-iles',
#   'country': 'Canada',
#   'airport_id': 'YZV',
#   'latitude': '50.22330093',
#   'longitude': '-66.26560211',
#   'altitude': 180},
#  {'airport_name': 'Teslin Airport',
#   'city': 'Teslin',
#   'country': 'Canada',
#   'airport_id': 'YZW',
#   'latitude': '60.17279816',
#   'longitude': '-132.7429962',
#   'altitude': 2313},
#  {'airport_name': 'CFB Greenwood',
#   'city': 'Greenwood',
#   'country': 'Canada',
#   'airport_id': 'YZX',
#   'latitude': '44.9844017',
#   'longitude': '-64.91690063',
#   'altitude': 92},
#  {'airport_name': 'Faro Airport',
#   'city': 'Faro',
#   'country': 'Canada',
#   'airport_id': 'ZFA',
#   'latitude': '62.20750046',
#   'longitude': '-133.3760071',
#   'altitude': 2351},
#  {'airport_name': 'Fort Mcpherson Airport',
#   'city': 'Fort Mcpherson',
#   'country': 'Canada',
#   'airport_id': 'ZFM',
#   'latitude': '67.40750122',
#   'longitude': '-134.8609924',
#   'altitude': 116},
#  {'airport_name': 'Blida Airport',
#   'city': 'Blida',
#   'country': 'Algeria',
#   'airport_id': 'QLD',
#   'latitude': '36.50360107',
#   'longitude': '2.814169884',
#   'altitude': 535},
#  {'airport_name': 'Bou Saada Airport',
#   'city': 'Bou Saada',
#   'country': 'Algeria',
#   'airport_id': 'BUJ',
#   'latitude': '35.33250046',
#   'longitude': '4.206389904',
#   'altitude': 1506},
#  {'airport_name': 'Soummam Airport',
#   'city': 'Bejaja',
#   'country': 'Algeria',
#   'airport_id': 'BJA',
#   'latitude': '36.7120018',
#   'longitude': '5.069920063',
#   'altitude': 20},
#  {'airport_name': 'Houari Boumediene Airport',
#   'city': 'Algier',
#   'country': 'Algeria',
#   'airport_id': 'ALG',
#   'latitude': '36.69100189',
#   'longitude': '3.215409994',
#   'altitude': 82},
#  {'airport_name': 'Djanet Inedbirene Airport',
#   'city': 'Djanet',
#   'country': 'Algeria',
#   'airport_id': 'DJG',
#   'latitude': '24.292801',
#   'longitude': '9.45244',
#   'altitude': 3176},
#  {'airport_name': 'Illizi Takhamalt Airport',
#   'city': 'Illizi',
#   'country': 'Algeria',
#   'airport_id': 'VVZ',
#   'latitude': '26.7234993',
#   'longitude': '8.622650146',
#   'altitude': 1778},
#  {'airport_name': 'Aguenar – Hadj Bey Akhamok Airport',
#   'city': 'Tamanrasset',
#   'country': 'Algeria',
#   'airport_id': 'TMR',
#   'latitude': '22.81150055',
#   'longitude': '5.451079845',
#   'altitude': 4518},
#  {'airport_name': 'Jijel Ferhat Abbas Airport',
#   'city': 'Jijel',
#   'country': 'Algeria',
#   'airport_id': 'GJL',
#   'latitude': '36.79510117',
#   'longitude': '5.87361002',
#   'altitude': 36},
#  {'airport_name': 'Mecheria Airport',
#   'city': 'Mecheria',
#   'country': 'Algeria',
#   'airport_id': 'MZW',
#   'latitude': '33.53590012',
#   'longitude': '-0.242353007',
#   'altitude': 3855},
#  {'airport_name': 'Rabah Bitat Airport',
#   'city': 'Annaba',
#   'country': 'Algeria',
#   'airport_id': 'AAE',
#   'latitude': '36.822201',
#   'longitude': '7.809174',
#   'altitude': 16},
#  {'airport_name': 'Mohamed Boudiaf International Airport',
#   'city': 'Constantine',
#   'country': 'Algeria',
#   'airport_id': 'CZL',
#   'latitude': '36.27600098',
#   'longitude': '6.620389938',
#   'altitude': 2265},
#  {'airport_name': 'Cheikh Larbi Tébessi Airport',
#   'city': 'Tebessa',
#   'country': 'Algeria',
#   'airport_id': 'TEE',
#   'latitude': '35.43159866',
#   'longitude': '8.12071991',
#   'altitude': 2661},
#  {'airport_name': "Hassi R'Mel Airport",
#   'city': 'Tilrempt',
#   'country': 'Algeria',
#   'airport_id': 'HRM',
#   'latitude': '32.93040085',
#   'longitude': '3.311539888',
#   'altitude': 2540},
#  {'airport_name': 'Bou Chekif Airport',
#   'city': 'Tiaret',
#   'country': 'Algeria',
#   'airport_id': 'TID',
#   'latitude': '35.34109879',
#   'longitude': '1.463150024',
#   'altitude': 3245},
#  {'airport_name': 'Tindouf Airport',
#   'city': 'Tindouf',
#   'country': 'Algeria',
#   'airport_id': 'TIN',
#   'latitude': '27.7003994',
#   'longitude': '-8.167099953',
#   'altitude': 1453},
#  {'airport_name': 'Ech Cheliff Airport',
#   'city': 'Ech-cheliff',
#   'country': 'Algeria',
#   'airport_id': 'CFK',
#   'latitude': '36.21269989',
#   'longitude': '1.331769943',
#   'altitude': 463},
#  {'airport_name': 'Tafaraoui Airport',
#   'city': 'Oran',
#   'country': 'Algeria',
#   'airport_id': 'TAF',
#   'latitude': '35.54240036',
#   'longitude': '-0.532278001',
#   'altitude': 367},
#  {'airport_name': 'Zenata – Messali El Hadj Airport',
#   'city': 'Tlemcen',
#   'country': 'Algeria',
#   'airport_id': 'TLM',
#   'latitude': '35.01670074',
#   'longitude': '-1.450000048',
#   'altitude': 814},
#  {'airport_name': 'Es Senia Airport',
#   'city': 'Oran',
#   'country': 'Algeria',
#   'airport_id': 'ORN',
#   'latitude': '35.62390137',
#   'longitude': '-0.621182978',
#   'altitude': 295},
#  {'airport_name': 'Sidi Bel Abbes Airport',
#   'city': 'Sidi Bel Abbes',
#   'country': 'Algeria',
#   'airport_id': 'BFW',
#   'latitude': '35.17179871',
#   'longitude': '-0.593275011',
#   'altitude': 1614},
#  {'airport_name': 'Ghriss Airport',
#   'city': 'Ghriss',
#   'country': 'Algeria',
#   'airport_id': 'MUW',
#   'latitude': '35.20769882',
#   'longitude': '0.147141993',
#   'altitude': 1686},
#  {'airport_name': 'Touat Cheikh Sidi Mohamed Belkebir Airport',
#   'city': 'Adrar',
#   'country': 'Algeria',
#   'airport_id': 'AZR',
#   'latitude': '27.83760071',
#   'longitude': '-0.186414003',
#   'altitude': 919},
#  {'airport_name': 'Biskra Airport',
#   'city': 'Biskra',
#   'country': 'Algeria',
#   'airport_id': 'BSK',
#   'latitude': '34.79330063',
#   'longitude': '5.738230228',
#   'altitude': 289},
#  {'airport_name': 'El Golea Airport',
#   'city': 'El Golea',
#   'country': 'Algeria',
#   'airport_id': 'ELG',
#   'latitude': '30.57130051',
#   'longitude': '2.859590054',
#   'altitude': 1306},
#  {'airport_name': 'Noumérat - Moufdi Zakaria Airport',
#   'city': 'Ghardaia',
#   'country': 'Algeria',
#   'airport_id': 'GHA',
#   'latitude': '32.38410187',
#   'longitude': '3.79411006',
#   'altitude': 1512},
#  {'airport_name': 'Oued Irara Airport',
#   'city': 'Hassi Messaoud',
#   'country': 'Algeria',
#   'airport_id': 'HME',
#   'latitude': '31.67300034',
#   'longitude': '6.140439987',
#   'altitude': 463},
#  {'airport_name': 'In Salah Airport',
#   'city': 'In Salah',
#   'country': 'Algeria',
#   'airport_id': 'INZ',
#   'latitude': '27.25099945',
#   'longitude': '2.512020111',
#   'altitude': 896},
#  {'airport_name': 'Touggourt Sidi Madhi Airport',
#   'city': 'Touggourt',
#   'country': 'Algeria',
#   'airport_id': 'TGR',
#   'latitude': '33.06779861',
#   'longitude': '6.088669777',
#   'altitude': 279},
#  {'airport_name': 'Laghouat Airport',
#   'city': 'Laghouat',
#   'country': 'Algeria',
#   'airport_id': 'LOO',
#   'latitude': '33.76440048',
#   'longitude': '2.928339958',
#   'altitude': 2510},
#  {'airport_name': 'Timimoun Airport',
#   'city': 'Timimoun',
#   'country': 'Algeria',
#   'airport_id': 'TMX',
#   'latitude': '29.2371006',
#   'longitude': '0.276033014',
#   'altitude': 1027},
#  {'airport_name': 'Ain el Beida Airport',
#   'city': 'Ouargla',
#   'country': 'Algeria',
#   'airport_id': 'OGX',
#   'latitude': '31.91720009',
#   'longitude': '5.412779808',
#   'altitude': 492},
#  {'airport_name': 'In Aménas Airport',
#   'city': 'Zarzaitine',
#   'country': 'Algeria',
#   'airport_id': 'IAM',
#   'latitude': '28.0515',
#   'longitude': '9.64291',
#   'altitude': 1847},
#  {'airport_name': 'Cadjehoun Airport',
#   'city': 'Cotonou',
#   'country': 'Benin',
#   'airport_id': 'COO',
#   'latitude': '6.357230186',
#   'longitude': '2.384350061',
#   'altitude': 19},
#  {'airport_name': 'Ouagadougou Airport',
#   'city': 'Ouagadougou',
#   'country': 'Burkina Faso',
#   'airport_id': 'OUA',
#   'latitude': '12.3532',
#   'longitude': '-1.51242',
#   'altitude': 1037},
#  {'airport_name': 'Bobo Dioulasso Airport',
#   'city': 'Bobo-dioulasso',
#   'country': 'Burkina Faso',
#   'airport_id': 'BOY',
#   'latitude': '11.16009998',
#   'longitude': '-4.33096981',
#   'altitude': 1511},
#  {'airport_name': 'Kotoka International Airport',
#   'city': 'Accra',
#   'country': 'Ghana',
#   'airport_id': 'ACC',
#   'latitude': '5.6051898',
#   'longitude': '-0.166786',
#   'altitude': 205},
#  {'airport_name': 'Tamale Airport',
#   'city': 'Tamale',
#   'country': 'Ghana',
#   'airport_id': 'TML',
#   'latitude': '9.557189941',
#   'longitude': '-0.863214016',
#   'altitude': 553},
#  {'airport_name': 'Sunyani Airport',
#   'city': 'Sunyani',
#   'country': 'Ghana',
#   'airport_id': 'NYI',
#   'latitude': '7.361830235',
#   'longitude': '-2.328759909',
#   'altitude': 1014},
#  {'airport_name': 'Takoradi Airport',
#   'city': 'Takoradi',
#   'country': 'Ghana',
#   'airport_id': 'TKD',
#   'latitude': '4.89605999',
#   'longitude': '-1.774760008',
#   'altitude': 21},
#  {'airport_name': 'Port Bouet Airport',
#   'city': 'Abidjan',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'ABJ',
#   'latitude': '5.261390209',
#   'longitude': '-3.926290035',
#   'altitude': 21},
#  {'airport_name': 'Bouaké Airport',
#   'city': 'Bouake',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'BYK',
#   'latitude': '7.738800049',
#   'longitude': '-5.07366991',
#   'altitude': 1230},
#  {'airport_name': 'Daloa Airport',
#   'city': 'Daloa',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'DJO',
#   'latitude': '6.792809963',
#   'longitude': '-6.473189831',
#   'altitude': 823},
#  {'airport_name': 'Korhogo Airport',
#   'city': 'Korhogo',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'HGO',
#   'latitude': '9.387180328',
#   'longitude': '-5.556660175',
#   'altitude': 1214},
#  {'airport_name': 'Man Airport',
#   'city': 'Man',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'MJC',
#   'latitude': '7.272069931',
#   'longitude': '-7.587359905',
#   'altitude': 1089},
#  {'airport_name': 'San Pedro Airport',
#   'city': 'San Pedro',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'SPY',
#   'latitude': '4.746719837',
#   'longitude': '-6.660820007',
#   'altitude': 26},
#  {'airport_name': 'Yamoussoukro Airport',
#   'city': 'Yamoussoukro',
#   'country': "Cote d'Ivoire",
#   'airport_id': 'ASK',
#   'latitude': '6.903170109',
#   'longitude': '-5.365580082',
#   'altitude': 699},
#  {'airport_name': 'Nnamdi Azikiwe International Airport',
#   'city': 'Abuja',
#   'country': 'Nigeria',
#   'airport_id': 'ABV',
#   'latitude': '9.006790161',
#   'longitude': '7.263169765',
#   'altitude': 1123},
#  {'airport_name': 'Akure Airport',
#   'city': 'Akure',
#   'country': 'Nigeria',
#   'airport_id': 'AKR',
# ...
#   'country': 'Sudan',
#   'airport_id': 'MAK',
#   'latitude': '9.558970451',
#   'longitude': '31.6522007',
#   'altitude': 1291},
#  {'airport_name': 'Khartoum International Airport',
#   'city': 'Khartoum',
#   'country': 'Sudan',
#   'airport_id': 'KRT',
#   'latitude': '15.58950043',
#   'longitude': '32.55319977',
#   'altitude': 1265},
#  {'airport_name': 'Arusha Airport',
#   'city': 'Arusha',
#   'country': 'Tanzania',
#   'airport_id': 'ARK',
#   'latitude': '-3.367789984',
#   'longitude': '36.63330078',
#   'altitude': 4550},
#  {'airport_name': 'Julius Nyerere International Airport',
#   'city': 'Dar Es Salaam',
#   'country': 'Tanzania',
#   'airport_id': 'DAR',
#   'latitude': '-6.87811',
#   'longitude': '39.202599',
#   'altitude': 182},
#  {'airport_name': 'Dodoma Airport',
#   'city': 'Dodoma',
#   'country': 'Tanzania',
#   'airport_id': 'DOD',
#   'latitude': '-6.170440197',
#   'longitude': '35.75260162',
#   'altitude': 3673},
#  {'airport_name': 'Iringa Airport',
#   'city': 'Iringa',
#   'country': 'Tanzania',
#   'airport_id': 'IRI',
#   'latitude': '-7.668630123',
#   'longitude': '35.7521019',
#   'altitude': 4678},
#  {'airport_name': 'Kilimanjaro International Airport',
#   'city': 'Kilimanjaro',
#   'country': 'Tanzania',
#   'airport_id': 'JRO',
#   'latitude': '-3.429409981',
#   'longitude': '37.07450104',
#   'altitude': 2932},
#  {'airport_name': 'Lake Manyara Airport',
#   'city': 'Lake Manyara',
#   'country': 'Tanzania',
#   'airport_id': 'LKY',
#   'latitude': '-3.37631011',
#   'longitude': '35.81829834',
#   'altitude': 4150},
#  {'airport_name': 'Mtwara Airport',
#   'city': 'Mtwara',
#   'country': 'Tanzania',
#   'airport_id': 'MYW',
#   'latitude': '-10.33909988',
#   'longitude': '40.18180084',
#   'altitude': 371},
#  {'airport_name': 'Mwanza Airport',
#   'city': 'Mwanza',
#   'country': 'Tanzania',
#   'airport_id': 'MWZ',
#   'latitude': '-2.444489956',
#   'longitude': '32.93270111',
#   'altitude': 3763},
#  {'airport_name': 'Pemba Airport',
#   'city': 'Pemba',
#   'country': 'Tanzania',
#   'airport_id': 'PMA',
#   'latitude': '-5.257259846',
#   'longitude': '39.81140137',
#   'altitude': 80},
#  {'airport_name': 'Tanga Airport',
#   'city': 'Tanga',
#   'country': 'Tanzania',
#   'airport_id': 'TGT',
#   'latitude': '-5.09236002',
#   'longitude': '39.07120132',
#   'altitude': 129},
#  {'airport_name': 'Abeid Amani Karume International Airport',
#   'city': 'Zanzibar',
#   'country': 'Tanzania',
#   'airport_id': 'ZNZ',
#   'latitude': '-6.22202',
#   'longitude': '39.224899',
#   'altitude': 54},
#  {'airport_name': 'Entebbe International Airport',
#   'city': 'Entebbe',
#   'country': 'Uganda',
#   'airport_id': 'EBB',
#   'latitude': '0.042386',
#   'longitude': '32.443501',
#   'altitude': 3782},
#  {'airport_name': 'Soroti Airport',
#   'city': 'Soroti',
#   'country': 'Uganda',
#   'airport_id': 'SRT',
#   'latitude': '1.727689981',
#   'longitude': '33.62279892',
#   'altitude': 3697},
#  {'airport_name': 'Tirana International Airport Mother Teresa',
#   'city': 'Tirana',
#   'country': 'Albania',
#   'airport_id': 'TIA',
#   'latitude': '41.41469955',
#   'longitude': '19.72060013',
#   'altitude': 126},
#  {'airport_name': 'Burgas Airport',
#   'city': 'Bourgas',
#   'country': 'Bulgaria',
#   'airport_id': 'BOJ',
#   'latitude': '42.56959915',
#   'longitude': '27.51519966',
#   'altitude': 135},
#  {'airport_name': 'Gorna Oryahovitsa Airport',
#   'city': 'Gorna Orechovica',
#   'country': 'Bulgaria',
#   'airport_id': 'GOZ',
#   'latitude': '43.15140152',
#   'longitude': '25.71290016',
#   'altitude': 285},
#  {'airport_name': 'Plovdiv International Airport',
#   'city': 'Plovdiv',
#   'country': 'Bulgaria',
#   'airport_id': 'PDV',
#   'latitude': '42.067799',
#   'longitude': '24.8508',
#   'altitude': 597},
#  {'airport_name': 'Sofia Airport',
#   'city': 'Sofia',
#   'country': 'Bulgaria',
#   'airport_id': 'SOF',
#   'latitude': '42.69669342',
#   'longitude': '23.41143608',
#   'altitude': 1742},
#  {'airport_name': 'Stara Zagora Airport',
#   'city': 'Stara Zagora',
#   'country': 'Bulgaria',
#   'airport_id': 'SZR',
#   'latitude': '42.3766667',
#   'longitude': '25.655',
#   'altitude': 558},
#  {'airport_name': 'Varna Airport',
#   'city': 'Varna',
#   'country': 'Bulgaria',
#   'airport_id': 'VAR',
#   'latitude': '43.232101',
#   'longitude': '27.8251',
#   'altitude': 230},
#  {'airport_name': 'Larnaca International Airport',
#   'city': 'Larnaca',
#   'country': 'Cyprus',
#   'airport_id': 'LCA',
#   'latitude': '34.87509918',
#   'longitude': '33.62490082',
#   'altitude': 8},
#  {'airport_name': 'Paphos International Airport',
#   'city': 'Paphos',
#   'country': 'Cyprus',
#   'airport_id': 'PFO',
#   'latitude': '34.7179985',
#   'longitude': '32.4856987',
#   'altitude': 41},
#  {'airport_name': 'RAF Akrotiri',
#   'city': 'Akrotiri',
#   'country': 'Cyprus',
#   'airport_id': 'AKT',
#   'latitude': '34.590401',
#   'longitude': '32.9879',
#   'altitude': 76},
#  {'airport_name': 'Dubrovnik Airport',
#   'city': 'Dubrovnik',
#   'country': 'Croatia',
#   'airport_id': 'DBV',
#   'latitude': '42.56140137',
#   'longitude': '18.26819992',
#   'altitude': 527},
#  {'airport_name': 'Osijek Airport',
#   'city': 'Osijek',
#   'country': 'Croatia',
#   'airport_id': 'OSI',
#   'latitude': '45.46269989',
#   'longitude': '18.81019974',
#   'altitude': 290},
#  {'airport_name': 'Pula Airport',
#   'city': 'Pula',
#   'country': 'Croatia',
#   'airport_id': 'PUY',
#   'latitude': '44.89350128',
#   'longitude': '13.9222002',
#   'altitude': 274},
#  {'airport_name': 'Rijeka Airport',
#   'city': 'Rijeka',
#   'country': 'Croatia',
#   'airport_id': 'RJK',
#   'latitude': '45.21689987',
#   'longitude': '14.5703001',
#   'altitude': 278},
#  {'airport_name': 'Split Airport',
#   'city': 'Split',
#   'country': 'Croatia',
#   'airport_id': 'SPU',
#   'latitude': '43.53889847',
#   'longitude': '16.29800034',
#   'altitude': 79},
#  {'airport_name': 'Zagreb Airport',
#   'city': 'Zagreb',
#   'country': 'Croatia',
#   'airport_id': 'ZAG',
#   'latitude': '45.74290085',
#   'longitude': '16.06879997',
#   'altitude': 353},
#  {'airport_name': 'Zadar Airport',
#   'city': 'Zadar',
#   'country': 'Croatia',
#   'airport_id': 'ZAD',
#   'latitude': '44.108299',
#   'longitude': '15.3467',
#   'altitude': 289},
#  {'airport_name': 'Albacete-Los Llanos Airport',
#   'city': 'Albacete',
#   'country': 'Spain',
#   'airport_id': 'ABC',
#   'latitude': '38.94850159',
#   'longitude': '-1.863520026',
#   'altitude': 2302},
#  {'airport_name': 'Alicante International Airport',
#   'city': 'Alicante',
#   'country': 'Spain',
#   'airport_id': 'ALC',
#   'latitude': '38.28219986',
#   'longitude': '-0.558156013',
#   'altitude': 142},
#  {'airport_name': 'Almería International Airport',
#   'city': 'Almeria',
#   'country': 'Spain',
#   'airport_id': 'LEI',
#   'latitude': '36.84389877',
#   'longitude': '-2.370100021',
#   'altitude': 70},
#  {'airport_name': 'Asturias Airport',
#   'city': 'Aviles',
#   'country': 'Spain',
#   'airport_id': 'OVD',
#   'latitude': '43.56359863',
#   'longitude': '-6.034619808',
#   'altitude': 416},
#  {'airport_name': 'Córdoba Airport',
#   'city': 'Cordoba',
#   'country': 'Spain',
#   'airport_id': 'ODB',
#   'latitude': '37.84199905',
#   'longitude': '-4.848879814',
#   'altitude': 297},
#  {'airport_name': 'Bilbao Airport',
#   'city': 'Bilbao',
#   'country': 'Spain',
#   'airport_id': 'BIO',
#   'latitude': '43.30110168',
#   'longitude': '-2.910609961',
#   'altitude': 138},
#  {'airport_name': 'Barcelona International Airport',
#   'city': 'Barcelona',
#   'country': 'Spain',
#   'airport_id': 'BCN',
#   'latitude': '41.2971',
#   'longitude': '2.07846',
#   'altitude': 12},
#  {'airport_name': 'Badajoz Airport',
#   'city': 'Badajoz',
#   'country': 'Spain',
#   'airport_id': 'BJZ',
#   'latitude': '38.8913002',
#   'longitude': '-6.82133007',
#   'altitude': 609},
#  {'airport_name': 'A Coruña Airport',
#   'city': 'La Coruna',
#   'country': 'Spain',
#   'airport_id': 'LCG',
#   'latitude': '43.302101',
#   'longitude': '-8.37726',
#   'altitude': 326},
#  {'airport_name': 'Girona Airport',
#   'city': 'Gerona',
#   'country': 'Spain',
#   'airport_id': 'GRO',
#   'latitude': '41.90100098',
#   'longitude': '2.760550022',
#   'altitude': 468},
#  {'airport_name': 'Federico Garcia Lorca Airport',
#   'city': 'Granada',
#   'country': 'Spain',
#   'airport_id': 'GRX',
#   'latitude': '37.18870163',
#   'longitude': '-3.777359962',
#   'altitude': 1860},
#  {'airport_name': 'Ibiza Airport',
#   'city': 'Ibiza',
#   'country': 'Spain',
#   'airport_id': 'IBZ',
#   'latitude': '38.8728981',
#   'longitude': '1.37311995',
#   'altitude': 24},
#  {'airport_name': 'Jerez Airport',
#   'city': 'Jerez',
#   'country': 'Spain',
#   'airport_id': 'XRY',
#   'latitude': '36.74459839',
#   'longitude': '-6.060110092',
#   'altitude': 93},
#  {'airport_name': 'San Javier Airport',
#   'city': 'Murcia',
#   'country': 'Spain',
#   'airport_id': 'MJV',
#   'latitude': '37.77500153',
#   'longitude': '-0.812389016',
#   'altitude': 11},
#  {'airport_name': 'Adolfo Suárez Madrid–Barajas Airport',
#   'city': 'Madrid',
#   'country': 'Spain',
#   'airport_id': 'MAD',
#   'latitude': '40.471926',
#   'longitude': '-3.56264',
#   'altitude': 1998},
#  {'airport_name': 'Málaga Airport',
#   'city': 'Malaga',
#   'country': 'Spain',
#   'airport_id': 'AGP',
#   'latitude': '36.67490005',
#   'longitude': '-4.499110222',
#   'altitude': 53},
#  {'airport_name': 'Menorca Airport',
#   'city': 'Menorca',
#   'country': 'Spain',
#   'airport_id': 'MAH',
#   'latitude': '39.86259842',
#   'longitude': '4.218649864',
#   'altitude': 302},
#  {'airport_name': 'Moron Air Base',
#   'city': 'Sevilla',
#   'country': 'Spain',
#   'airport_id': 'OZP',
#   'latitude': '37.17490005',
#   'longitude': '-5.615940094',
#   'altitude': 285},
#  {'airport_name': 'Pamplona Airport',
#   'city': 'Pamplona',
#   'country': 'Spain',
#   'airport_id': 'PNA',
#   'latitude': '42.77000046',
#   'longitude': '-1.646329999',
#   'altitude': 1504},
#  {'airport_name': 'Reus Air Base',
#   'city': 'Reus',
#   'country': 'Spain',
#   'airport_id': 'REU',
#   'latitude': '41.1473999',
#   'longitude': '1.167170048',
#   'altitude': 233},
#  {'airport_name': 'Rota Naval Station Airport',
#   'city': 'Rota',
#   'country': 'Spain',
#   'airport_id': 'ROZ',
#   'latitude': '36.64519882',
#   'longitude': '-6.349460125',
#   'altitude': 86},
#  {'airport_name': 'Salamanca Airport',
#   'city': 'Salamanca',
#   'country': 'Spain',
#   'airport_id': 'SLM',
#   'latitude': '40.95209885',
#   'longitude': '-5.501989841',
#   'altitude': 2595},
#  {'airport_name': 'San Sebastian Airport',
#   'city': 'San Sebastian',
#   'country': 'Spain',
#   'airport_id': 'EAS',
#   'latitude': '43.35649872',
#   'longitude': '-1.790609956',
#   'altitude': 16},
#  {'airport_name': 'Santiago de Compostela Airport',
#   'city': 'Santiago',
#   'country': 'Spain',
#   'airport_id': 'SCQ',
#   'latitude': '42.89630127',
#   'longitude': '-8.415140152',
#   'altitude': 1213},
#  {'airport_name': "Pirineus - la Seu d'Urgel Airport",
#   'city': 'Seo De Urgel',
#   'country': 'Spain',
#   'airport_id': 'LEU',
#   'latitude': '42.3386',
#   'longitude': '1.40917',
#   'altitude': 2625},
#  {'airport_name': 'Torrejón Airport',
#   'city': 'Madrid',
#   'country': 'Spain',
#   'airport_id': 'TOJ',
#   'latitude': '40.49670029',
#   'longitude': '-3.445869923',
#   'altitude': 2026},
#  {'airport_name': 'Valencia Airport',
#   'city': 'Valencia',
#   'country': 'Spain',
#   'airport_id': 'VLC',
#   'latitude': '39.4893',
#   'longitude': '-0.481625',
#   'altitude': 240},
#  {'airport_name': 'Valladolid Airport',
#   'city': 'Valladolid',
#   'country': 'Spain',
#   'airport_id': 'VLL',
#   'latitude': '41.70610046',
#   'longitude': '-4.851940155',
#   'altitude': 2776},
#  {'airport_name': 'Vitoria/Foronda Airport',
#   'city': 'Vitoria',
#   'country': 'Spain',
#   'airport_id': 'VIT',
#   'latitude': '42.88280106',
#   'longitude': '-2.7244699',
#   'altitude': 1682},
#  {'airport_name': 'Vigo Airport',
#   'city': 'Vigo',
#   'country': 'Spain',
#   'airport_id': 'VGO',
#   'latitude': '42.23180008',
#   'longitude': '-8.62677002',
#   'altitude': 856},
#  {'airport_name': 'Santander Airport',
#   'city': 'Santander',
#   'country': 'Spain',
#   'airport_id': 'SDR',
#   'latitude': '43.42710114',
#   'longitude': '-3.820009947',
#   'altitude': 16},
#  {'airport_name': 'Zaragoza Air Base',
#   'city': 'Zaragoza',
#   'country': 'Spain',
#   'airport_id': 'ZAZ',
#   'latitude': '41.66619873',
#   'longitude': '-1.04155004',
#   'altitude': 863},
#  {'airport_name': 'Sevilla Airport',
#   'city': 'Sevilla',
#   'country': 'Spain',
#   'airport_id': 'SVQ',
#   'latitude': '37.41799927',
#   'longitude': '-5.893109798',
#   'altitude': 112},
#  {'airport_name': 'Calais-Dunkerque Airport',
#   'city': 'Calais',
#   'country': 'France',
#   'airport_id': 'CQF',
#   'latitude': '50.96210098',
#   'longitude': '1.954759955',
#   'altitude': 12},
#  {'airport_name': 'Albert-Bray Airport',
#   'city': 'Albert',
#   'country': 'France',
#   'airport_id': 'BYF',
#   'latitude': '49.9715004',
#   'longitude': '2.697659969',
#   'altitude': 364},
#  {'airport_name': "Le Touquet-Côte d'Opale Airport",
#   'city': 'Le Tourquet',
#   'country': 'France',
#   'airport_id': 'LTQ',
#   'latitude': '50.51739883',
#   'longitude': '1.620589972',
#   'altitude': 36},
#  {'airport_name': 'Valenciennes-Denain Airport',
#   'city': 'Valenciennes',
#   'country': 'France',
#   'airport_id': 'XVS',
#   'latitude': '50.32580185',
#   'longitude': '3.46126008',
#   'altitude': 177},
#  {'airport_name': 'Agen-La Garenne Airport',
#   'city': 'Agen',
#   'country': 'France',
#   'airport_id': 'AGF',
#   'latitude': '44.17470169',
#   'longitude': '0.590556026',
#   'altitude': 204},
#  {'airport_name': 'Bordeaux-Mérignac Airport',
#   'city': 'Bordeaux',
#   'country': 'France',
#   'airport_id': 'BOD',
#   'latitude': '44.82830048',
#   'longitude': '-0.715556026',
#   'altitude': 162},
#  {'airport_name': 'Bergerac-Roumanière Airport',
#   'city': 'Bergerac',
#   'country': 'France',
#   'airport_id': 'EGC',
#   'latitude': '44.82529831',
#   'longitude': '0.518611014',
#   'altitude': 171},
#  {'airport_name': 'Cognac-Châteaubernard (BA 709) Air Base',
#   'city': 'Cognac',
#   'country': 'France',
#   'airport_id': 'CNG',
#   'latitude': '45.65829849',
#   'longitude': '-0.317499995',
#   'altitude': 102},
#  {'airport_name': 'Poitiers-Biard Airport',
#   'city': 'Poitiers',
#   'country': 'France',
#   'airport_id': 'PIS',
#   'latitude': '46.58769989',
#   'longitude': '0.306665987',
#   'altitude': 423},
#  {'airport_name': 'Montluçon-Guéret Airport',
#   'city': 'Montlucon-gueret',
#   'country': 'France',
#   'airport_id': 'MCU',
#   'latitude': '46.22259903',
#   'longitude': '2.363960028',
#   'altitude': 1497},
#  {'airport_name': 'Limoges Airport',
#   'city': 'Limoges',
#   'country': 'France',
#   'airport_id': 'LIG',
#   'latitude': '45.8628006',
#   'longitude': '1.179440022',
#   'altitude': 1300},
#  {'airport_name': 'Niort-Souché Airport',
#   'city': 'Niort',
#   'country': 'France',
#   'airport_id': 'NIT',
#   'latitude': '46.313477',
#   'longitude': '-0.394529',
#   'altitude': 203},
#  {'airport_name': 'Toulouse-Blagnac Airport',
#   'city': 'Toulouse',
#   'country': 'France',
#   'airport_id': 'TLS',
#   'latitude': '43.629101',
#   'longitude': '1.36382',
#   'altitude': 499},
#  {'airport_name': 'Pau Pyrénées Airport',
#   'city': 'Pau',
#   'country': 'France',
#   'airport_id': 'PUF',
#   'latitude': '43.38000107',
#   'longitude': '-0.41861099',
#   'altitude': 616},
#  {'airport_name': 'Tarbes-Lourdes-Pyrénées Airport',
#   'city': 'Tarbes',
#   'country': 'France',
#   'airport_id': 'LDE',
#   'latitude': '43.17869949',
#   'longitude': '-0.006439',
#   'altitude': 1260},
#  {'airport_name': 'Angoulême-Brie-Champniers Airport',
#   'city': 'Angouleme',
#   'country': 'France',
#   'airport_id': 'ANG',
#   'latitude': '45.72919846',
#   'longitude': '0.221456006',
#   'altitude': 436},
#  {'airport_name': 'Brive Souillac Airport',
#   'city': 'Brive',
#   'country': 'France',
#   'airport_id': 'BVE',
#   'latitude': '45.039722',
#   'longitude': '1.485556',
#   'altitude': 1016},
#  {'airport_name': 'Périgueux-Bassillac Airport',
#   'city': 'Perigueux',
#   'country': 'France',
#   'airport_id': 'PGX',
#   'latitude': '45.19810104',
#   'longitude': '0.81555599',
#   'altitude': 328},
#  {'airport_name': 'Biarritz-Anglet-Bayonne Airport',
#   'city': 'Biarritz-bayonne',
#   'country': 'France',
#   'airport_id': 'BIQ',
#   'latitude': '43.4683333',
#   'longitude': '-1.5311111',
#   'altitude': 245},
#  {'airport_name': 'Cahors-Lalbenque Airport',
#   'city': 'Cahors',
#   'country': 'France',
#   'airport_id': 'ZAO',
#   'latitude': '44.35139847',
#   'longitude': '1.475280046',
#   'altitude': 912},
#  ...]

# %%
flights_dict = [columns_to_dict(row) for row in session.query(Flights).all()]
flights_dict
# Out:
# [{'index': 0,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 515,
#   'sched_arr_time': 819,
#   'airline_id': 'UA',
#   'flight': 1545,
#   'tailnum': 'N14228',
#   'origin': 'EWR',
#   'dest': 'IAH',
#   'air_time': 227.0,
#   'distance': 1400,
#   'hour': 5,
#   'minute': 15},
#  {'index': 1,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 529,
#   'sched_arr_time': 830,
#   'airline_id': 'UA',
#   'flight': 1714,
#   'tailnum': 'N24211',
#   'origin': 'LGA',
#   'dest': 'IAH',
#   'air_time': 227.0,
#   'distance': 1416,
#   'hour': 5,
#   'minute': 29},
#  {'index': 2,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 540,
#   'sched_arr_time': 850,
#   'airline_id': 'AA',
#   'flight': 1141,
#   'tailnum': 'N619AA',
#   'origin': 'JFK',
#   'dest': 'MIA',
#   'air_time': 160.0,
#   'distance': 1089,
#   'hour': 5,
#   'minute': 40},
#  {'index': 3,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 545,
#   'sched_arr_time': 1022,
#   'airline_id': 'B6',
#   'flight': 725,
#   'tailnum': 'N804JB',
#   'origin': 'JFK',
#   'dest': 'BQN',
#   'air_time': 183.0,
#   'distance': 1576,
#   'hour': 5,
#   'minute': 45},
#  {'index': 4,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 837,
#   'airline_id': 'DL',
#   'flight': 461,
#   'tailnum': 'N668DN',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 116.0,
#   'distance': 762,
#   'hour': 6,
#   'minute': 0},
#  {'index': 5,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 558,
#   'sched_arr_time': 728,
#   'airline_id': 'UA',
#   'flight': 1696,
#   'tailnum': 'N39463',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': 150.0,
#   'distance': 719,
#   'hour': 5,
#   'minute': 58},
#  {'index': 6,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 854,
#   'airline_id': 'B6',
#   'flight': 507,
#   'tailnum': 'N516JB',
#   'origin': 'EWR',
#   'dest': 'FLL',
#   'air_time': 158.0,
#   'distance': 1065,
#   'hour': 6,
#   'minute': 0},
#  {'index': 7,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 723,
#   'airline_id': 'EV',
#   'flight': 5708,
#   'tailnum': 'N829AS',
#   'origin': 'LGA',
#   'dest': 'IAD',
#   'air_time': 53.0,
#   'distance': 229,
#   'hour': 6,
#   'minute': 0},
#  {'index': 8,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 846,
#   'airline_id': 'B6',
#   'flight': 79,
#   'tailnum': 'N593JB',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': 140.0,
#   'distance': 944,
#   'hour': 6,
#   'minute': 0},
#  {'index': 9,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 745,
#   'airline_id': 'AA',
#   'flight': 301,
#   'tailnum': 'N3ALAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 138.0,
#   'distance': 733,
#   'hour': 6,
#   'minute': 0},
#  {'index': 10,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 851,
#   'airline_id': 'B6',
#   'flight': 49,
#   'tailnum': 'N793JB',
#   'origin': 'JFK',
#   'dest': 'PBI',
#   'air_time': 149.0,
#   'distance': 1028,
#   'hour': 6,
#   'minute': 0},
#  {'index': 11,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 856,
#   'airline_id': 'B6',
#   'flight': 71,
#   'tailnum': 'N657JB',
#   'origin': 'JFK',
#   'dest': 'TPA',
#   'air_time': 158.0,
#   'distance': 1005,
#   'hour': 6,
#   'minute': 0},
#  {'index': 12,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 917,
#   'airline_id': 'UA',
#   'flight': 194,
#   'tailnum': 'N29129',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 345.0,
#   'distance': 2475,
#   'hour': 6,
#   'minute': 0},
#  {'index': 13,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 937,
#   'airline_id': 'UA',
#   'flight': 1124,
#   'tailnum': 'N53441',
#   'origin': 'EWR',
#   'dest': 'SFO',
#   'air_time': 361.0,
#   'distance': 2565,
#   'hour': 6,
#   'minute': 0},
#  {'index': 14,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 910,
#   'airline_id': 'AA',
#   'flight': 707,
#   'tailnum': 'N3DUAA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': 257.0,
#   'distance': 1389,
#   'hour': 6,
#   'minute': 0},
#  {'index': 15,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 559,
#   'sched_arr_time': 706,
#   'airline_id': 'B6',
#   'flight': 1806,
#   'tailnum': 'N708JB',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': 44.0,
#   'distance': 187,
#   'hour': 5,
#   'minute': 59},
#  {'index': 16,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 902,
#   'airline_id': 'UA',
#   'flight': 1187,
#   'tailnum': 'N76515',
#   'origin': 'EWR',
#   'dest': 'LAS',
#   'air_time': 337.0,
#   'distance': 2227,
#   'hour': 6,
#   'minute': 0},
#  {'index': 17,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 858,
#   'airline_id': 'B6',
#   'flight': 371,
#   'tailnum': 'N595JB',
#   'origin': 'LGA',
#   'dest': 'FLL',
#   'air_time': 152.0,
#   'distance': 1076,
#   'hour': 6,
#   'minute': 0},
#  {'index': 18,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 825,
#   'airline_id': 'MQ',
#   'flight': 4650,
#   'tailnum': 'N542MQ',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 134.0,
#   'distance': 762,
#   'hour': 6,
#   'minute': 0},
#  {'index': 19,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 850,
#   'airline_id': 'B6',
#   'flight': 343,
#   'tailnum': 'N644JB',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': 147.0,
#   'distance': 1023,
#   'hour': 6,
#   'minute': 0},
#  {'index': 20,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 610,
#   'sched_arr_time': 820,
#   'airline_id': 'DL',
#   'flight': 1919,
#   'tailnum': 'N971DL',
#   'origin': 'LGA',
#   'dest': 'MSP',
#   'air_time': 170.0,
#   'distance': 1020,
#   'hour': 6,
#   'minute': 10},
#  {'index': 21,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 605,
#   'sched_arr_time': 805,
#   'airline_id': 'MQ',
#   'flight': 4401,
#   'tailnum': 'N730MQ',
#   'origin': 'LGA',
#   'dest': 'DTW',
#   'air_time': 105.0,
#   'distance': 502,
#   'hour': 6,
#   'minute': 5},
#  {'index': 22,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 610,
#   'sched_arr_time': 910,
#   'airline_id': 'AA',
#   'flight': 1895,
#   'tailnum': 'N633AA',
#   'origin': 'EWR',
#   'dest': 'MIA',
#   'air_time': 152.0,
#   'distance': 1085,
#   'hour': 6,
#   'minute': 10},
#  {'index': 23,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 610,
#   'sched_arr_time': 845,
#   'airline_id': 'DL',
#   'flight': 1743,
#   'tailnum': 'N3739P',
#   'origin': 'JFK',
#   'dest': 'ATL',
#   'air_time': 128.0,
#   'distance': 760,
#   'hour': 6,
#   'minute': 10},
#  {'index': 24,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 607,
#   'sched_arr_time': 915,
#   'airline_id': 'UA',
#   'flight': 1077,
#   'tailnum': 'N53442',
#   'origin': 'EWR',
#   'dest': 'MIA',
#   'air_time': 157.0,
#   'distance': 1085,
#   'hour': 6,
#   'minute': 7},
#  {'index': 25,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 735,
#   'airline_id': 'MQ',
#   'flight': 3768,
#   'tailnum': 'N9EAMQ',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': 139.0,
#   'distance': 719,
#   'hour': 6,
#   'minute': 0},
#  {'index': 26,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 600,
#   'sched_arr_time': 931,
#   'airline_id': 'UA',
#   'flight': 303,
#   'tailnum': 'N532UA',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 366.0,
#   'distance': 2586,
#   'hour': 6,
#   'minute': 0},
#  {'index': 27,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 610,
#   'sched_arr_time': 921,
#   'airline_id': 'B6',
#   'flight': 135,
#   'tailnum': 'N635JB',
#   'origin': 'JFK',
#   'dest': 'RSW',
#   'air_time': 175.0,
#   'distance': 1074,
#   'hour': 6,
#   'minute': 10},
#  {'index': 28,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 615,
#   'sched_arr_time': 1100,
#   'airline_id': 'B6',
#   'flight': 709,
#   'tailnum': 'N794JB',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 182.0,
#   'distance': 1598,
#   'hour': 6,
#   'minute': 15},
#  {'index': 29,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 615,
#   'sched_arr_time': 842,
#   'airline_id': 'DL',
#   'flight': 575,
#   'tailnum': 'N326NB',
#   'origin': 'EWR',
#   'dest': 'ATL',
#   'air_time': 120.0,
#   'distance': 746,
#   'hour': 6,
#   'minute': 15},
#  {'index': 30,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 1014,
#   'airline_id': 'US',
#   'flight': 245,
#   'tailnum': 'N807AW',
#   'origin': 'EWR',
#   'dest': 'PHX',
#   'air_time': 342.0,
#   'distance': 2133,
#   'hour': 6,
#   'minute': 30},
#  {'index': 31,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 610,
#   'sched_arr_time': 915,
#   'airline_id': 'AA',
#   'flight': 1837,
#   'tailnum': 'N3EMAA',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 153.0,
#   'distance': 1096,
#   'hour': 6,
#   'minute': 10},
#  {'index': 32,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 627,
#   'sched_arr_time': 932,
#   'airline_id': 'UA',
#   'flight': 496,
#   'tailnum': 'N459UA',
#   'origin': 'LGA',
#   'dest': 'IAH',
#   'air_time': 229.0,
#   'distance': 1416,
#   'hour': 6,
#   'minute': 27},
#  {'index': 33,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 840,
#   'airline_id': 'EV',
#   'flight': 4626,
#   'tailnum': 'N11107',
#   'origin': 'EWR',
#   'dest': 'MSP',
#   'air_time': 190.0,
#   'distance': 1008,
#   'hour': 6,
#   'minute': 30},
#  {'index': 34,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 830,
#   'airline_id': 'MQ',
#   'flight': 4599,
#   'tailnum': 'N518MQ',
#   'origin': 'LGA',
#   'dest': 'MSP',
#   'air_time': 166.0,
#   'distance': 1020,
#   'hour': 6,
#   'minute': 30},
#  {'index': 35,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 1018,
#   'airline_id': 'US',
#   'flight': 27,
#   'tailnum': 'N535UW',
#   'origin': 'JFK',
#   'dest': 'PHX',
#   'air_time': 330.0,
#   'distance': 2153,
#   'hour': 6,
#   'minute': 30},
#  {'index': 36,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 1140,
#   'airline_id': 'AA',
#   'flight': 413,
#   'tailnum': 'N3BAAA',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 192.0,
#   'distance': 1598,
#   'hour': 6,
#   'minute': 30},
#  {'index': 37,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 947,
#   'airline_id': 'UA',
#   'flight': 1665,
#   'tailnum': 'N33289',
#   'origin': 'EWR',
#   'dest': 'LAX',
#   'air_time': 366.0,
#   'distance': 2454,
#   'hour': 6,
#   'minute': 30},
#  {'index': 38,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 810,
#   'airline_id': 'AA',
#   'flight': 303,
#   'tailnum': 'N3CYAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 140.0,
#   'distance': 733,
#   'hour': 6,
#   'minute': 30},
#  {'index': 39,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 740,
#   'airline_id': 'WN',
#   'flight': 4646,
#   'tailnum': 'N273WN',
#   'origin': 'LGA',
#   'dest': 'BWI',
#   'air_time': 40.0,
#   'distance': 185,
#   'hour': 6,
#   'minute': 30},
#  {'index': 40,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 833,
#   'airline_id': 'US',
#   'flight': 1019,
#   'tailnum': 'N426US',
#   'origin': 'EWR',
#   'dest': 'CLT',
#   'air_time': 91.0,
#   'distance': 529,
#   'hour': 6,
#   'minute': 30},
#  {'index': 41,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 608,
#   'sched_arr_time': 728,
#   'airline_id': 'EV',
#   'flight': 4144,
#   'tailnum': 'N13553',
#   'origin': 'EWR',
#   'dest': 'IAD',
#   'air_time': 52.0,
#   'distance': 212,
#   'hour': 6,
#   'minute': 8},
#  {'index': 42,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 635,
#   'sched_arr_time': 940,
#   'airline_id': 'AA',
#   'flight': 711,
#   'tailnum': 'N3GKAA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': 248.0,
#   'distance': 1389,
#   'hour': 6,
#   'minute': 35},
#  {'index': 43,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 645,
#   'sched_arr_time': 935,
#   'airline_id': 'B6',
#   'flight': 389,
#   'tailnum': 'N709JB',
#   'origin': 'LGA',
#   'dest': 'MCO',
#   'air_time': 144.0,
#   'distance': 950,
#   'hour': 6,
#   'minute': 45},
#  {'index': 44,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 640,
#   'sched_arr_time': 749,
#   'airline_id': 'B6',
#   'flight': 1002,
#   'tailnum': 'N805JB',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': 41.0,
#   'distance': 187,
#   'hour': 6,
#   'minute': 40},
#  {'index': 45,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 646,
#   'sched_arr_time': 940,
#   'airline_id': 'UA',
#   'flight': 556,
#   'tailnum': 'N497UA',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': 146.0,
#   'distance': 1023,
#   'hour': 6,
#   'minute': 46},
#  {'index': 46,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 645,
#   'sched_arr_time': 848,
#   'airline_id': 'US',
#   'flight': 926,
#   'tailnum': 'N178US',
#   'origin': 'EWR',
#   'dest': 'CLT',
#   'air_time': 91.0,
#   'distance': 529,
#   'hour': 6,
#   'minute': 45},
#  {'index': 47,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 636,
#   'sched_arr_time': 940,
#   'airline_id': 'UA',
#   'flight': 1701,
#   'tailnum': 'N75435',
#   'origin': 'EWR',
#   'dest': 'FLL',
#   'air_time': 151.0,
#   'distance': 1065,
#   'hour': 6,
#   'minute': 36},
#  {'index': 48,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 647,
#   'sched_arr_time': 810,
#   'airline_id': 'B6',
#   'flight': 102,
#   'tailnum': 'N796JB',
#   'origin': 'JFK',
#   'dest': 'BUF',
#   'air_time': 63.0,
#   'distance': 301,
#   'hour': 6,
#   'minute': 47},
#  {'index': 49,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 645,
#   'sched_arr_time': 916,
#   'airline_id': 'UA',
#   'flight': 883,
#   'tailnum': 'N569UA',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 243.0,
#   'distance': 1620,
#   'hour': 6,
#   'minute': 45},
#  {'index': 50,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 645,
#   'sched_arr_time': 1030,
#   'airline_id': 'UA',
#   'flight': 1496,
#   'tailnum': 'N38727',
#   'origin': 'EWR',
#   'dest': 'SNA',
#   'air_time': 380.0,
#   'distance': 2434,
#   'hour': 6,
#   'minute': 45},
#  {'index': 51,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 655,
#   'sched_arr_time': 942,
#   'airline_id': 'B6',
#   'flight': 203,
#   'tailnum': 'N558JB',
#   'origin': 'JFK',
#   'dest': 'LAS',
#   'air_time': 323.0,
#   'distance': 2248,
#   'hour': 6,
#   'minute': 55},
#  {'index': 52,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 655,
#   'sched_arr_time': 921,
#   'airline_id': 'B6',
#   'flight': 117,
#   'tailnum': 'N178JB',
#   'origin': 'JFK',
#   'dest': 'MSY',
#   'air_time': 191.0,
#   'distance': 1182,
#   'hour': 6,
#   'minute': 55},
#  {'index': 53,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1009,
#   'airline_id': 'DL',
#   'flight': 1383,
#   'tailnum': 'N327NW',
#   'origin': 'LGA',
#   'dest': 'PBI',
#   'air_time': 149.0,
#   'distance': 1035,
#   'hour': 7,
#   'minute': 0},
#  {'index': 54,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 655,
#   'sched_arr_time': 1030,
#   'airline_id': 'DL',
#   'flight': 1415,
#   'tailnum': 'N3763D',
#   'origin': 'JFK',
#   'dest': 'SLC',
#   'air_time': 294.0,
#   'distance': 1990,
#   'hour': 6,
#   'minute': 55},
#  {'index': 55,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1045,
#   'airline_id': 'DL',
#   'flight': 1865,
#   'tailnum': 'N705TW',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 362.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 0},
#  {'index': 56,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1020,
#   'airline_id': 'DL',
#   'flight': 2003,
#   'tailnum': 'N997DL',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 161.0,
#   'distance': 1096,
#   'hour': 7,
#   'minute': 0},
#  {'index': 57,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 850,
#   'airline_id': 'AA',
#   'flight': 305,
#   'tailnum': 'N4WNAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 143.0,
#   'distance': 733,
#   'hour': 7,
#   'minute': 0},
#  {'index': 58,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 659,
#   'sched_arr_time': 959,
#   'airline_id': 'AA',
#   'flight': 1815,
#   'tailnum': 'N5FMAA',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': 142.0,
#   'distance': 944,
#   'hour': 6,
#   'minute': 59},
#  {'index': 59,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 705,
#   'sched_arr_time': 940,
#   'airline_id': 'MQ',
#   'flight': 4534,
#   'tailnum': 'N722MQ',
#   'origin': 'LGA',
#   'dest': 'XNA',
#   'air_time': 233.0,
#   'distance': 1147,
#   'hour': 7,
#   'minute': 5},
#  {'index': 60,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1011,
#   'airline_id': 'UA',
#   'flight': 1115,
#   'tailnum': 'N24212',
#   'origin': 'EWR',
#   'dest': 'TPA',
#   'air_time': 156.0,
#   'distance': 997,
#   'hour': 7,
#   'minute': 0},
#  {'index': 61,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1013,
#   'airline_id': 'DL',
#   'flight': 1879,
#   'tailnum': 'N318NB',
#   'origin': 'LGA',
#   'dest': 'FLL',
#   'air_time': 164.0,
#   'distance': 1076,
#   'hour': 7,
#   'minute': 0},
#  {'index': 62,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 939,
#   'airline_id': 'DL',
#   'flight': 1547,
#   'tailnum': 'N6703D',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 126.0,
#   'distance': 762,
#   'hour': 7,
#   'minute': 0},
#  {'index': 63,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1025,
#   'airline_id': 'VX',
#   'flight': 399,
#   'tailnum': 'N627VA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 361.0,
#   'distance': 2475,
#   'hour': 7,
#   'minute': 0},
#  {'index': 64,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1015,
#   'airline_id': 'AA',
#   'flight': 2279,
#   'tailnum': 'N3EKAA',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 159.0,
#   'distance': 1096,
#   'hour': 7,
#   'minute': 0},
#  {'index': 65,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1007,
#   'airline_id': 'B6',
#   'flight': 981,
#   'tailnum': 'N646JB',
#   'origin': 'JFK',
#   'dest': 'FLL',
#   'air_time': 156.0,
#   'distance': 1069,
#   'hour': 7,
#   'minute': 0},
#  {'index': 66,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 705,
#   'sched_arr_time': 913,
#   'airline_id': 'DL',
#   'flight': 831,
#   'tailnum': 'N998DL',
#   'origin': 'LGA',
#   'dest': 'DTW',
#   'air_time': 105.0,
#   'distance': 502,
#   'hour': 7,
#   'minute': 5},
#  {'index': 67,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1008,
#   'airline_id': 'UA',
#   'flight': 960,
#   'tailnum': 'N838UA',
#   'origin': 'EWR',
#   'dest': 'RSW',
#   'air_time': 164.0,
#   'distance': 1068,
#   'hour': 7,
#   'minute': 0},
#  {'index': 68,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1154,
#   'airline_id': 'UA',
#   'flight': 1203,
#   'tailnum': 'N77296',
#   'origin': 'EWR',
#   'dest': 'SJU',
#   'air_time': 188.0,
#   'distance': 1608,
#   'hour': 7,
#   'minute': 0},
#  {'index': 69,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1014,
#   'airline_id': 'B6',
#   'flight': 671,
#   'tailnum': 'N779JB',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 381.0,
#   'distance': 2475,
#   'hour': 7,
#   'minute': 0},
#  {'index': 70,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 700,
#   'sched_arr_time': 832,
#   'airline_id': 'UA',
#   'flight': 1092,
#   'tailnum': 'N26226',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 135.0,
#   'distance': 733,
#   'hour': 7,
#   'minute': 0},
#  {'index': 71,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 715,
#   'sched_arr_time': 1206,
#   'airline_id': 'B6',
#   'flight': 715,
#   'tailnum': 'N651JB',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 190.0,
#   'distance': 1598,
#   'hour': 7,
#   'minute': 15},
#  {'index': 72,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 715,
#   'sched_arr_time': 1035,
#   'airline_id': 'AA',
#   'flight': 825,
#   'tailnum': 'N3ETAA',
#   'origin': 'JFK',
#   'dest': 'FLL',
#   'air_time': 159.0,
#   'distance': 1069,
#   'hour': 7,
#   'minute': 15},
#  {'index': 73,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 713,
#   'sched_arr_time': 850,
#   'airline_id': 'UA',
#   'flight': 544,
#   'tailnum': 'N841UA',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': 156.0,
#   'distance': 719,
#   'hour': 7,
#   'minute': 13},
#  {'index': 74,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 720,
#   'sched_arr_time': 840,
#   'airline_id': 'FL',
#   'flight': 850,
#   'tailnum': 'N978AT',
#   'origin': 'LGA',
#   'dest': 'MKE',
#   'air_time': 134.0,
#   'distance': 738,
#   'hour': 7,
#   'minute': 20},
#  {'index': 75,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 721,
#   'sched_arr_time': 1012,
#   'airline_id': 'B6',
#   'flight': 987,
#   'tailnum': 'N562JB',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': 147.0,
#   'distance': 944,
#   'hour': 7,
#   'minute': 21},
#  {'index': 76,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 725,
#   'sched_arr_time': 1017,
#   'airline_id': 'UA',
#   'flight': 962,
#   'tailnum': 'N514UA',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': 153.0,
#   'distance': 1023,
#   'hour': 7,
#   'minute': 25},
#  {'index': 77,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1040,
#   'airline_id': 'AA',
#   'flight': 715,
#   'tailnum': 'N541AA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': 254.0,
#   'distance': 1389,
#   'hour': 7,
#   'minute': 30},
#  {'index': 78,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 725,
#   'sched_arr_time': 1030,
#   'airline_id': 'AS',
#   'flight': 11,
#   'tailnum': 'N594AS',
#   'origin': 'EWR',
#   'dest': 'SEA',
#   'air_time': 338.0,
#   'distance': 2402,
#   'hour': 7,
#   'minute': 25},
#  {'index': 79,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1040,
#   'airline_id': 'AA',
#   'flight': 2083,
#   'tailnum': 'N4WRAA',
#   'origin': 'EWR',
#   'dest': 'DFW',
#   'air_time': 238.0,
#   'distance': 1372,
#   'hour': 7,
#   'minute': 30},
#  {'index': 80,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 952,
#   'airline_id': 'UA',
#   'flight': 1162,
#   'tailnum': 'N37462',
#   'origin': 'EWR',
#   'dest': 'DEN',
#   'air_time': 254.0,
#   'distance': 1605,
#   'hour': 7,
#   'minute': 30},
#  {'index': 81,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 732,
#   'sched_arr_time': 1038,
#   'airline_id': 'UA',
#   'flight': 473,
#   'tailnum': 'N488UA',
#   'origin': 'LGA',
#   'dest': 'IAH',
#   'air_time': 238.0,
#   'distance': 1416,
#   'hour': 7,
#   'minute': 32},
#  {'index': 82,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1115,
#   'airline_id': 'VX',
#   'flight': 11,
#   'tailnum': 'N635VA',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 356.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 30},
#  {'index': 83,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 735,
#   'sched_arr_time': 858,
#   'airline_id': 'B6',
#   'flight': 20,
#   'tailnum': 'N304JB',
#   'origin': 'JFK',
#   'dest': 'ROC',
#   'air_time': 64.0,
#   'distance': 264,
#   'hour': 7,
#   'minute': 35},
#  {'index': 84,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 729,
#   'sched_arr_time': 1039,
#   'airline_id': 'B6',
#   'flight': 1601,
#   'tailnum': 'N563JB',
#   'origin': 'LGA',
#   'dest': 'RSW',
#   'air_time': 167.0,
#   'distance': 1080,
#   'hour': 7,
#   'minute': 29},
#  {'index': 85,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 645,
#   'sched_arr_time': 941,
#   'airline_id': 'UA',
#   'flight': 1111,
#   'tailnum': 'N37456',
#   'origin': 'EWR',
#   'dest': 'MCO',
#   'air_time': 145.0,
#   'distance': 937,
#   'hour': 6,
#   'minute': 45},
#  {'index': 86,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 736,
#   'sched_arr_time': 850,
#   'airline_id': 'B6',
#   'flight': 44,
#   'tailnum': 'N552JB',
#   'origin': 'JFK',
#   'dest': 'SYR',
#   'air_time': 54.0,
#   'distance': 209,
#   'hour': 7,
#   'minute': 36},
#  {'index': 87,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 737,
#   'sched_arr_time': 1113,
#   'airline_id': 'B6',
#   'flight': 643,
#   'tailnum': 'N625JB',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 350.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 37},
#  {'index': 88,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 745,
#   'sched_arr_time': 930,
#   'airline_id': 'AA',
#   'flight': 309,
#   'tailnum': 'N4WPAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 137.0,
#   'distance': 733,
#   'hour': 7,
#   'minute': 45},
#  {'index': 89,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 739,
#   'sched_arr_time': 1038,
#   'airline_id': 'UA',
#   'flight': 1479,
#   'tailnum': 'N37408',
#   'origin': 'EWR',
#   'dest': 'IAH',
#   'air_time': 249.0,
#   'distance': 1400,
#   'hour': 7,
#   'minute': 39},
#  {'index': 90,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 745,
#   'sched_arr_time': 1036,
#   'airline_id': 'B6',
#   'flight': 983,
#   'tailnum': 'N633JB',
#   'origin': 'LGA',
#   'dest': 'TPA',
#   'air_time': 158.0,
#   'distance': 1010,
#   'hour': 7,
#   'minute': 45},
#  {'index': 91,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1100,
#   'airline_id': 'AA',
#   'flight': 33,
#   'tailnum': 'N338AA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 358.0,
#   'distance': 2475,
#   'hour': 7,
#   'minute': 30},
#  {'index': 92,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 749,
#   'sched_arr_time': 1054,
#   'airline_id': 'B6',
#   'flight': 341,
#   'tailnum': 'N624JB',
#   'origin': 'JFK',
#   'dest': 'SRQ',
#   'air_time': 164.0,
#   'distance': 1041,
#   'hour': 7,
#   'minute': 49},
#  {'index': 93,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1056,
#   'airline_id': 'DL',
#   'flight': 495,
#   'tailnum': 'N3760C',
#   'origin': 'JFK',
#   'dest': 'SEA',
#   'air_time': 349.0,
#   'distance': 2422,
#   'hour': 7,
#   'minute': 30},
#  {'index': 94,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 745,
#   'sched_arr_time': 1125,
#   'airline_id': 'AA',
#   'flight': 59,
#   'tailnum': 'N336AA',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 378.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 45},
#  {'index': 95,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 746,
#   'sched_arr_time': 1129,
#   'airline_id': 'UA',
#   'flight': 1668,
#   'tailnum': 'N24224',
#   'origin': 'EWR',
#   'dest': 'SFO',
#   'air_time': 373.0,
#   'distance': 2565,
#   'hour': 7,
#   'minute': 46},
#  {'index': 96,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 710,
#   'sched_arr_time': 850,
#   'airline_id': 'MQ',
#   'flight': 3737,
#   'tailnum': 'N508MQ',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': 148.0,
#   'distance': 719,
#   'hour': 7,
#   'minute': 10},
#  {'index': 97,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 755,
#   'sched_arr_time': 1059,
#   'airline_id': 'DL',
#   'flight': 2263,
#   'tailnum': 'N325US',
#   'origin': 'LGA',
#   'dest': 'MCO',
#   'air_time': 140.0,
#   'distance': 950,
#   'hour': 7,
#   'minute': 55},
#  {'index': 98,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 750,
#   'sched_arr_time': 1029,
#   'airline_id': 'UA',
#   'flight': 477,
#   'tailnum': 'N511UA',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 249.0,
#   'distance': 1620,
#   'hour': 7,
#   'minute': 50},
#  {'index': 99,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 759,
#   'sched_arr_time': 959,
#   'airline_id': 'US',
#   'flight': 1733,
#   'tailnum': 'N543UW',
#   'origin': 'LGA',
#   'dest': 'CLT',
#   'air_time': 96.0,
#   'distance': 544,
#   'hour': 7,
#   'minute': 59},
#  {'index': 100,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 755,
#   'sched_arr_time': 1110,
#   'airline_id': 'AA',
#   'flight': 2267,
#   'tailnum': 'N3HMAA',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 157.0,
#   'distance': 1096,
#   'hour': 7,
#   'minute': 55},
#  {'index': 101,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 759,
#   'sched_arr_time': 1041,
#   'airline_id': 'DL',
#   'flight': 2047,
#   'tailnum': 'N935DL',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 126.0,
#   'distance': 762,
#   'hour': 7,
#   'minute': 59},
#  {'index': 102,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 755,
#   'sched_arr_time': 1030,
#   'airline_id': 'WN',
#   'flight': 733,
#   'tailnum': 'N789SW',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 279.0,
#   'distance': 1620,
#   'hour': 7,
#   'minute': 55},
#  {'index': 103,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1054,
#   'airline_id': 'B6',
#   'flight': 517,
#   'tailnum': 'N645JB',
#   'origin': 'EWR',
#   'dest': 'MCO',
#   'air_time': 142.0,
#   'distance': 937,
#   'hour': 8,
#   'minute': 0},
#  {'index': 104,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1127,
#   'airline_id': 'DL',
#   'flight': 1843,
#   'tailnum': 'N955DL',
#   'origin': 'JFK',
#   'dest': 'MIA',
#   'air_time': 158.0,
#   'distance': 1089,
#   'hour': 8,
#   'minute': 0},
#  {'index': 105,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1014,
#   'airline_id': 'DL',
#   'flight': 2119,
#   'tailnum': 'N317US',
#   'origin': 'LGA',
#   'dest': 'MSP',
#   'air_time': 171.0,
#   'distance': 1020,
#   'hour': 8,
#   'minute': 0},
#  {'index': 106,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 955,
#   'airline_id': 'MQ',
#   'flight': 4406,
#   'tailnum': 'N828MQ',
#   'origin': 'JFK',
#   'dest': 'RDU',
#   'air_time': 80.0,
#   'distance': 427,
#   'hour': 8,
#   'minute': 10},
#  {'index': 107,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 805,
#   'sched_arr_time': 919,
#   'airline_id': 'B6',
#   'flight': 1172,
#   'tailnum': 'N206JB',
#   'origin': 'EWR',
#   'dest': 'BOS',
#   'air_time': 38.0,
#   'distance': 200,
#   'hour': 8,
#   'minute': 5},
#  {'index': 108,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 925,
#   'airline_id': 'AA',
#   'flight': 1838,
#   'tailnum': 'N3GEAA',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': 38.0,
#   'distance': 187,
#   'hour': 8,
#   'minute': 10},
#  {'index': 109,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1144,
#   'airline_id': 'UA',
#   'flight': 223,
#   'tailnum': 'N510UA',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 369.0,
#   'distance': 2586,
#   'hour': 8,
#   'minute': 0},
#  {'index': 110,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1116,
#   'airline_id': 'DL',
#   'flight': 1959,
#   'tailnum': 'N947DL',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': 147.0,
#   'distance': 944,
#   'hour': 8,
#   'minute': 10},
#  {'index': 111,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 805,
#   'sched_arr_time': 1005,
#   'airline_id': 'B6',
#   'flight': 219,
#   'tailnum': 'N273JB',
#   'origin': 'JFK',
#   'dest': 'CLT',
#   'air_time': 98.0,
#   'distance': 541,
#   'hour': 8,
#   'minute': 5},
#  {'index': 112,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1106,
#   'airline_id': 'B6',
#   'flight': 3,
#   'tailnum': 'N570JB',
#   'origin': 'JFK',
#   'dest': 'FLL',
#   'air_time': 165.0,
#   'distance': 1069,
#   'hour': 8,
#   'minute': 0},
#  {'index': 113,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1010,
#   'airline_id': 'MQ',
#   'flight': 4490,
#   'tailnum': 'N739MQ',
#   'origin': 'LGA',
#   'dest': 'CMH',
#   'air_time': 101.0,
#   'distance': 479,
#   'hour': 8,
#   'minute': 15},
#  {'index': 114,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1043,
#   'airline_id': 'DL',
#   'flight': 269,
#   'tailnum': 'N308DE',
#   'origin': 'JFK',
#   'dest': 'ATL',
#   'air_time': 126.0,
#   'distance': 760,
#   'hour': 8,
#   'minute': 10},
#  {'index': 115,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1050,
#   'airline_id': 'EV',
#   'flight': 4388,
#   'tailnum': 'N14542',
#   'origin': 'EWR',
#   'dest': 'JAX',
#   'air_time': 132.0,
#   'distance': 820,
#   'hour': 8,
#   'minute': 15},
#  {'index': 116,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1037,
#   'airline_id': '9E',
#   'flight': 3538,
#   'tailnum': 'N915XJ',
#   'origin': 'JFK',
#   'dest': 'MSP',
#   'air_time': 189.0,
#   'distance': 1029,
#   'hour': 8,
#   'minute': 10},
#  {'index': 117,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1128,
#   'airline_id': 'DL',
#   'flight': 2395,
#   'tailnum': 'N349NW',
#   'origin': 'LGA',
#   'dest': 'PBI',
#   'air_time': 149.0,
#   'distance': 1035,
#   'hour': 8,
#   'minute': 15},
#  {'index': 118,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1032,
#   'airline_id': 'EV',
#   'flight': 4260,
#   'tailnum': 'N11193',
#   'origin': 'EWR',
#   'dest': 'CHS',
#   'air_time': 101.0,
#   'distance': 628,
#   'hour': 8,
#   'minute': 15},
#  {'index': 119,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 630,
#   'sched_arr_time': 830,
#   'airline_id': 'MQ',
#   'flight': 4576,
#   'tailnum': 'N531MQ',
#   'origin': 'LGA',
#   'dest': 'CLT',
#   'air_time': 118.0,
#   'distance': 544,
#   'hour': 6,
#   'minute': 30},
#  {'index': 120,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1016,
#   'airline_id': 'US',
#   'flight': 675,
#   'tailnum': 'N654AW',
#   'origin': 'EWR',
#   'dest': 'CLT',
#   'air_time': 96.0,
#   'distance': 529,
#   'hour': 8,
#   'minute': 15},
#  {'index': 121,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 814,
#   'sched_arr_time': 1017,
#   'airline_id': 'EV',
#   'flight': 4537,
#   'tailnum': 'N17108',
#   'origin': 'EWR',
#   'dest': 'MEM',
#   'air_time': 180.0,
#   'distance': 946,
#   'hour': 8,
#   'minute': 14},
#  {'index': 122,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1056,
#   'airline_id': 'DL',
#   'flight': 914,
#   'tailnum': 'N375NC',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 267.0,
#   'distance': 1620,
#   'hour': 8,
#   'minute': 15},
#  {'index': 123,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1030,
#   'airline_id': 'FL',
#   'flight': 346,
#   'tailnum': 'N977AT',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 132.0,
#   'distance': 762,
#   'hour': 8,
#   'minute': 10},
#  {'index': 124,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 810,
#   'sched_arr_time': 948,
#   'airline_id': 'B6',
#   'flight': 1051,
#   'tailnum': 'N228JB',
#   'origin': 'JFK',
#   'dest': 'PIT',
#   'air_time': 86.0,
#   'distance': 340,
#   'hour': 8,
#   'minute': 10},
#  {'index': 125,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 820,
#   'sched_arr_time': 1310,
#   'airline_id': 'B6',
#   'flight': 717,
#   'tailnum': 'N527JB',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 190.0,
#   'distance': 1598,
#   'hour': 8,
#   'minute': 20},
#  {'index': 126,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 954,
#   'airline_id': 'DL',
#   'flight': 27,
#   'tailnum': 'N324US',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': 36.0,
#   'distance': 187,
#   'hour': 8,
#   'minute': 30},
#  {'index': 127,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 820,
#   'sched_arr_time': 1329,
#   'airline_id': 'DL',
#   'flight': 301,
#   'tailnum': 'N900PC',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 182.0,
#   'distance': 1598,
#   'hour': 8,
#   'minute': 20},
#  {'index': 128,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 820,
#   'sched_arr_time': 1129,
#   'airline_id': 'B6',
#   'flight': 181,
#   'tailnum': 'N521JB',
#   'origin': 'JFK',
#   'dest': 'SAN',
#   'air_time': 354.0,
#   'distance': 2446,
#   'hour': 8,
#   'minute': 20},
#  {'index': 129,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 825,
#   'sched_arr_time': 945,
#   'airline_id': 'MQ',
#   'flight': 4418,
#   'tailnum': 'N846MQ',
#   'origin': 'JFK',
#   'dest': 'DCA',
#   'air_time': 52.0,
#   'distance': 213,
#   'hour': 8,
#   'minute': 25},
#  {'index': 130,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1016,
#   'airline_id': 'EV',
#   'flight': 4104,
#   'tailnum': 'N12540',
#   'origin': 'LGA',
#   'dest': 'CLE',
#   'air_time': 91.0,
#   'distance': 419,
#   'hour': 8,
#   'minute': 30},
#  {'index': 131,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 825,
#   'sched_arr_time': 1024,
#   'airline_id': 'US',
#   'flight': 487,
#   'tailnum': 'N655AW',
#   'origin': 'JFK',
#   'dest': 'CLT',
#   'air_time': 96.0,
#   'distance': 541,
#   'hour': 8,
#   'minute': 25},
#  {'index': 132,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 823,
#   'sched_arr_time': 1135,
#   'airline_id': 'UA',
#   'flight': 1223,
#   'tailnum': 'N39728',
#   'origin': 'EWR',
#   'dest': 'DFW',
#   'air_time': 250.0,
#   'distance': 1372,
#   'hour': 8,
#   'minute': 23},
#  {'index': 133,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1025,
#   'airline_id': 'AA',
#   'flight': 1855,
#   'tailnum': 'N573AA',
#   'origin': 'LGA',
#   'dest': 'STL',
#   'air_time': 169.0,
#   'distance': 888,
#   'hour': 8,
#   'minute': 30},
#  {'index': 134,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 827,
#   'sched_arr_time': 1105,
#   'airline_id': 'B6',
#   'flight': 611,
#   'tailnum': 'N292JB',
#   'origin': 'JFK',
#   'dest': 'JAX',
#   'air_time': 130.0,
#   'distance': 828,
#   'hour': 8,
#   'minute': 27},
#  {'index': 135,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 715,
#   'sched_arr_time': 1045,
#   'airline_id': 'AA',
#   'flight': 443,
#   'tailnum': 'N3GVAA',
#   'origin': 'JFK',
#   'dest': 'MIA',
#   'air_time': 160.0,
#   'distance': 1089,
#   'hour': 7,
#   'minute': 15},
#  {'index': 136,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 817,
#   'sched_arr_time': 1158,
#   'airline_id': 'UA',
#   'flight': 1480,
#   'tailnum': 'N76522',
#   'origin': 'EWR',
#   'dest': 'SFO',
#   'air_time': 357.0,
#   'distance': 2565,
#   'hour': 8,
#   'minute': 17},
#  {'index': 137,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1012,
#   'airline_id': 'B6',
#   'flight': 905,
#   'tailnum': 'N274JB',
#   'origin': 'JFK',
#   'dest': 'ORD',
#   'air_time': 160.0,
#   'distance': 740,
#   'hour': 8,
#   'minute': 30},
#  {'index': 138,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 823,
#   'sched_arr_time': 1143,
#   'airline_id': 'UA',
#   'flight': 1506,
#   'tailnum': 'N76528',
#   'origin': 'EWR',
#   'dest': 'LAX',
#   'air_time': 359.0,
#   'distance': 2454,
#   'hour': 8,
#   'minute': 23},
#  {'index': 139,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1200,
#   'airline_id': 'UA',
#   'flight': 443,
#   'tailnum': 'N554UA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 360.0,
#   'distance': 2475,
#   'hour': 8,
#   'minute': 30},
#  {'index': 140,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1140,
#   'airline_id': 'UA',
#   'flight': 1592,
#   'tailnum': 'N75425',
#   'origin': 'EWR',
#   'dest': 'MCO',
#   'air_time': 145.0,
#   'distance': 937,
#   'hour': 8,
#   'minute': 30},
#  {'index': 141,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 830,
#   'sched_arr_time': 1015,
#   'airline_id': 'AA',
#   'flight': 313,
#   'tailnum': 'N4YCAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 137.0,
#   'distance': 733,
#   'hour': 8,
#   'minute': 30},
#  {'index': 142,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 835,
#   'sched_arr_time': 1105,
#   'airline_id': 'MQ',
#   'flight': 4610,
#   'tailnum': 'N513MQ',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 123.0,
#   'distance': 762,
#   'hour': 8,
#   'minute': 35},
#  {'index': 143,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 835,
#   'sched_arr_time': 1039,
#   'airline_id': 'EV',
#   'flight': 4412,
#   'tailnum': 'N13969',
#   'origin': 'EWR',
#   'dest': 'MYR',
#   'air_time': 92.0,
#   'distance': 550,
#   'hour': 8,
#   'minute': 35},
#  {'index': 144,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 840,
#   'sched_arr_time': 1030,
#   'airline_id': 'MQ',
#   'flight': 4521,
#   'tailnum': 'N725MQ',
#   'origin': 'LGA',
#   'dest': 'RDU',
#   'air_time': 77.0,
#   'distance': 431,
#   'hour': 8,
#   'minute': 40},
#  {'index': 145,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 835,
#   'sched_arr_time': 1102,
#   'airline_id': 'F9',
#   'flight': 835,
#   'tailnum': 'N203FR',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 257.0,
#   'distance': 1620,
#   'hour': 8,
#   'minute': 35},
#  {'index': 146,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 835,
#   'sched_arr_time': 1150,
#   'airline_id': 'AA',
#   'flight': 717,
#   'tailnum': 'N3BDAA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': 249.0,
#   'distance': 1389,
#   'hour': 8,
#   'minute': 35},
#  {'index': 147,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 850,
#   'sched_arr_time': 1035,
#   'airline_id': 'MQ',
#   'flight': 4558,
#   'tailnum': 'N711MQ',
#   'origin': 'LGA',
#   'dest': 'CLE',
#   'air_time': 88.0,
#   'distance': 419,
#   'hour': 8,
#   'minute': 50},
#  {'index': 148,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 845,
#   'sched_arr_time': 1350,
#   'airline_id': 'AA',
#   'flight': 1357,
#   'tailnum': 'N5FSAA',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 188.0,
#   'distance': 1598,
#   'hour': 8,
#   'minute': 45},
#  {'index': 149,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 845,
#   'sched_arr_time': 1102,
#   'airline_id': 'DL',
#   'flight': 2304,
#   'tailnum': 'N926DL',
#   'origin': 'JFK',
#   'dest': 'DTW',
#   'air_time': 108.0,
#   'distance': 509,
#   'hour': 8,
#   'minute': 45},
#  {'index': 150,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 845,
#   'sched_arr_time': 1205,
#   'airline_id': 'B6',
#   'flight': 553,
#   'tailnum': 'N564JB',
#   'origin': 'EWR',
#   'dest': 'RSW',
#   'air_time': 157.0,
#   'distance': 1068,
#   'hour': 8,
#   'minute': 45},
#  {'index': 151,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 1835,
#   'sched_arr_time': 1950,
#   'airline_id': 'MQ',
#   'flight': 3944,
#   'tailnum': 'N942MQ',
#   'origin': 'JFK',
#   'dest': 'BWI',
#   'air_time': 41.0,
#   'distance': 184,
#   'hour': 18,
#   'minute': 35},
#  {'index': 152,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 851,
#   'sched_arr_time': 1136,
#   'airline_id': 'UA',
#   'flight': 1741,
#   'tailnum': 'N27724',
#   'origin': 'EWR',
#   'dest': 'JAC',
#   'air_time': 275.0,
#   'distance': 1874,
#   'hour': 8,
#   'minute': 51},
#  {'index': 153,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 851,
#   'sched_arr_time': 1036,
#   'airline_id': 'EV',
#   'flight': 4548,
#   'tailnum': 'N19966',
#   'origin': 'EWR',
#   'dest': 'RDU',
#   'air_time': 75.0,
#   'distance': 416,
#   'hour': 8,
#   'minute': 51},
#  {'index': 154,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 859,
#   'sched_arr_time': 1105,
#   'airline_id': 'DL',
#   'flight': 869,
#   'tailnum': 'N361NB',
#   'origin': 'EWR',
#   'dest': 'DTW',
#   'air_time': 106.0,
#   'distance': 488,
#   'hour': 8,
#   'minute': 59},
#  {'index': 155,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 840,
#   'sched_arr_time': 1206,
#   'airline_id': 'UA',
#   'flight': 1626,
#   'tailnum': 'N39297',
#   'origin': 'EWR',
#   'dest': 'SAN',
#   'air_time': 367.0,
#   'distance': 2425,
#   'hour': 8,
#   'minute': 40},
#  {'index': 156,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 855,
#   'sched_arr_time': 1020,
#   'airline_id': 'WN',
#   'flight': 3848,
#   'tailnum': 'N777QC',
#   'origin': 'EWR',
#   'dest': 'MDW',
#   'air_time': 146.0,
#   'distance': 711,
#   'hour': 8,
#   'minute': 55},
#  {'index': 157,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 845,
#   'sched_arr_time': 1145,
#   'airline_id': 'B6',
#   'flight': 59,
#   'tailnum': 'N184JB',
#   'origin': 'JFK',
#   'dest': 'TPA',
#   'air_time': 159.0,
#   'distance': 1005,
#   'hour': 8,
#   'minute': 45},
#  {'index': 158,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 859,
#   'sched_arr_time': 1145,
#   'airline_id': 'DL',
#   'flight': 1747,
#   'tailnum': 'N646DL',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 129.0,
#   'distance': 762,
#   'hour': 8,
#   'minute': 59},
#  {'index': 159,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1220,
#   'airline_id': 'AA',
#   'flight': 1,
#   'tailnum': 'N324AA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 358.0,
#   'distance': 2475,
#   'hour': 9,
#   'minute': 0},
#  {'index': 160,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1232,
#   'airline_id': 'DL',
#   'flight': 2143,
#   'tailnum': 'N970DL',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 158.0,
#   'distance': 1096,
#   'hour': 9,
#   'minute': 0},
#  {'index': 161,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 855,
#   'sched_arr_time': 1203,
#   'airline_id': 'UA',
#   'flight': 1296,
#   'tailnum': 'N75426',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': 150.0,
#   'distance': 1023,
#   'hour': 8,
#   'minute': 55},
#  {'index': 162,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1530,
#   'airline_id': 'HA',
#   'flight': 51,
#   'tailnum': 'N380HA',
#   'origin': 'JFK',
#   'dest': 'HNL',
#   'air_time': 659.0,
#   'distance': 4983,
#   'hour': 9,
#   'minute': 0},
#  {'index': 163,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 905,
#   'sched_arr_time': 1120,
#   'airline_id': 'DL',
#   'flight': 181,
#   'tailnum': 'N321NB',
#   'origin': 'LGA',
#   'dest': 'DTW',
#   'air_time': 110.0,
#   'distance': 502,
#   'hour': 9,
#   'minute': 5},
#  {'index': 164,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1133,
#   'airline_id': 'DL',
#   'flight': 485,
#   'tailnum': 'N371NB',
#   'origin': 'EWR',
#   'dest': 'ATL',
#   'air_time': 125.0,
#   'distance': 746,
#   'hour': 9,
#   'minute': 0},
#  {'index': 165,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 851,
#   'sched_arr_time': 1222,
#   'airline_id': 'UA',
#   'flight': 1670,
#   'tailnum': 'N45440',
#   'origin': 'EWR',
#   'dest': 'SEA',
#   'air_time': 343.0,
#   'distance': 2402,
#   'hour': 8,
#   'minute': 51},
#  {'index': 166,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1110,
#   'airline_id': 'MQ',
#   'flight': 4478,
#   'tailnum': 'N737MQ',
#   'origin': 'LGA',
#   'dest': 'DTW',
#   'air_time': 103.0,
#   'distance': 502,
#   'hour': 9,
#   'minute': 0},
#  {'index': 167,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1204,
#   'airline_id': 'DL',
#   'flight': 1885,
#   'tailnum': 'N360NB',
#   'origin': 'LGA',
#   'dest': 'MCO',
#   'air_time': 140.0,
#   'distance': 950,
#   'hour': 9,
#   'minute': 0},
#  {'index': 168,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1225,
#   'airline_id': 'VX',
#   'flight': 407,
#   'tailnum': 'N846VA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 359.0,
#   'distance': 2475,
#   'hour': 9,
#   'minute': 0},
#  {'index': 169,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 900,
#   'sched_arr_time': 1203,
#   'airline_id': 'UA',
#   'flight': 1170,
#   'tailnum': 'N19130',
#   'origin': 'EWR',
#   'dest': 'FLL',
#   'air_time': 161.0,
#   'distance': 1065,
#   'hour': 9,
#   'minute': 0},
#  {'index': 170,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 903,
#   'sched_arr_time': 1045,
#   'airline_id': 'UA',
#   'flight': 580,
#   'tailnum': 'N820UA',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': 145.0,
#   'distance': 719,
#   'hour': 9,
#   'minute': 3},
#  {'index': 171,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 820,
#   'sched_arr_time': 955,
#   'airline_id': 'MQ',
#   'flight': 4655,
#   'tailnum': 'N532MQ',
#   'origin': 'LGA',
#   'dest': 'BNA',
#   'air_time': 142.0,
#   'distance': 764,
#   'hour': 8,
#   'minute': 20},
#  {'index': 172,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 906,
#   'sched_arr_time': 1226,
#   'airline_id': 'UA',
#   'flight': 1401,
#   'tailnum': 'N77525',
#   'origin': 'EWR',
#   'dest': 'MIA',
#   'air_time': 158.0,
#   'distance': 1085,
#   'hour': 9,
#   'minute': 6},
#  {'index': 173,
#   'year': 2013,
#   'month': 1,
#   'day': 1,
#   'sched_dep_time': 905,
#   'sched_arr_time': 1229,
#   'airline_id': 'B6',
#   'flight': 1061,
# ...
#   'airline_id': 'UA',
#   'flight': 311,
#   'tailnum': 'N413UA',
#   'origin': 'EWR',
#   'dest': 'DEN',
#   'air_time': 251.0,
#   'distance': 1605,
#   'hour': 7,
#   'minute': 30},
#  {'index': 954,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 720,
#   'sched_arr_time': 840,
#   'airline_id': 'FL',
#   'flight': 850,
#   'tailnum': 'N982AT',
#   'origin': 'LGA',
#   'dest': 'MKE',
#   'air_time': 113.0,
#   'distance': 738,
#   'hour': 7,
#   'minute': 20},
#  {'index': 955,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 729,
#   'sched_arr_time': 1039,
#   'airline_id': 'B6',
#   'flight': 1601,
#   'tailnum': 'N645JB',
#   'origin': 'LGA',
#   'dest': 'RSW',
#   'air_time': 168.0,
#   'distance': 1080,
#   'hour': 7,
#   'minute': 29},
#  {'index': 956,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1056,
#   'airline_id': 'DL',
#   'flight': 495,
#   'tailnum': 'N3768',
#   'origin': 'JFK',
#   'dest': 'SEA',
#   'air_time': 309.0,
#   'distance': 2422,
#   'hour': 7,
#   'minute': 30},
#  {'index': 957,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 715,
#   'sched_arr_time': 1206,
#   'airline_id': 'B6',
#   'flight': 715,
#   'tailnum': 'N559JB',
#   'origin': 'JFK',
#   'dest': 'SJU',
#   'air_time': 187.0,
#   'distance': 1598,
#   'hour': 7,
#   'minute': 15},
#  {'index': 958,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1100,
#   'airline_id': 'AA',
#   'flight': 33,
#   'tailnum': 'N322AA',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': 351.0,
#   'distance': 2475,
#   'hour': 7,
#   'minute': 30},
#  {'index': 959,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 736,
#   'sched_arr_time': 850,
#   'airline_id': 'B6',
#   'flight': 44,
#   'tailnum': 'N506JB',
#   'origin': 'JFK',
#   'dest': 'SYR',
#   'air_time': 50.0,
#   'distance': 209,
#   'hour': 7,
#   'minute': 36},
#  {'index': 960,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 732,
#   'sched_arr_time': 1040,
#   'airline_id': 'UA',
#   'flight': 1509,
#   'tailnum': 'N73291',
#   'origin': 'LGA',
#   'dest': 'IAH',
#   'air_time': 230.0,
#   'distance': 1416,
#   'hour': 7,
#   'minute': 32},
#  {'index': 961,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 735,
#   'sched_arr_time': 858,
#   'airline_id': 'B6',
#   'flight': 20,
#   'tailnum': 'N337JB',
#   'origin': 'JFK',
#   'dest': 'ROC',
#   'air_time': 57.0,
#   'distance': 264,
#   'hour': 7,
#   'minute': 35},
#  {'index': 962,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 737,
#   'sched_arr_time': 1113,
#   'airline_id': 'B6',
#   'flight': 643,
#   'tailnum': 'N804JB',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 335.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 37},
#  {'index': 963,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 700,
#   'sched_arr_time': 1025,
#   'airline_id': 'WN',
#   'flight': 20,
#   'tailnum': 'N485WN',
#   'origin': 'EWR',
#   'dest': 'HOU',
#   'air_time': 235.0,
#   'distance': 1411,
#   'hour': 7,
#   'minute': 0},
#  {'index': 964,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 732,
#   'sched_arr_time': 853,
#   'airline_id': 'UA',
#   'flight': 1199,
#   'tailnum': 'N37408',
#   'origin': 'EWR',
#   'dest': 'BOS',
#   'air_time': 34.0,
#   'distance': 200,
#   'hour': 7,
#   'minute': 32},
#  {'index': 965,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 745,
#   'sched_arr_time': 1036,
#   'airline_id': 'B6',
#   'flight': 983,
#   'tailnum': 'N504JB',
#   'origin': 'LGA',
#   'dest': 'TPA',
#   'air_time': 162.0,
#   'distance': 1010,
#   'hour': 7,
#   'minute': 45},
#  {'index': 966,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 745,
#   'sched_arr_time': 930,
#   'airline_id': 'AA',
#   'flight': 309,
#   'tailnum': 'N528AA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': 121.0,
#   'distance': 733,
#   'hour': 7,
#   'minute': 45},
#  {'index': 967,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 745,
#   'sched_arr_time': 1125,
#   'airline_id': 'AA',
#   'flight': 59,
#   'tailnum': 'N325AA',
#   'origin': 'JFK',
#   'dest': 'SFO',
#   'air_time': 353.0,
#   'distance': 2586,
#   'hour': 7,
#   'minute': 45},
#  {'index': 968,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 735,
#   'sched_arr_time': 1031,
#   'airline_id': 'UA',
#   'flight': 1296,
#   'tailnum': 'N19117',
#   'origin': 'EWR',
#   'dest': 'MCO',
#   'air_time': 144.0,
#   'distance': 937,
#   'hour': 7,
#   'minute': 35},
#  {'index': 969,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 740,
#   'sched_arr_time': 1015,
#   'airline_id': 'WN',
#   'flight': 1581,
#   'tailnum': 'N468WN',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 263.0,
#   'distance': 1620,
#   'hour': 7,
#   'minute': 40},
#  {'index': 970,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 743,
#   'sched_arr_time': 920,
#   'airline_id': 'EV',
#   'flight': 4348,
#   'tailnum': 'N14542',
#   'origin': 'EWR',
#   'dest': 'GSO',
#   'air_time': 94.0,
#   'distance': 445,
#   'hour': 7,
#   'minute': 43},
#  {'index': 971,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 740,
#   'sched_arr_time': 1019,
#   'airline_id': 'UA',
#   'flight': 328,
#   'tailnum': 'N533UA',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 220.0,
#   'distance': 1620,
#   'hour': 7,
#   'minute': 40},
#  {'index': 972,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 745,
#   'sched_arr_time': 857,
#   'airline_id': '9E',
#   'flight': 3373,
#   'tailnum': 'N902XJ',
#   'origin': 'JFK',
#   'dest': 'PHL',
#   'air_time': 30.0,
#   'distance': 94,
#   'hour': 7,
#   'minute': 45},
#  {'index': 973,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1007,
#   'airline_id': 'DL',
#   'flight': 807,
#   'tailnum': 'N989DL',
#   'origin': 'EWR',
#   'dest': 'ATL',
#   'air_time': 128.0,
#   'distance': 746,
#   'hour': 7,
#   'minute': 30},
#  {'index': 974,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1040,
#   'airline_id': 'AA',
#   'flight': 715,
#   'tailnum': 'N455AA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': 244.0,
#   'distance': 1389,
#   'hour': 7,
#   'minute': 30},
#  {'index': 975,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 746,
#   'sched_arr_time': 1129,
#   'airline_id': 'UA',
#   'flight': 1668,
#   'tailnum': 'N37287',
#   'origin': 'EWR',
#   'dest': 'SFO',
#   'air_time': 350.0,
#   'distance': 2565,
#   'hour': 7,
#   'minute': 46},
#  {'index': 976,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 749,
#   'sched_arr_time': 1054,
#   'airline_id': 'B6',
#   'flight': 341,
#   'tailnum': 'N508JB',
#   'origin': 'JFK',
#   'dest': 'SRQ',
#   'air_time': 167.0,
#   'distance': 1041,
#   'hour': 7,
#   'minute': 49},
#  {'index': 977,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 725,
#   'sched_arr_time': 1020,
#   'airline_id': 'UA',
#   'flight': 1724,
#   'tailnum': 'N79521',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': 151.0,
#   'distance': 1023,
#   'hour': 7,
#   'minute': 25},
#  {'index': 978,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 945,
#   'airline_id': '9E',
#   'flight': 3643,
#   'tailnum': 'N8869B',
#   'origin': 'JFK',
#   'dest': 'PIT',
#   'air_time': 68.0,
#   'distance': 340,
#   'hour': 8,
#   'minute': 0},
#  {'index': 979,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 959,
#   'airline_id': 'EV',
#   'flight': 4166,
#   'tailnum': 'N11536',
#   'origin': 'EWR',
#   'dest': 'GSP',
#   'air_time': 109.0,
#   'distance': 594,
#   'hour': 8,
#   'minute': 0},
#  {'index': 980,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 918,
#   'airline_id': 'EV',
#   'flight': 4233,
#   'tailnum': 'N21130',
#   'origin': 'EWR',
#   'dest': 'BTV',
#   'air_time': 49.0,
#   'distance': 266,
#   'hour': 8,
#   'minute': 0},
#  {'index': 981,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 745,
#   'sched_arr_time': 1042,
#   'airline_id': 'UA',
#   'flight': 251,
#   'tailnum': 'N430UA',
#   'origin': 'EWR',
#   'dest': 'IAH',
#   'air_time': 215.0,
#   'distance': 1400,
#   'hour': 7,
#   'minute': 45},
#  {'index': 982,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 635,
#   'sched_arr_time': 745,
#   'airline_id': 'EV',
#   'flight': 4241,
#   'tailnum': 'N22909',
#   'origin': 'EWR',
#   'dest': 'DCA',
#   'air_time': 46.0,
#   'distance': 199,
#   'hour': 6,
#   'minute': 35},
#  {'index': 983,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 755,
#   'sched_arr_time': 1059,
#   'airline_id': 'DL',
#   'flight': 2263,
#   'tailnum': 'N361NW',
#   'origin': 'LGA',
#   'dest': 'MCO',
#   'air_time': 143.0,
#   'distance': 950,
#   'hour': 7,
#   'minute': 55},
#  {'index': 984,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1054,
#   'airline_id': 'B6',
#   'flight': 517,
#   'tailnum': 'N703JB',
#   'origin': 'EWR',
#   'dest': 'MCO',
#   'air_time': 146.0,
#   'distance': 937,
#   'hour': 8,
#   'minute': 0},
#  {'index': 985,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1106,
#   'airline_id': 'B6',
#   'flight': 3,
#   'tailnum': 'N509JB',
#   'origin': 'JFK',
#   'dest': 'FLL',
#   'air_time': 155.0,
#   'distance': 1069,
#   'hour': 8,
#   'minute': 0},
#  {'index': 986,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 759,
#   'sched_arr_time': 1039,
#   'airline_id': 'DL',
#   'flight': 2047,
#   'tailnum': 'N660DL',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': 123.0,
#   'distance': 762,
#   'hour': 7,
#   'minute': 59},
#  {'index': 987,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1127,
#   'airline_id': 'DL',
#   'flight': 1843,
#   'tailnum': 'N918DL',
#   'origin': 'JFK',
#   'dest': 'MIA',
#   'air_time': 155.0,
#   'distance': 1089,
#   'hour': 8,
#   'minute': 0},
#  {'index': 988,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 759,
#   'sched_arr_time': 959,
#   'airline_id': 'US',
#   'flight': 1733,
#   'tailnum': 'N537UW',
#   'origin': 'LGA',
#   'dest': 'CLT',
#   'air_time': 106.0,
#   'distance': 544,
#   'hour': 7,
#   'minute': 59},
#  {'index': 989,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 755,
#   'sched_arr_time': 1110,
#   'airline_id': 'AA',
#   'flight': 2267,
#   'tailnum': 'N3CNAA',
#   'origin': 'LGA',
#   'dest': 'MIA',
#   'air_time': 160.0,
#   'distance': 1096,
#   'hour': 7,
#   'minute': 55},
#  {'index': 990,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 805,
#   'sched_arr_time': 919,
#   'airline_id': 'B6',
#   'flight': 1172,
#   'tailnum': 'N309JB',
#   'origin': 'EWR',
#   'dest': 'BOS',
#   'air_time': 38.0,
#   'distance': 200,
#   'hour': 8,
#   'minute': 5},
#  {'index': 991,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1116,
#   'airline_id': 'DL',
#   'flight': 1959,
#   'tailnum': 'N995DL',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': 143.0,
#   'distance': 944,
#   'hour': 8,
#   'minute': 10},
#  {'index': 992,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 730,
#   'sched_arr_time': 1040,
#   'airline_id': 'AA',
#   'flight': 2083,
#   'tailnum': 'N487AA',
#   'origin': 'EWR',
#   'dest': 'DFW',
#   'air_time': 241.0,
#   'distance': 1372,
#   'hour': 7,
#   'minute': 30},
#  {'index': 993,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 955,
#   'airline_id': 'MQ',
#   'flight': 4406,
#   'tailnum': 'N837MQ',
#   'origin': 'JFK',
#   'dest': 'RDU',
#   'air_time': 86.0,
#   'distance': 427,
#   'hour': 8,
#   'minute': 10},
#  {'index': 994,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 805,
#   'sched_arr_time': 1110,
#   'airline_id': 'UA',
#   'flight': 423,
#   'tailnum': 'N528UA',
#   'origin': 'EWR',
#   'dest': 'PDX',
#   'air_time': 310.0,
#   'distance': 2434,
#   'hour': 8,
#   'minute': 5},
#  {'index': 995,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1315,
#   'airline_id': 'AA',
#   'flight': 655,
#   'tailnum': 'N5FTAA',
#   'origin': 'JFK',
#   'dest': 'STT',
#   'air_time': 193.0,
#   'distance': 1623,
#   'hour': 8,
#   'minute': 10},
#  {'index': 996,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1129,
#   'airline_id': 'DL',
#   'flight': 1271,
#   'tailnum': 'N322US',
#   'origin': 'JFK',
#   'dest': 'FLL',
#   'air_time': 170.0,
#   'distance': 1069,
#   'hour': 8,
#   'minute': 10},
#  {'index': 997,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 1045,
#   'airline_id': 'DL',
#   'flight': 269,
#   'tailnum': 'N971DL',
#   'origin': 'JFK',
#   'dest': 'ATL',
#   'air_time': 124.0,
#   'distance': 760,
#   'hour': 8,
#   'minute': 10},
#  {'index': 998,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1016,
#   'airline_id': 'US',
#   'flight': 675,
#   'tailnum': 'N656AW',
#   'origin': 'EWR',
#   'dest': 'CLT',
#   'air_time': 107.0,
#   'distance': 529,
#   'hour': 8,
#   'minute': 15},
#  {'index': 999,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 948,
#   'airline_id': 'B6',
#   'flight': 1051,
#   'tailnum': 'N304JB',
#   'origin': 'JFK',
#   'dest': 'PIT',
#   'air_time': 71.0,
#   'distance': 340,
#   'hour': 8,
#   'minute': 10},
#  {'index': 1000,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 800,
#   'sched_arr_time': 1014,
#   'airline_id': 'DL',
#   'flight': 2119,
#   'tailnum': 'N358NW',
#   'origin': 'LGA',
#   'dest': 'MSP',
#   'air_time': 142.0,
#   'distance': 1020,
#   'hour': 8,
#   'minute': 0},
#  {'index': 1001,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1056,
#   'airline_id': 'DL',
#   'flight': 914,
#   'tailnum': 'N328NW',
#   'origin': 'LGA',
#   'dest': 'DEN',
#   'air_time': 253.0,
#   'distance': 1620,
#   'hour': 8,
#   'minute': 15},
#  {'index': 1002,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1131,
#   'airline_id': 'DL',
#   'flight': 1167,
#   'tailnum': 'N305DQ',
#   'origin': 'JFK',
#   'dest': 'TPA',
#   'air_time': 160.0,
#   'distance': 1005,
#   'hour': 8,
#   'minute': 15},
#  {'index': 1003,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 820,
#   'sched_arr_time': 955,
#   'airline_id': 'MQ',
#   'flight': 4655,
#   'tailnum': 'N509MQ',
#   'origin': 'LGA',
#   'dest': 'BNA',
#   'air_time': 131.0,
#   'distance': 764,
#   'hour': 8,
#   'minute': 20},
#  {'index': 1004,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1128,
#   'airline_id': 'DL',
#   'flight': 2395,
#   'tailnum': 'N335NW',
#   'origin': 'LGA',
#   'dest': 'PBI',
#   'air_time': 153.0,
#   'distance': 1035,
#   'hour': 8,
#   'minute': 15},
#  {'index': 1005,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 815,
#   'sched_arr_time': 1010,
#   'airline_id': 'MQ',
#   'flight': 4490,
#   'tailnum': 'N723MQ',
#   'origin': 'LGA',
#   'dest': 'CMH',
#   'air_time': 90.0,
#   'distance': 479,
#   'hour': 8,
#   'minute': 15},
#  {'index': 1006,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 825,
#   'sched_arr_time': 945,
#   'airline_id': 'MQ',
#   'flight': 4418,
#   'tailnum': 'N853MQ',
#   'origin': 'JFK',
#   'dest': 'DCA',
#   'air_time': 43.0,
#   'distance': 213,
#   'hour': 8,
#   'minute': 25},
#  {'index': 1007,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 630,
#   'sched_arr_time': 845,
#   'airline_id': 'EV',
#   'flight': 4235,
#   'tailnum': 'N16546',
#   'origin': 'EWR',
#   'dest': 'IND',
#   'air_time': 132.0,
#   'distance': 645,
#   'hour': 6,
#   'minute': 30},
#  {'index': 1008,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 820,
#   'sched_arr_time': 1007,
#   'airline_id': '9E',
#   'flight': 3521,
#   'tailnum': 'N931XJ',
#   'origin': 'JFK',
#   'dest': 'ORD',
#   'air_time': 143.0,
#   'distance': 740,
#   'hour': 8,
#   'minute': 20},
#  {'index': 1009,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 810,
#   'sched_arr_time': 925,
#   'airline_id': 'AA',
#   'flight': 1838,
#   'tailnum': 'N3BYAA',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': 37.0,
#   'distance': 187,
#   'hour': 8,
#   'minute': 10},
#  {'index': 1010,
#   'year': 2013,
#   'month': 1,
#   'day': 2,
#   'sched_dep_time': 805,
#   'sched_arr_time': 1005,
#   'airline_id': 'B6',
#   'flight': 219,
#   'tailnum': 'N339JB',
#   'origin': 'JFK',
#   'dest': 'CLT',
#   'air_time': 108.0,
#   'distance': 541,
#   'hour': 8,
#   'minute': 5},
#  ...]

# %%
all_flights_dict = [columns_to_dict(row) for row in session.query(All_Flights).all()]
all_flights_dict
# Out:
# [{'index': 0,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 46,
#   'total': 46},
#  {'index': 1,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SAW',
#   'alid': 21134,
#   'airline_id': '0J',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 2,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YQB',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 3,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YWG',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 4,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 5,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GCM',
#   'alid': 20207,
#   'airline_id': 'XP',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 6,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 16,
#   'total': 16},
#  {'index': 7,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'POS',
#   'alid': 20405,
#   'airline_id': 'N8',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 8,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 9,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YMX',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 10,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYT',
#   'alid': 19682,
#   'airline_id': 'VS',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 11,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 12,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 36,
#   'total': 36},
#  {'index': 13,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHU',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 14,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 15,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 16,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YVR',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 17,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YWG',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 18,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 6,
#   'total': 6},
#  {'index': 19,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ARN',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 20,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GDL',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 21,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 7,
#   'total': 7},
#  {'index': 22,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'RUH',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 23,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'RUH',
#   'alid': 21629,
#   'airline_id': 'KD',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 24,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SCL',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 25,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 26,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 19550,
#   'airline_id': 'KE',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 27,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 28,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 44,
#   'total': 44},
#  {'index': 29,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 30,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 31,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'RLG',
#   'alid': 21635,
#   'airline_id': 'LF',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 32,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 33,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHM',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 34,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 35,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 36,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 40,
#   'total': 40},
#  {'index': 37,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CUN',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 6,
#   'total': 6},
#  {'index': 38,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 39,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 40,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 41,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 42,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 43,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CMN',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 44,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GCM',
#   'alid': 20207,
#   'airline_id': 'XP',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 6,
#   'total': 6},
#  {'index': 45,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GCM',
#   'alid': 20310,
#   'airline_id': 'WL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 46,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ICN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 47,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 7,
#   'total': 7},
#  {'index': 48,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'POS',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 49,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SCL',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 50,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 51,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TLV',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 52,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 19550,
#   'airline_id': 'KE',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 53,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 54,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 55,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 56,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 20405,
#   'airline_id': 'N8',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 57,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 40,
#   'total': 40},
#  {'index': 58,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'PUJ',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 59,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YEG',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 60,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHM',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 61,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHU',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 62,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 63,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 64,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 65,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YWG',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 66,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 67,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 68,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 69,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YWG',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 70,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 42,
#   'total': 42},
#  {'index': 71,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SJD',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 72,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 73,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 74,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 75,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYC',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 76,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 77,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 78,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSA',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 79,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HHN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 80,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HHN',
#   'alid': 20100,
#   'airline_id': 'PO',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 81,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 82,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TLS',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 83,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 42,
#   'total': 42},
#  {'index': 84,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 85,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 86,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 87,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BEY',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 88,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MTY',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 89,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MTY',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 90,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'STN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 91,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 92,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 42,
#   'total': 42},
#  {'index': 93,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 94,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BDA',
#   'alid': 20422,
#   'airline_id': 'SY',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 95,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'VCP',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 5,
#   'total': 5},
#  {'index': 96,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 97,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 39,
#   'total': 39},
#  {'index': 98,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SVD',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 99,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SXM',
#   'alid': 21421,
#   'airline_id': 'PP',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 100,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'VKO',
#   'alid': 21421,
#   'airline_id': 'PP',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 101,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YQX',
#   'alid': 21635,
#   'airline_id': 'LF',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 102,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 103,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 16,
#   'total': 16},
#  {'index': 104,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGW',
#   'alid': 19682,
#   'airline_id': 'VS',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 105,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MXP',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 106,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 107,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 43,
#   'total': 43},
#  {'index': 108,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'MAN',
#   'alid': 19682,
#   'airline_id': 'VS',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 109,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 10,
#   'total': 10},
#  {'index': 110,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 41,
#   'total': 41},
#  {'index': 111,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YWG',
#   'alid': 20422,
#   'airline_id': 'SY',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 112,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20422,
#   'airline_id': 'SY',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 113,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 16,
#   'total': 16},
#  {'index': 114,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'PLS',
#   'alid': 21635,
#   'airline_id': 'LF',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 115,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 116,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ZAZ',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 117,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 34,
#   'total': 34},
#  {'index': 118,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHU',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 119,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HHN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 120,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 18,
#   'total': 18},
#  {'index': 121,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LUX',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 122,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MAN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 123,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 124,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 44,
#   'total': 44},
#  {'index': 125,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'CUN',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 126,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YOW',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 127,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 128,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 129,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LUX',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 130,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'NAS',
#   'alid': 20422,
#   'airline_id': 'SY',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 131,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'SCL',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 132,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 133,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 19550,
#   'airline_id': 'KE',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 4,
#   'total': 4},
#  {'index': 134,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YQM',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 135,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 136,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 40,
#   'total': 40},
#  {'index': 137,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'CUN',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 5,
#   'total': 5},
#  {'index': 138,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'PTY',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 139,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'SJO',
#   'alid': 20422,
#   'airline_id': 'SY',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 140,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 141,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 142,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 5,
#   'total': 5},
#  {'index': 143,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20402,
#   'airline_id': 'GL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 144,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'ADJ',
#   'alid': 21629,
#   'airline_id': 'KD',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 145,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'GCM',
#   'alid': 20310,
#   'airline_id': 'WL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 17,
#   'total': 17},
#  {'index': 146,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'HHN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 147,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'ICN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 148,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20405,
#   'airline_id': 'N8',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 149,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 150,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'TLS',
#   'alid': 20100,
#   'airline_id': 'PO',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 151,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20313,
#   'airline_id': 'W8',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 44,
#   'total': 44},
#  {'index': 152,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'CUN',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 7,
#   'total': 7},
#  {'index': 153,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'MTY',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 6,
#   'total': 6},
#  {'index': 154,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'SJD',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 155,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'TIJ',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 156,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 157,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'AMS',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 158,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSA',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 3,
#   'total': 3},
#  {'index': 159,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'FRA',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 160,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'GCM',
#   'alid': 20310,
#   'airline_id': 'WL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 20,
#   'total': 20},
#  {'index': 161,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'GDL',
#   'alid': 20405,
#   'airline_id': 'N8',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 162,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'ICN',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 163,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'ICN',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 14,
#   'total': 14},
#  {'index': 164,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 165,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGG',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 11,
#   'total': 11},
#  {'index': 166,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LUX',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 167,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'STR',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 168,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAR',
#   'alid': 20007,
#   'airline_id': '5Y',
#   'dom_fgn': 1,
#   'scheduled': 0,
#   'chartered': 1,
#   'total': 1},
#  {'index': 169,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 20140,
#   'airline_id': 'CC',
#   'dom_fgn': 0,
#   'scheduled': 0,
#   'chartered': 2,
#   'total': 2},
#  {'index': 170,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'FAO',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 171,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'KEF',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 172,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'OPO',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 173,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'KEF',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 174,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CLO',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 175,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 176,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'KTW',
#   'alid': 19558,
#   'airline_id': 'LY',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 177,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYT',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 178,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TER',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 179,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'PIK',
#   'alid': 19540,
#   'airline_id': 'BA',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 180,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MTY',
#   'alid': 19534,
#   'airline_id': 'AM',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 181,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MTY',
#   'alid': 19534,
#   'airline_id': 'AM',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 182,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'EMA',
#   'alid': 19917,
#   'airline_id': '5X',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 183,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 184,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BDA',
#   'alid': 21823,
#   'airline_id': 'D8',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 185,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'LBA',
#   'alid': 21624,
#   'airline_id': 'LS',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 186,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BDA',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 187,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYZ',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 188,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 189,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 190,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TRN',
#   'alid': 19539,
#   'airline_id': 'AZ',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 191,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'NCL',
#   'alid': 21624,
#   'airline_id': 'LS',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 192,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYT',
#   'alid': 19540,
#   'airline_id': 'BA',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 193,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'MVD',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 194,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'PIK',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 195,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'PUJ',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 196,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YYT',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 197,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'BHX',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 198,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYR',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 199,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YUL',
#   'alid': 20452,
#   'airline_id': 'YX',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 200,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YUL',
#   'alid': 20445,
#   'airline_id': 'C5',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 201,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MVD',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 202,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'REX',
#   'alid': 20250,
#   'airline_id': '5D',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 203,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 204,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'STN',
#   'alid': 21924,
#   'airline_id': 'DI',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 205,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 206,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHZ',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 207,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'SDQ',
#   'alid': 20416,
#   'airline_id': 'NK',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 208,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'SNN',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 209,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YHM',
#   'alid': 21611,
#   'airline_id': 'KV',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 210,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ACA',
#   'alid': 21342,
#   'airline_id': 'VB',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 211,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ANF',
#   'alid': 19552,
#   'airline_id': 'LA',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 212,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SNN',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 213,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'KIX',
#   'alid': 19779,
#   'airline_id': 'CX',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 214,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'DUB',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 215,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'ATH',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 216,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'ESB',
#   'alid': 19821,
#   'airline_id': 'TK',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 217,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYZ',
#   'alid': 20229,
#   'airline_id': 'WS',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 218,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YQX',
#   'alid': 21579,
#   'airline_id': 'DY',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 219,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'YOW',
#   'alid': 19779,
#   'airline_id': 'CX',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 220,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YWG',
#   'alid': 20366,
#   'airline_id': 'EV',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 221,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 222,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'UIO',
#   'alid': 19821,
#   'airline_id': 'TK',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 223,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'TER',
#   'alid': 19576,
#   'airline_id': 'TP',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 224,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'STR',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 225,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'NLD',
#   'alid': 20250,
#   'airline_id': '5D',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 226,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19564,
#   'airline_id': 'PR',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 227,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BDA',
#   'alid': 19547,
#   'airline_id': 'IB',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 228,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'GND',
#   'alid': 19542,
#   'airline_id': 'BW',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 229,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'BOG',
#   'alid': 19821,
#   'airline_id': 'TK',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 230,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DUS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 231,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'MBJ',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 232,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MDE',
#   'alid': 19953,
#   'airline_id': 'QT',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 233,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 19532,
#   'airline_id': 'AF',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 234,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YEG',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 235,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SXM',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 236,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'HAV',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 237,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'KIN',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 238,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'POS',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 239,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YYT',
#   'alid': 19540,
#   'airline_id': 'BA',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 240,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 241,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SCQ',
#   'alid': 20119,
#   'airline_id': 'UX',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 242,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SCL',
#   'alid': 19779,
#   'airline_id': 'CX',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 243,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LGW',
#   'alid': 21579,
#   'airline_id': 'DY',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 244,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'JNB',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 245,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GND',
#   'alid': 19542,
#   'airline_id': 'BW',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 246,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'DEL',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 247,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'GRU',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 248,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'MVD',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 249,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'BSB',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 250,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'SNN',
#   'alid': 19554,
#   'airline_id': 'LH',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 251,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YQX',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 252,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'BDA',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 253,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'YHZ',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 254,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TER',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 255,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YUL',
#   'alid': 20452,
#   'airline_id': 'YX',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 256,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YUL',
#   'alid': 19531,
#   'airline_id': 'AC',
#   'dom_fgn': 0,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 257,
#   'year': 2019,
#   'dep_airport': 'LGA',
#   'des_airport': 'YHZ',
#   'alid': 20363,
#   'airline_id': '9E',
#   'dom_fgn': 1,
#   'scheduled': 1,
#   'chartered': 0,
#   'total': 1},
#  {'index': 258,
#   'year': 2019,
#   'dep_airport': 'JFK',
# ...
#  {'index': 915,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CDG',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 916,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 917,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'CTU',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 918,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 919,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'GYD',
#   'alid': 21692,
#   'airline_id': 'J2',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 920,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 921,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CTU',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 922,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'FRA',
#   'alid': 21427,
#   'airline_id': '3S',
#   'dom_fgn': 0,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 923,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'STN',
#   'alid': 19917,
#   'airline_id': '5X',
#   'dom_fgn': 1,
#   'scheduled': 16,
#   'chartered': 0,
#   'total': 16},
#  {'index': 924,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'AMM',
#   'alid': 19568,
#   'airline_id': 'RJ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 2,
#   'total': 19},
#  {'index': 925,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'LOS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 926,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 927,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 928,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 929,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CDG',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 930,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SAP',
#   'alid': 19574,
#   'airline_id': 'TA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 931,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'STN',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 932,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'FCO',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 933,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'AGP',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 934,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'OSL',
#   'alid': 21579,
#   'airline_id': 'DY',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 935,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CPH',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 936,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GLA',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 937,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SAP',
#   'alid': 19574,
#   'airline_id': 'TA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 938,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'PDL',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 939,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GIG',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 940,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 941,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 942,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LUX',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 943,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'SKB',
#   'alid': 19805,
#   'airline_id': 'AA',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 944,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 945,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'FCO',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 2,
#   'total': 19},
#  {'index': 946,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 947,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'YQB',
#   'alid': 20366,
#   'airline_id': 'EV',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 948,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 949,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 950,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 951,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 952,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SAP',
#   'alid': 19574,
#   'airline_id': 'TA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 953,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 954,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'STN',
#   'alid': 19917,
#   'airline_id': '5X',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 955,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'MEX',
#   'alid': 21351,
#   'airline_id': 'Y4',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 956,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 957,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 958,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SAP',
#   'alid': 19574,
#   'airline_id': 'TA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 959,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GRU',
#   'alid': 19552,
#   'airline_id': 'LA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 960,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'SAP',
#   'alid': 19574,
#   'airline_id': 'TA',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 961,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BRU',
#   'alid': 20277,
#   'airline_id': 'OZ',
#   'dom_fgn': 0,
#   'scheduled': 17,
#   'chartered': 0,
#   'total': 17},
#  {'index': 962,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CDG',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 963,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'OPO',
#   'alid': 19576,
#   'airline_id': 'TP',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 964,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'CDG',
#   'alid': 20107,
#   'airline_id': 'FX',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 965,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GYD',
#   'alid': 21692,
#   'airline_id': 'J2',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 966,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CKG',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 967,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 968,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SVD',
#   'alid': 19542,
#   'airline_id': 'BW',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 969,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 970,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ADD',
#   'alid': 20153,
#   'airline_id': 'ET',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 971,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GYD',
#   'alid': 21692,
#   'airline_id': 'J2',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 972,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'BEG',
#   'alid': 21738,
#   'airline_id': 'JU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 973,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CKG',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 974,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 975,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'LIR',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 976,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SNN',
#   'alid': 19540,
#   'airline_id': 'BA',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 977,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 978,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 979,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'HKG',
#   'alid': 19545,
#   'airline_id': 'CV',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 980,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CUR',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 981,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CKG',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 982,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'ADD',
#   'alid': 20153,
#   'airline_id': 'ET',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 983,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 984,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'SVD',
#   'alid': 19542,
#   'airline_id': 'BW',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 985,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CKG',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 986,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GYD',
#   'alid': 21692,
#   'airline_id': 'J2',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 987,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'BZE',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 988,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'OPO',
#   'alid': 19576,
#   'airline_id': 'TP',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 989,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'YUL',
#   'alid': 20452,
#   'airline_id': 'YX',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 990,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'PLS',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 991,
#   'year': 2019,
#   'dep_airport': 'EWR',
#   'des_airport': 'MBJ',
#   'alid': 19977,
#   'airline_id': 'UA',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 992,
#   'year': 2020,
#   'dep_airport': 'EWR',
#   'des_airport': 'ORY',
#   'alid': 22002,
#   'airline_id': 'LV',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 993,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CKG',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 994,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CTU',
#   'alid': 21271,
#   'airline_id': 'HU',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 995,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'TAS',
#   'alid': 20080,
#   'airline_id': 'HY',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 996,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 997,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'CUR',
#   'alid': 20409,
#   'airline_id': 'B6',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 998,
#   'year': 2019,
#   'dep_airport': 'JFK',
#   'des_airport': 'GYD',
#   'alid': 21692,
#   'airline_id': 'J2',
#   'dom_fgn': 0,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  {'index': 999,
#   'year': 2020,
#   'dep_airport': 'JFK',
#   'des_airport': 'DSS',
#   'alid': 19790,
#   'airline_id': 'DL',
#   'dom_fgn': 1,
#   'scheduled': 18,
#   'chartered': 0,
#   'total': 18},
#  ...]

# %%
routes_dict = [columns_to_dict(row) for row in session.query(Routes).all()]
routes_dict
# Out:
# [{'index': 0,
#   'airline_id': '2B',
#   'dep_airport_id': 'AER',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 1,
#   'airline_id': '2B',
#   'dep_airport_id': 'ASF',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 2,
#   'airline_id': '2B',
#   'dep_airport_id': 'ASF',
#   'des_airport_id': 'MRV',
#   'stops': 0},
#  {'index': 3,
#   'airline_id': '2B',
#   'dep_airport_id': 'CEK',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 4,
#   'airline_id': '2B',
#   'dep_airport_id': 'CEK',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 5,
#   'airline_id': '2B',
#   'dep_airport_id': 'DME',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 6,
#   'airline_id': '2B',
#   'dep_airport_id': 'DME',
#   'des_airport_id': 'NBC',
#   'stops': 0},
#  {'index': 7,
#   'airline_id': '2B',
#   'dep_airport_id': 'DME',
#   'des_airport_id': 'TGK',
#   'stops': 0},
#  {'index': 8,
#   'airline_id': '2B',
#   'dep_airport_id': 'DME',
#   'des_airport_id': 'UUA',
#   'stops': 0},
#  {'index': 9,
#   'airline_id': '2B',
#   'dep_airport_id': 'EGO',
#   'des_airport_id': 'KGD',
#   'stops': 0},
#  {'index': 10,
#   'airline_id': '2B',
#   'dep_airport_id': 'EGO',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 11,
#   'airline_id': '2B',
#   'dep_airport_id': 'GYD',
#   'des_airport_id': 'NBC',
#   'stops': 0},
#  {'index': 12,
#   'airline_id': '2B',
#   'dep_airport_id': 'KGD',
#   'des_airport_id': 'EGO',
#   'stops': 0},
#  {'index': 13,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'AER',
#   'stops': 0},
#  {'index': 14,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'ASF',
#   'stops': 0},
#  {'index': 15,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'CEK',
#   'stops': 0},
#  {'index': 16,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'DME',
#   'stops': 0},
#  {'index': 17,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'EGO',
#   'stops': 0},
#  {'index': 18,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'LED',
#   'stops': 0},
#  {'index': 19,
#   'airline_id': '2B',
#   'dep_airport_id': 'KZN',
#   'des_airport_id': 'SVX',
#   'stops': 0},
#  {'index': 20,
#   'airline_id': '2B',
#   'dep_airport_id': 'LED',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 21,
#   'airline_id': '2B',
#   'dep_airport_id': 'LED',
#   'des_airport_id': 'NBC',
#   'stops': 0},
#  {'index': 22,
#   'airline_id': '2B',
#   'dep_airport_id': 'LED',
#   'des_airport_id': 'UUA',
#   'stops': 0},
#  {'index': 23,
#   'airline_id': '2B',
#   'dep_airport_id': 'MRV',
#   'des_airport_id': 'ASF',
#   'stops': 0},
#  {'index': 24,
#   'airline_id': '2B',
#   'dep_airport_id': 'NBC',
#   'des_airport_id': 'DME',
#   'stops': 0},
#  {'index': 25,
#   'airline_id': '2B',
#   'dep_airport_id': 'NBC',
#   'des_airport_id': 'GYD',
#   'stops': 0},
#  {'index': 26,
#   'airline_id': '2B',
#   'dep_airport_id': 'NBC',
#   'des_airport_id': 'LED',
#   'stops': 0},
#  {'index': 27,
#   'airline_id': '2B',
#   'dep_airport_id': 'NBC',
#   'des_airport_id': 'SVX',
#   'stops': 0},
#  {'index': 28,
#   'airline_id': '2B',
#   'dep_airport_id': 'NJC',
#   'des_airport_id': 'SVX',
#   'stops': 0},
#  {'index': 29,
#   'airline_id': '2B',
#   'dep_airport_id': 'NJC',
#   'des_airport_id': 'UUA',
#   'stops': 0},
#  {'index': 30,
#   'airline_id': '2B',
#   'dep_airport_id': 'NUX',
#   'des_airport_id': 'SVX',
#   'stops': 0},
#  {'index': 31,
#   'airline_id': '2B',
#   'dep_airport_id': 'OVB',
#   'des_airport_id': 'CEK',
#   'stops': 0},
#  {'index': 32,
#   'airline_id': '2B',
#   'dep_airport_id': 'OVB',
#   'des_airport_id': 'SVX',
#   'stops': 0},
#  {'index': 33,
#   'airline_id': '2B',
#   'dep_airport_id': 'SVX',
#   'des_airport_id': 'KZN',
#   'stops': 0},
#  {'index': 34,
#   'airline_id': '2B',
#   'dep_airport_id': 'SVX',
#   'des_airport_id': 'NBC',
#   'stops': 0},
#  {'index': 35,
#   'airline_id': '2B',
#   'dep_airport_id': 'SVX',
#   'des_airport_id': 'NJC',
#   'stops': 0},
#  {'index': 36,
#   'airline_id': '2B',
#   'dep_airport_id': 'SVX',
#   'des_airport_id': 'NUX',
#   'stops': 0},
#  {'index': 37,
#   'airline_id': '2B',
#   'dep_airport_id': 'SVX',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 38,
#   'airline_id': '2B',
#   'dep_airport_id': 'TGK',
#   'des_airport_id': 'DME',
#   'stops': 0},
#  {'index': 39,
#   'airline_id': '2B',
#   'dep_airport_id': 'UUA',
#   'des_airport_id': 'DME',
#   'stops': 0},
#  {'index': 40,
#   'airline_id': '2B',
#   'dep_airport_id': 'UUA',
#   'des_airport_id': 'LED',
#   'stops': 0},
#  {'index': 41,
#   'airline_id': '2B',
#   'dep_airport_id': 'UUA',
#   'des_airport_id': 'NJC',
#   'stops': 0},
#  {'index': 42,
#   'airline_id': '2G',
#   'dep_airport_id': 'BTK',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 43,
#   'airline_id': '2G',
#   'dep_airport_id': 'BTK',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 44,
#   'airline_id': '2G',
#   'dep_airport_id': 'CEK',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 45,
#   'airline_id': '2G',
#   'dep_airport_id': 'HTA',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 46,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'BTK',
#   'stops': 0},
#  {'index': 47,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'HTA',
#   'stops': 0},
#  {'index': 48,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'KCK',
#   'stops': 0},
#  {'index': 49,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'ODO',
#   'stops': 0},
#  {'index': 50,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 51,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'UKX',
#   'stops': 0},
#  {'index': 52,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'ULK',
#   'stops': 0},
#  {'index': 53,
#   'airline_id': '2G',
#   'dep_airport_id': 'IKT',
#   'des_airport_id': 'YKS',
#   'stops': 0},
#  {'index': 54,
#   'airline_id': '2G',
#   'dep_airport_id': 'KCK',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 55,
#   'airline_id': '2G',
#   'dep_airport_id': 'MJZ',
#   'des_airport_id': 'OVB',
#   'stops': 0},
#  {'index': 56,
#   'airline_id': '2G',
#   'dep_airport_id': 'ODO',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 57,
#   'airline_id': '2G',
#   'dep_airport_id': 'OVB',
#   'des_airport_id': 'BTK',
#   'stops': 0},
#  {'index': 58,
#   'airline_id': '2G',
#   'dep_airport_id': 'OVB',
#   'des_airport_id': 'CEK',
#   'stops': 0},
#  {'index': 59,
#   'airline_id': '2G',
#   'dep_airport_id': 'OVB',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 60,
#   'airline_id': '2G',
#   'dep_airport_id': 'UKX',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 61,
#   'airline_id': '2G',
#   'dep_airport_id': 'ULK',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 62,
#   'airline_id': '2G',
#   'dep_airport_id': 'YKS',
#   'des_airport_id': 'IKT',
#   'stops': 0},
#  {'index': 63,
#   'airline_id': '2I',
#   'dep_airport_id': 'AYP',
#   'des_airport_id': 'LIM',
#   'stops': 0},
#  {'index': 64,
#   'airline_id': '2I',
#   'dep_airport_id': 'CUZ',
#   'des_airport_id': 'LIM',
#   'stops': 0},
#  {'index': 65,
#   'airline_id': '2I',
#   'dep_airport_id': 'CUZ',
#   'des_airport_id': 'PEM',
#   'stops': 0},
#  {'index': 66,
#   'airline_id': '2I',
#   'dep_airport_id': 'HUU',
#   'des_airport_id': 'LIM',
#   'stops': 0},
#  {'index': 67,
#   'airline_id': '2I',
#   'dep_airport_id': 'IQT',
#   'des_airport_id': 'PCL',
#   'stops': 0},
#  {'index': 68,
#   'airline_id': '2I',
#   'dep_airport_id': 'IQT',
#   'des_airport_id': 'TPP',
#   'stops': 0},
#  {'index': 69,
#   'airline_id': '2I',
#   'dep_airport_id': 'LIM',
#   'des_airport_id': 'AYP',
#   'stops': 0},
#  {'index': 70,
#   'airline_id': '2I',
#   'dep_airport_id': 'LIM',
#   'des_airport_id': 'CUZ',
#   'stops': 0},
#  {'index': 71,
#   'airline_id': '2I',
#   'dep_airport_id': 'LIM',
#   'des_airport_id': 'HUU',
#   'stops': 0},
#  {'index': 72,
#   'airline_id': '2I',
#   'dep_airport_id': 'LIM',
#   'des_airport_id': 'PCL',
#   'stops': 0},
#  {'index': 73,
#   'airline_id': '2I',
#   'dep_airport_id': 'LIM',
#   'des_airport_id': 'TPP',
#   'stops': 0},
#  {'index': 74,
#   'airline_id': '2I',
#   'dep_airport_id': 'PCL',
#   'des_airport_id': 'IQT',
#   'stops': 0},
#  {'index': 75,
#   'airline_id': '2I',
#   'dep_airport_id': 'PCL',
#   'des_airport_id': 'LIM',
#   'stops': 0},
#  {'index': 76,
#   'airline_id': '2I',
#   'dep_airport_id': 'PCL',
#   'des_airport_id': 'TPP',
#   'stops': 0},
#  {'index': 77,
#   'airline_id': '2I',
#   'dep_airport_id': 'PEM',
#   'des_airport_id': 'CUZ',
#   'stops': 0},
#  {'index': 78,
#   'airline_id': '2I',
#   'dep_airport_id': 'TPP',
#   'des_airport_id': 'IQT',
#   'stops': 0},
#  {'index': 79,
#   'airline_id': '2I',
#   'dep_airport_id': 'TPP',
#   'des_airport_id': 'LIM',
#   'stops': 0},
#  {'index': 80,
#   'airline_id': '2I',
#   'dep_airport_id': 'TPP',
#   'des_airport_id': 'PCL',
#   'stops': 0},
#  {'index': 81,
#   'airline_id': '2J',
#   'dep_airport_id': 'ABJ',
#   'des_airport_id': 'BOY',
#   'stops': 0},
#  {'index': 82,
#   'airline_id': '2J',
#   'dep_airport_id': 'ABJ',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 83,
#   'airline_id': '2J',
#   'dep_airport_id': 'ACC',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 84,
#   'airline_id': '2J',
#   'dep_airport_id': 'BKO',
#   'des_airport_id': 'ABJ',
#   'stops': 0},
#  {'index': 85,
#   'airline_id': '2J',
#   'dep_airport_id': 'BKO',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 86,
#   'airline_id': '2J',
#   'dep_airport_id': 'BKO',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 87,
#   'airline_id': '2J',
#   'dep_airport_id': 'BOY',
#   'des_airport_id': 'ABJ',
#   'stops': 0},
#  {'index': 88,
#   'airline_id': '2J',
#   'dep_airport_id': 'BOY',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 89,
#   'airline_id': '2J',
#   'dep_airport_id': 'COO',
#   'des_airport_id': 'LFW',
#   'stops': 0},
#  {'index': 90,
#   'airline_id': '2J',
#   'dep_airport_id': 'COO',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 91,
#   'airline_id': '2J',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'BKO',
#   'stops': 0},
#  {'index': 92,
#   'airline_id': '2J',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 93,
#   'airline_id': '2J',
#   'dep_airport_id': 'LFW',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 94,
#   'airline_id': '2J',
#   'dep_airport_id': 'NIM',
#   'des_airport_id': 'OUA',
#   'stops': 0},
#  {'index': 95,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'ABJ',
#   'stops': 0},
#  {'index': 96,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'ACC',
#   'stops': 0},
#  {'index': 97,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'BKO',
#   'stops': 0},
#  {'index': 98,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'BOY',
#   'stops': 0},
#  {'index': 99,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'COO',
#   'stops': 0},
#  {'index': 100,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 101,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'LFW',
#   'stops': 0},
#  {'index': 102,
#   'airline_id': '2J',
#   'dep_airport_id': 'OUA',
#   'des_airport_id': 'NIM',
#   'stops': 0},
#  {'index': 103,
#   'airline_id': '2K',
#   'dep_airport_id': 'BOG',
#   'des_airport_id': 'GYE',
#   'stops': 0},
#  {'index': 104,
#   'airline_id': '2K',
#   'dep_airport_id': 'BOG',
#   'des_airport_id': 'UIO',
#   'stops': 0},
#  {'index': 105,
#   'airline_id': '2K',
#   'dep_airport_id': 'CLO',
#   'des_airport_id': 'GYE',
#   'stops': 0},
#  {'index': 106,
#   'airline_id': '2K',
#   'dep_airport_id': 'GYE',
#   'des_airport_id': 'BOG',
#   'stops': 0},
#  {'index': 107,
#   'airline_id': '2K',
#   'dep_airport_id': 'GYE',
#   'des_airport_id': 'CLO',
#   'stops': 0},
#  {'index': 108,
#   'airline_id': '2K',
#   'dep_airport_id': 'GYE',
#   'des_airport_id': 'SCY',
#   'stops': 0},
#  {'index': 109,
#   'airline_id': '2K',
#   'dep_airport_id': 'GYE',
#   'des_airport_id': 'UIO',
#   'stops': 0},
#  {'index': 110,
#   'airline_id': '2K',
#   'dep_airport_id': 'OCC',
#   'des_airport_id': 'UIO',
#   'stops': 0},
#  {'index': 111,
#   'airline_id': '2K',
#   'dep_airport_id': 'SCY',
#   'des_airport_id': 'GYE',
#   'stops': 0},
#  {'index': 112,
#   'airline_id': '2K',
#   'dep_airport_id': 'UIO',
#   'des_airport_id': 'BOG',
#   'stops': 0},
#  {'index': 113,
#   'airline_id': '2K',
#   'dep_airport_id': 'UIO',
#   'des_airport_id': 'GYE',
#   'stops': 0},
#  {'index': 114,
#   'airline_id': '2K',
#   'dep_airport_id': 'UIO',
#   'des_airport_id': 'OCC',
#   'stops': 0},
#  {'index': 115,
#   'airline_id': '2L',
#   'dep_airport_id': 'BDS',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 116,
#   'airline_id': '2L',
#   'dep_airport_id': 'BOD',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 117,
#   'airline_id': '2L',
#   'dep_airport_id': 'BRS',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 118,
#   'airline_id': '2L',
#   'dep_airport_id': 'GVA',
#   'des_airport_id': 'LPA',
#   'stops': 0},
#  {'index': 119,
#   'airline_id': '2L',
#   'dep_airport_id': 'LCA',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 120,
#   'airline_id': '2L',
#   'dep_airport_id': 'LPA',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 121,
#   'airline_id': '2L',
#   'dep_airport_id': 'RMF',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 122,
#   'airline_id': '2L',
#   'dep_airport_id': 'TFS',
#   'des_airport_id': 'GVA',
#   'stops': 0},
#  {'index': 123,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'BDS',
#   'stops': 0},
#  {'index': 124,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'BOD',
#   'stops': 0},
#  {'index': 125,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'BRS',
#   'stops': 0},
#  {'index': 126,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'LCA',
#   'stops': 0},
#  {'index': 127,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'LPA',
#   'stops': 0},
#  {'index': 128,
#   'airline_id': '2L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'RMF',
#   'stops': 0},
#  {'index': 129,
#   'airline_id': '2N',
#   'dep_airport_id': 'AJR',
#   'des_airport_id': 'LYC',
#   'stops': 0},
#  {'index': 130,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'GEV',
#   'stops': 0},
#  {'index': 131,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'HAD',
#   'stops': 0},
#  {'index': 132,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'JKG',
#   'stops': 0},
#  {'index': 133,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'KRF',
#   'stops': 0},
#  {'index': 134,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'KSD',
#   'stops': 0},
#  {'index': 135,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'LYC',
#   'stops': 0},
#  {'index': 136,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'MHQ',
#   'stops': 0},
#  {'index': 137,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'OER',
#   'stops': 0},
#  {'index': 138,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'POR',
#   'stops': 0},
#  {'index': 139,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'TRF',
#   'stops': 0},
#  {'index': 140,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'VBY',
#   'stops': 0},
#  {'index': 141,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'VHM',
#   'stops': 0},
#  {'index': 142,
#   'airline_id': '2N',
#   'dep_airport_id': 'ARN',
#   'des_airport_id': 'VXO',
#   'stops': 0},
#  {'index': 143,
#   'airline_id': '2N',
#   'dep_airport_id': 'GEV',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 144,
#   'airline_id': '2N',
#   'dep_airport_id': 'GEV',
#   'des_airport_id': 'KRF',
#   'stops': 0},
#  {'index': 145,
#   'airline_id': '2N',
#   'dep_airport_id': 'HAD',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 146,
#   'airline_id': '2N',
#   'dep_airport_id': 'HAD',
#   'des_airport_id': 'JKG',
#   'stops': 0},
#  {'index': 147,
#   'airline_id': '2N',
#   'dep_airport_id': 'HAD',
#   'des_airport_id': 'VXO',
#   'stops': 0},
#  {'index': 148,
#   'airline_id': '2N',
#   'dep_airport_id': 'HMV',
#   'des_airport_id': 'VHM',
#   'stops': 0},
#  {'index': 149,
#   'airline_id': '2N',
#   'dep_airport_id': 'JKG',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 150,
#   'airline_id': '2N',
#   'dep_airport_id': 'JKG',
#   'des_airport_id': 'HAD',
#   'stops': 0},
#  {'index': 151,
#   'airline_id': '2N',
#   'dep_airport_id': 'KOK',
#   'des_airport_id': 'POR',
#   'stops': 0},
#  {'index': 152,
#   'airline_id': '2N',
#   'dep_airport_id': 'KRF',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 153,
#   'airline_id': '2N',
#   'dep_airport_id': 'KRF',
#   'des_airport_id': 'GEV',
#   'stops': 0},
#  {'index': 154,
#   'airline_id': '2N',
#   'dep_airport_id': 'KSD',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 155,
#   'airline_id': '2N',
#   'dep_airport_id': 'LYC',
#   'des_airport_id': 'AJR',
#   'stops': 0},
#  {'index': 156,
#   'airline_id': '2N',
#   'dep_airport_id': 'LYC',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 157,
#   'airline_id': '2N',
#   'dep_airport_id': 'MHQ',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 158,
#   'airline_id': '2N',
#   'dep_airport_id': 'MHQ',
#   'des_airport_id': 'TKU',
#   'stops': 0},
#  {'index': 159,
#   'airline_id': '2N',
#   'dep_airport_id': 'OER',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 160,
#   'airline_id': '2N',
#   'dep_airport_id': 'OSL',
#   'des_airport_id': 'VXO',
#   'stops': 0},
#  {'index': 161,
#   'airline_id': '2N',
#   'dep_airport_id': 'POR',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 162,
#   'airline_id': '2N',
#   'dep_airport_id': 'POR',
#   'des_airport_id': 'KOK',
#   'stops': 0},
#  {'index': 163,
#   'airline_id': '2N',
#   'dep_airport_id': 'TKU',
#   'des_airport_id': 'MHQ',
#   'stops': 0},
#  {'index': 164,
#   'airline_id': '2N',
#   'dep_airport_id': 'TRF',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 165,
#   'airline_id': '2N',
#   'dep_airport_id': 'VBY',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 166,
#   'airline_id': '2N',
#   'dep_airport_id': 'VHM',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 167,
#   'airline_id': '2N',
#   'dep_airport_id': 'VHM',
#   'des_airport_id': 'HMV',
#   'stops': 0},
#  {'index': 168,
#   'airline_id': '2N',
#   'dep_airport_id': 'VXO',
#   'des_airport_id': 'ARN',
#   'stops': 0},
#  {'index': 169,
#   'airline_id': '2N',
#   'dep_airport_id': 'VXO',
#   'des_airport_id': 'OSL',
#   'stops': 0},
#  {'index': 170,
#   'airline_id': '2O',
#   'dep_airport_id': 'ADQ',
#   'des_airport_id': 'AOS',
#   'stops': 0},
#  {'index': 171,
#   'airline_id': '2O',
#   'dep_airport_id': 'ADQ',
#   'des_airport_id': 'KKB',
#   'stops': 0},
#  {'index': 172,
#   'airline_id': '2O',
#   'dep_airport_id': 'ADQ',
#   'des_airport_id': 'KLN',
#   'stops': 0},
#  {'index': 173,
#   'airline_id': '2O',
#   'dep_airport_id': 'ADQ',
#   'des_airport_id': 'KOZ',
#   'stops': 0},
#  {'index': 174,
#   'airline_id': '2O',
#   'dep_airport_id': 'ADQ',
#   'des_airport_id': 'OLH',
#   'stops': 0},
#  {'index': 175,
#   'airline_id': '2O',
#   'dep_airport_id': 'AOS',
#   'des_airport_id': 'KZB',
#   'stops': 0},
#  {'index': 176,
#   'airline_id': '2O',
#   'dep_airport_id': 'KKB',
#   'des_airport_id': 'SYB',
#   'stops': 0},
#  {'index': 177,
#   'airline_id': '2O',
#   'dep_airport_id': 'KLN',
#   'des_airport_id': 'KYK',
#   'stops': 0},
#  {'index': 178,
#   'airline_id': '2O',
#   'dep_airport_id': 'KOZ',
#   'des_airport_id': 'ORI',
#   'stops': 0},
#  {'index': 179,
#   'airline_id': '2O',
#   'dep_airport_id': 'SYB',
#   'des_airport_id': 'KPR',
#   'stops': 0},
#  {'index': 180,
#   'airline_id': '2P',
#   'dep_airport_id': 'BSO',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 181,
#   'airline_id': '2P',
#   'dep_airport_id': 'BXU',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 182,
#   'airline_id': '2P',
#   'dep_airport_id': 'CBO',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 183,
#   'airline_id': '2P',
#   'dep_airport_id': 'CGY',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 184,
#   'airline_id': '2P',
#   'dep_airport_id': 'CRM',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 185,
#   'airline_id': '2P',
#   'dep_airport_id': 'DGT',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 186,
#   'airline_id': '2P',
#   'dep_airport_id': 'DWC',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 187,
#   'airline_id': '2P',
#   'dep_airport_id': 'GES',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 188,
#   'airline_id': '2P',
#   'dep_airport_id': 'KLO',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 189,
#   'airline_id': '2P',
#   'dep_airport_id': 'LGP',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 190,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'BSO',
#   'stops': 0},
#  {'index': 191,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'BXU',
#   'stops': 0},
#  {'index': 192,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'CBO',
#   'stops': 0},
#  {'index': 193,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'CGY',
#   'stops': 0},
#  {'index': 194,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'CRM',
#   'stops': 0},
#  {'index': 195,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'DGT',
#   'stops': 0},
#  {'index': 196,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'DWC',
#   'stops': 0},
#  {'index': 197,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'GES',
#   'stops': 0},
#  {'index': 198,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'KLO',
#   'stops': 0},
#  {'index': 199,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'LGP',
#   'stops': 0},
#  {'index': 200,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'MPH',
#   'stops': 0},
#  {'index': 201,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'OZC',
#   'stops': 0},
#  {'index': 202,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'PPS',
#   'stops': 0},
#  {'index': 203,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'RXS',
#   'stops': 0},
#  {'index': 204,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'SUG',
#   'stops': 0},
#  {'index': 205,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'TUG',
#   'stops': 0},
#  {'index': 206,
#   'airline_id': '2P',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'ZAM',
#   'stops': 0},
#  {'index': 207,
#   'airline_id': '2P',
#   'dep_airport_id': 'MPH',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 208,
#   'airline_id': '2P',
#   'dep_airport_id': 'OZC',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 209,
#   'airline_id': '2P',
#   'dep_airport_id': 'PPS',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 210,
#   'airline_id': '2P',
#   'dep_airport_id': 'RXS',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 211,
#   'airline_id': '2P',
#   'dep_airport_id': 'SUG',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 212,
#   'airline_id': '2P',
#   'dep_airport_id': 'TUG',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 213,
#   'airline_id': '2P',
#   'dep_airport_id': 'ZAM',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 214,
#   'airline_id': '2Z',
#   'dep_airport_id': 'AUX',
#   'des_airport_id': 'PMW',
#   'stops': 0},
#  {'index': 215,
#   'airline_id': '2Z',
#   'dep_airport_id': 'BRA',
#   'des_airport_id': 'BSB',
#   'stops': 0},
#  {'index': 216,
#   'airline_id': '2Z',
#   'dep_airport_id': 'BRA',
#   'des_airport_id': 'SSA',
#   'stops': 0},
#  {'index': 217,
#   'airline_id': '2Z',
#   'dep_airport_id': 'BSB',
#   'des_airport_id': 'BRA',
#   'stops': 0},
#  {'index': 218,
#   'airline_id': '2Z',
#   'dep_airport_id': 'BSB',
#   'des_airport_id': 'OPS',
#   'stops': 0},
#  {'index': 219,
#   'airline_id': '2Z',
#   'dep_airport_id': 'BSB',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 220,
#   'airline_id': '2Z',
#   'dep_airport_id': 'CAC',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 221,
#   'airline_id': '2Z',
#   'dep_airport_id': 'CGB',
#   'des_airport_id': 'GYN',
#   'stops': 0},
#  {'index': 222,
#   'airline_id': '2Z',
#   'dep_airport_id': 'CGB',
#   'des_airport_id': 'OPS',
#   'stops': 0},
#  {'index': 223,
#   'airline_id': '2Z',
#   'dep_airport_id': 'CGR',
#   'des_airport_id': 'DOU',
#   'stops': 0},
#  {'index': 224,
#   'airline_id': '2Z',
#   'dep_airport_id': 'DOU',
#   'des_airport_id': 'CGR',
#   'stops': 0},
#  {'index': 225,
#   'airline_id': '2Z',
#   'dep_airport_id': 'DOU',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 226,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GIG',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 227,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'CAC',
#   'stops': 0},
#  {'index': 228,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'DOU',
#   'stops': 0},
#  {'index': 229,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 230,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'UBA',
#   'stops': 0},
#  {'index': 231,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'UDI',
#   'stops': 0},
#  {'index': 232,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GRU',
#   'des_airport_id': 'VDC',
#   'stops': 0},
#  {'index': 233,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GYN',
#   'des_airport_id': 'CGB',
#   'stops': 0},
#  {'index': 234,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GYN',
#   'des_airport_id': 'PMW',
#   'stops': 0},
#  {'index': 235,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GYN',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 236,
#   'airline_id': '2Z',
#   'dep_airport_id': 'GYN',
#   'des_airport_id': 'UDI',
#   'stops': 0},
#  {'index': 237,
#   'airline_id': '2Z',
#   'dep_airport_id': 'OPS',
#   'des_airport_id': 'BSB',
#   'stops': 0},
#  {'index': 238,
#   'airline_id': '2Z',
#   'dep_airport_id': 'OPS',
#   'des_airport_id': 'CGB',
#   'stops': 0},
#  {'index': 239,
#   'airline_id': '2Z',
#   'dep_airport_id': 'PLU',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 240,
#   'airline_id': '2Z',
#   'dep_airport_id': 'PMW',
#   'des_airport_id': 'AUX',
#   'stops': 0},
#  {'index': 241,
#   'airline_id': '2Z',
#   'dep_airport_id': 'PMW',
#   'des_airport_id': 'GYN',
#   'stops': 0},
#  {'index': 242,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'BSB',
#   'stops': 0},
#  {'index': 243,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'GIG',
#   'stops': 0},
#  {'index': 244,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 245,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'GYN',
#   'stops': 0},
#  {'index': 246,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'PLU',
#   'stops': 0},
#  {'index': 247,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'SJP',
#   'stops': 0},
#  {'index': 248,
#   'airline_id': '2Z',
#   'dep_airport_id': 'RAO',
#   'des_airport_id': 'UDI',
#   'stops': 0},
#  {'index': 249,
#   'airline_id': '2Z',
#   'dep_airport_id': 'SJP',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 250,
#   'airline_id': '2Z',
#   'dep_airport_id': 'SSA',
#   'des_airport_id': 'BRA',
#   'stops': 0},
#  {'index': 251,
#   'airline_id': '2Z',
#   'dep_airport_id': 'SSA',
#   'des_airport_id': 'VDC',
#   'stops': 0},
#  {'index': 252,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UBA',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 253,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UBA',
#   'des_airport_id': 'UDI',
#   'stops': 0},
#  {'index': 254,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UDI',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 255,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UDI',
#   'des_airport_id': 'GYN',
#   'stops': 0},
#  {'index': 256,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UDI',
#   'des_airport_id': 'RAO',
#   'stops': 0},
#  {'index': 257,
#   'airline_id': '2Z',
#   'dep_airport_id': 'UDI',
#   'des_airport_id': 'UBA',
#   'stops': 0},
#  {'index': 258,
#   'airline_id': '2Z',
#   'dep_airport_id': 'VDC',
#   'des_airport_id': 'GRU',
#   'stops': 0},
#  {'index': 259,
#   'airline_id': '2Z',
#   'dep_airport_id': 'VDC',
#   'des_airport_id': 'SSA',
#   'stops': 0},
#  {'index': 260,
#   'airline_id': '3E',
#   'dep_airport_id': 'BRL',
#   'des_airport_id': 'ORD',
#   'stops': 0},
#  {'index': 261,
#   'airline_id': '3E',
#   'dep_airport_id': 'BRL',
#   'des_airport_id': 'STL',
#   'stops': 0},
#  {'index': 262,
#   'airline_id': '3E',
#   'dep_airport_id': 'DEC',
#   'des_airport_id': 'ORD',
#   'stops': 0},
#  {'index': 263,
#   'airline_id': '3E',
#   'dep_airport_id': 'DEC',
#   'des_airport_id': 'STL',
#   'stops': 0},
#  {'index': 264,
#   'airline_id': '3E',
#   'dep_airport_id': 'JBR',
#   'des_airport_id': 'STL',
#   'stops': 0},
#  {'index': 265,
#   'airline_id': '3E',
#   'dep_airport_id': 'ORD',
#   'des_airport_id': 'BRL',
#   'stops': 0},
#  {'index': 266,
#   'airline_id': '3E',
#   'dep_airport_id': 'ORD',
#   'des_airport_id': 'DEC',
#   'stops': 0},
#  {'index': 267,
#   'airline_id': '3E',
#   'dep_airport_id': 'STL',
#   'des_airport_id': 'BRL',
#   'stops': 0},
#  {'index': 268,
#   'airline_id': '3E',
#   'dep_airport_id': 'STL',
#   'des_airport_id': 'DEC',
#   'stops': 0},
#  {'index': 269,
#   'airline_id': '3E',
#   'dep_airport_id': 'STL',
#   'des_airport_id': 'JBR',
#   'stops': 0},
#  {'index': 270,
#   'airline_id': '3F',
#   'dep_airport_id': 'CGA',
#   'des_airport_id': 'HYL',
#   'stops': 0},
#  {'index': 271,
#   'airline_id': '3F',
#   'dep_airport_id': 'CGA',
#   'des_airport_id': 'KTN',
#   'stops': 0},
#  {'index': 272,
#   'airline_id': '3F',
#   'dep_airport_id': 'HYL',
#   'des_airport_id': 'CGA',
#   'stops': 0},
#  {'index': 273,
#   'airline_id': '3F',
#   'dep_airport_id': 'HYL',
#   'des_airport_id': 'KTB',
#   'stops': 0},
#  {'index': 274,
#   'airline_id': '3F',
#   'dep_airport_id': 'HYL',
#   'des_airport_id': 'KTN',
#   'stops': 0},
#  {'index': 275,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTB',
#   'des_airport_id': 'HYL',
#   'stops': 0},
#  {'index': 276,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTB',
#   'des_airport_id': 'KTN',
#   'stops': 0},
#  {'index': 277,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTN',
#   'des_airport_id': 'CGA',
#   'stops': 0},
#  {'index': 278,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTN',
#   'des_airport_id': 'HYL',
#   'stops': 0},
#  {'index': 279,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTN',
#   'des_airport_id': 'KTB',
#   'stops': 0},
#  {'index': 280,
#   'airline_id': '3F',
#   'dep_airport_id': 'KTN',
#   'des_airport_id': 'MTM',
#   'stops': 0},
#  {'index': 281,
#   'airline_id': '3F',
#   'dep_airport_id': 'MTM',
#   'des_airport_id': 'KTN',
#   'stops': 0},
#  {'index': 282,
#   'airline_id': '3G',
#   'dep_airport_id': 'ACC',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 283,
#   'airline_id': '3G',
#   'dep_airport_id': 'ACC',
#   'des_airport_id': 'LOS',
#   'stops': 0},
#  {'index': 284,
#   'airline_id': '3G',
#   'dep_airport_id': 'ACC',
#   'des_airport_id': 'ROB',
#   'stops': 0},
#  {'index': 285,
#   'airline_id': '3G',
#   'dep_airport_id': 'BCN',
#   'des_airport_id': 'BJL',
#   'stops': 0},
#  {'index': 286,
#   'airline_id': '3G',
#   'dep_airport_id': 'BJL',
#   'des_airport_id': 'BCN',
#   'stops': 0},
#  {'index': 287,
#   'airline_id': '3G',
#   'dep_airport_id': 'BJL',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 288,
#   'airline_id': '3G',
#   'dep_airport_id': 'BJL',
#   'des_airport_id': 'FNA',
#   'stops': 0},
#  {'index': 289,
#   'airline_id': '3G',
#   'dep_airport_id': 'CKY',
#   'des_airport_id': 'OXB',
#   'stops': 0},
#  {'index': 290,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'ACC',
#   'stops': 0},
#  {'index': 291,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'BJL',
#   'stops': 0},
#  {'index': 292,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'DLA',
#   'stops': 0},
#  {'index': 293,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'FNA',
#   'stops': 0},
#  {'index': 294,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'LOS',
#   'stops': 0},
#  {'index': 295,
#   'airline_id': '3G',
#   'dep_airport_id': 'DKR',
#   'des_airport_id': 'OXB',
#   'stops': 0},
#  {'index': 296,
#   'airline_id': '3G',
#   'dep_airport_id': 'DLA',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 297,
#   'airline_id': '3G',
#   'dep_airport_id': 'DLA',
#   'des_airport_id': 'LOS',
#   'stops': 0},
#  {'index': 298,
#   'airline_id': '3G',
#   'dep_airport_id': 'FNA',
#   'des_airport_id': 'BJL',
#   'stops': 0},
#  {'index': 299,
#   'airline_id': '3G',
#   'dep_airport_id': 'FNA',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 300,
#   'airline_id': '3G',
#   'dep_airport_id': 'FNA',
#   'des_airport_id': 'LGW',
#   'stops': 0},
#  {'index': 301,
#   'airline_id': '3G',
#   'dep_airport_id': 'FNA',
#   'des_airport_id': 'ROB',
#   'stops': 0},
#  {'index': 302,
#   'airline_id': '3G',
#   'dep_airport_id': 'LGW',
#   'des_airport_id': 'FNA',
#   'stops': 0},
#  {'index': 303,
#   'airline_id': '3G',
#   'dep_airport_id': 'LOS',
#   'des_airport_id': 'ACC',
#   'stops': 0},
#  {'index': 304,
#   'airline_id': '3G',
#   'dep_airport_id': 'LOS',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 305,
#   'airline_id': '3G',
#   'dep_airport_id': 'LOS',
#   'des_airport_id': 'DLA',
#   'stops': 0},
#  {'index': 306,
#   'airline_id': '3G',
#   'dep_airport_id': 'LOS',
#   'des_airport_id': 'ROB',
#   'stops': 0},
#  {'index': 307,
#   'airline_id': '3G',
#   'dep_airport_id': 'OXB',
#   'des_airport_id': 'CKY',
#   'stops': 0},
#  {'index': 308,
#   'airline_id': '3G',
#   'dep_airport_id': 'OXB',
#   'des_airport_id': 'DKR',
#   'stops': 0},
#  {'index': 309,
#   'airline_id': '3G',
#   'dep_airport_id': 'ROB',
#   'des_airport_id': 'ACC',
#   'stops': 0},
#  {'index': 310,
#   'airline_id': '3G',
#   'dep_airport_id': 'ROB',
#   'des_airport_id': 'FNA',
#   'stops': 0},
#  {'index': 311,
#   'airline_id': '3G',
#   'dep_airport_id': 'ROB',
#   'des_airport_id': 'LOS',
#   'stops': 0},
#  {'index': 312,
#   'airline_id': '3H',
#   'dep_airport_id': 'AKV',
#   'des_airport_id': 'YIK',
#   'stops': 0},
#  {'index': 313,
#   'airline_id': '3H',
#   'dep_airport_id': 'AKV',
#   'des_airport_id': 'YPX',
#   'stops': 0},
#  {'index': 314,
#   'airline_id': '3H',
#   'dep_airport_id': 'XGR',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 315,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGL',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 316,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGL',
#   'des_airport_id': 'YPX',
#   'stops': 0},
#  {'index': 317,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGL',
#   'des_airport_id': 'YUL',
#   'stops': 0},
#  {'index': 318,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YGL',
#   'stops': 0},
#  {'index': 319,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YPH',
#   'stops': 0},
#  {'index': 320,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YSK',
#   'stops': 0},
#  {'index': 321,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YUD',
#   'stops': 0},
#  {'index': 322,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YUL',
#   'stops': 0},
#  {'index': 323,
#   'airline_id': '3H',
#   'dep_airport_id': 'YGW',
#   'des_airport_id': 'YUY',
#   'stops': 0},
#  {'index': 324,
#   'airline_id': '3H',
#   'dep_airport_id': 'YIK',
#   'des_airport_id': 'AKV',
#   'stops': 0},
#  {'index': 325,
#   'airline_id': '3H',
#   'dep_airport_id': 'YIK',
#   'des_airport_id': 'YZG',
#   'stops': 0},
#  {'index': 326,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKG',
#   'des_airport_id': 'YPJ',
#   'stops': 0},
#  {'index': 327,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKG',
#   'des_airport_id': 'YQC',
#   'stops': 0},
#  {'index': 328,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKG',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 329,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKL',
#   'des_airport_id': 'YQB',
#   'stops': 0},
#  {'index': 330,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKL',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 331,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKL',
#   'des_airport_id': 'YWK',
#   'stops': 0},
#  {'index': 332,
#   'airline_id': '3H',
#   'dep_airport_id': 'YKL',
#   'des_airport_id': 'YZV',
#   'stops': 0},
#  {'index': 333,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPH',
#   'des_airport_id': 'YPX',
#   'stops': 0},
#  {'index': 334,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPH',
#   'des_airport_id': 'YUD',
#   'stops': 0},
#  {'index': 335,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPH',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 336,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPJ',
#   'des_airport_id': 'YKG',
#   'stops': 0},
#  {'index': 337,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPJ',
#   'des_airport_id': 'YTQ',
#   'stops': 0},
#  {'index': 338,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPJ',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 339,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPX',
#   'des_airport_id': 'AKV',
#   'stops': 0},
#  {'index': 340,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPX',
#   'des_airport_id': 'YGL',
#   'stops': 0},
#  {'index': 341,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPX',
#   'des_airport_id': 'YPH',
#   'stops': 0},
#  {'index': 342,
#   'airline_id': '3H',
#   'dep_airport_id': 'YPX',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 343,
#   'airline_id': '3H',
#   'dep_airport_id': 'YQB',
#   'des_airport_id': 'YKL',
#   'stops': 0},
#  {'index': 344,
#   'airline_id': '3H',
#   'dep_airport_id': 'YQB',
#   'des_airport_id': 'YUL',
#   'stops': 0},
#  {'index': 345,
#   'airline_id': '3H',
#   'dep_airport_id': 'YQC',
#   'des_airport_id': 'YKG',
#   'stops': 0},
#  {'index': 346,
#   'airline_id': '3H',
#   'dep_airport_id': 'YQC',
#   'des_airport_id': 'YWB',
#   'stops': 0},
#  {'index': 347,
#   'airline_id': '3H',
#   'dep_airport_id': 'YSK',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 348,
#   'airline_id': '3H',
#   'dep_airport_id': 'YSK',
#   'des_airport_id': 'YUD',
#   'stops': 0},
#  {'index': 349,
#   'airline_id': '3H',
#   'dep_airport_id': 'YTQ',
#   'des_airport_id': 'YPJ',
#   'stops': 0},
#  {'index': 350,
#   'airline_id': '3H',
#   'dep_airport_id': 'YTQ',
#   'des_airport_id': 'YVP',
#   'stops': 0},
#  {'index': 351,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUD',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 352,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUD',
#   'des_airport_id': 'YPH',
#   'stops': 0},
#  {'index': 353,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUD',
#   'des_airport_id': 'YSK',
#   'stops': 0},
#  {'index': 354,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUL',
#   'des_airport_id': 'YGL',
#   'stops': 0},
#  {'index': 355,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUL',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 356,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUL',
#   'des_airport_id': 'YQB',
#   'stops': 0},
#  {'index': 357,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUL',
#   'des_airport_id': 'YUY',
#   'stops': 0},
#  {'index': 358,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUY',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 359,
#   'airline_id': '3H',
#   'dep_airport_id': 'YUY',
#   'des_airport_id': 'YUL',
#   'stops': 0},
#  {'index': 360,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'XGR',
#   'stops': 0},
#  {'index': 361,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YGW',
#   'stops': 0},
#  {'index': 362,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YKG',
#   'stops': 0},
#  {'index': 363,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YKL',
#   'stops': 0},
#  {'index': 364,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YPH',
#   'stops': 0},
#  {'index': 365,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YPJ',
#   'stops': 0},
#  {'index': 366,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YPX',
#   'stops': 0},
#  {'index': 367,
#   'airline_id': '3H',
#   'dep_airport_id': 'YVP',
#   'des_airport_id': 'YTQ',
#   'stops': 0},
#  {'index': 368,
#   'airline_id': '3H',
#   'dep_airport_id': 'YWB',
#   'des_airport_id': 'YQC',
#   'stops': 0},
#  {'index': 369,
#   'airline_id': '3H',
#   'dep_airport_id': 'YWB',
#   'des_airport_id': 'YZG',
#   'stops': 0},
#  {'index': 370,
#   'airline_id': '3H',
#   'dep_airport_id': 'YWK',
#   'des_airport_id': 'YKL',
#   'stops': 0},
#  {'index': 371,
#   'airline_id': '3H',
#   'dep_airport_id': 'YWK',
#   'des_airport_id': 'YZV',
#   'stops': 0},
#  {'index': 372,
#   'airline_id': '3H',
#   'dep_airport_id': 'YZG',
#   'des_airport_id': 'YIK',
#   'stops': 0},
#  {'index': 373,
#   'airline_id': '3H',
#   'dep_airport_id': 'YZG',
#   'des_airport_id': 'YWB',
#   'stops': 0},
#  {'index': 374,
#   'airline_id': '3H',
#   'dep_airport_id': 'YZV',
#   'des_airport_id': 'YKL',
#   'stops': 0},
#  {'index': 375,
#   'airline_id': '3H',
#   'dep_airport_id': 'YZV',
#   'des_airport_id': 'YWK',
#   'stops': 0},
#  {'index': 376,
#   'airline_id': '3J',
#   'dep_airport_id': 'JIB',
#   'des_airport_id': 'DXB',
#   'stops': 0},
#  {'index': 377,
#   'airline_id': '3J',
#   'dep_airport_id': 'JIB',
#   'des_airport_id': 'JED',
#   'stops': 0},
#  {'index': 378,
#   'airline_id': '3J',
#   'dep_airport_id': 'JIB',
#   'des_airport_id': 'MGQ',
#   'stops': 0},
#  {'index': 379,
#   'airline_id': '3J',
#   'dep_airport_id': 'MGQ',
#   'des_airport_id': 'NBO',
#   'stops': 0},
#  {'index': 380,
#   'airline_id': '3J',
#   'dep_airport_id': 'NBO',
#   'des_airport_id': 'MGQ',
#   'stops': 0},
#  {'index': 381,
#   'airline_id': '3K',
#   'dep_airport_id': 'BKK',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 382,
#   'airline_id': '3K',
#   'dep_airport_id': 'DRW',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 383,
#   'airline_id': '3K',
#   'dep_airport_id': 'HAK',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 384,
#   'airline_id': '3K',
#   'dep_airport_id': 'HGH',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 385,
#   'airline_id': '3K',
#   'dep_airport_id': 'HKG',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 386,
#   'airline_id': '3K',
#   'dep_airport_id': 'HKT',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 387,
#   'airline_id': '3K',
#   'dep_airport_id': 'KIX',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 388,
#   'airline_id': '3K',
#   'dep_airport_id': 'KIX',
#   'des_airport_id': 'TPE',
#   'stops': 0},
#  {'index': 389,
#   'airline_id': '3K',
#   'dep_airport_id': 'KUL',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 390,
#   'airline_id': '3K',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'KIX',
#   'stops': 0},
#  {'index': 391,
#   'airline_id': '3K',
#   'dep_airport_id': 'MNL',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 392,
#   'airline_id': '3K',
#   'dep_airport_id': 'PEN',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 393,
#   'airline_id': '3K',
#   'dep_airport_id': 'PER',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 394,
#   'airline_id': '3K',
#   'dep_airport_id': 'PNH',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 395,
#   'airline_id': '3K',
#   'dep_airport_id': 'REP',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 396,
#   'airline_id': '3K',
#   'dep_airport_id': 'RGN',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 397,
#   'airline_id': '3K',
#   'dep_airport_id': 'SGN',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 398,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'BKK',
#   'stops': 0},
#  {'index': 399,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'DRW',
#   'stops': 0},
#  {'index': 400,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'HAK',
#   'stops': 0},
#  {'index': 401,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'HGH',
#   'stops': 0},
#  {'index': 402,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'HKG',
#   'stops': 0},
#  {'index': 403,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'HKT',
#   'stops': 0},
#  {'index': 404,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'KUL',
#   'stops': 0},
#  {'index': 405,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'MNL',
#   'stops': 0},
#  {'index': 406,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'PEN',
#   'stops': 0},
#  {'index': 407,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'PER',
#   'stops': 0},
#  {'index': 408,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'PNH',
#   'stops': 0},
#  {'index': 409,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'REP',
#   'stops': 0},
#  {'index': 410,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'RGN',
#   'stops': 0},
#  {'index': 411,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'SGN',
#   'stops': 0},
#  {'index': 412,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'SWA',
#   'stops': 0},
#  {'index': 413,
#   'airline_id': '3K',
#   'dep_airport_id': 'SIN',
#   'des_airport_id': 'TPE',
#   'stops': 0},
#  {'index': 414,
#   'airline_id': '3K',
#   'dep_airport_id': 'SWA',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 415,
#   'airline_id': '3K',
#   'dep_airport_id': 'TPE',
#   'des_airport_id': 'KIX',
#   'stops': 0},
#  {'index': 416,
#   'airline_id': '3K',
#   'dep_airport_id': 'TPE',
#   'des_airport_id': 'SIN',
#   'stops': 0},
#  {'index': 417,
#   'airline_id': '3L',
#   'dep_airport_id': 'ACH',
#   'des_airport_id': 'EBA',
#   'stops': 0},
#  {'index': 418,
#   'airline_id': '3L',
#   'dep_airport_id': 'DRS',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 419,
#   'airline_id': '3L',
#   'dep_airport_id': 'DUS',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 420,
#   'airline_id': '3L',
#   'dep_airport_id': 'EBA',
#   'des_airport_id': 'ACH',
#   'stops': 0},
#  {'index': 421,
#   'airline_id': '3L',
#   'dep_airport_id': 'EBA',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 422,
#   'airline_id': '3L',
#   'dep_airport_id': 'EBA',
#   'des_airport_id': 'MUC',
#   'stops': 0},
#  {'index': 423,
#   'airline_id': '3L',
#   'dep_airport_id': 'EBA',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 424,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'DUS',
#   'stops': 0},
#  {'index': 425,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'EBA',
#   'stops': 0},
#  {'index': 426,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'HAM',
#   'stops': 0},
#  {'index': 427,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'OLB',
#   'stops': 0},
#  {'index': 428,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'TXL',
#   'stops': 0},
#  {'index': 429,
#   'airline_id': '3L',
#   'dep_airport_id': 'FDH',
#   'des_airport_id': 'ZAD',
#   'stops': 0},
#  {'index': 430,
#   'airline_id': '3L',
#   'dep_airport_id': 'FMM',
#   'des_airport_id': 'NAP',
#   'stops': 0},
#  {'index': 431,
#   'airline_id': '3L',
#   'dep_airport_id': 'GRZ',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 432,
#   'airline_id': '3L',
#   'dep_airport_id': 'HAM',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 433,
#   'airline_id': '3L',
#   'dep_airport_id': 'MUC',
#   'des_airport_id': 'EBA',
#   'stops': 0},
#  {'index': 434,
#   'airline_id': '3L',
#   'dep_airport_id': 'NAP',
#   'des_airport_id': 'FMM',
#   'stops': 0},
#  {'index': 435,
#   'airline_id': '3L',
#   'dep_airport_id': 'OLB',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 436,
#   'airline_id': '3L',
#   'dep_airport_id': 'SZG',
#   'des_airport_id': 'ZRH',
#   'stops': 0},
#  {'index': 437,
#   'airline_id': '3L',
#   'dep_airport_id': 'TXL',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 438,
#   'airline_id': '3L',
#   'dep_airport_id': 'ZAD',
#   'des_airport_id': 'FDH',
#   'stops': 0},
#  {'index': 439,
#   'airline_id': '3L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'DRS',
#   'stops': 0},
#  {'index': 440,
#   'airline_id': '3L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'EBA',
#   'stops': 0},
#  {'index': 441,
#   'airline_id': '3L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'GRZ',
#   'stops': 0},
#  {'index': 442,
#   'airline_id': '3L',
#   'dep_airport_id': 'ZRH',
#   'des_airport_id': 'SZG',
#   'stops': 0},
#  {'index': 443,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'LWB',
#   'stops': 0},
#  {'index': 444,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'MCN',
#   'stops': 0},
#  {'index': 445,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'MEI',
#   'stops': 0},
#  {'index': 446,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'MSL',
#   'stops': 0},
#  {'index': 447,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'PIB',
#   'stops': 0},
#  {'index': 448,
#   'airline_id': '3M',
#   'dep_airport_id': 'ATL',
#   'des_airport_id': 'TUP',
#   'stops': 0},
#  {'index': 449,
#   'airline_id': '3M',
#   'dep_airport_id': 'BIM',
# ...
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 851,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 852,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'DYG',
#   'stops': 0},
#  {'index': 853,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 854,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 855,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'MIG',
#   'stops': 0},
#  {'index': 856,
#   'airline_id': '3U',
#   'dep_airport_id': 'NKG',
#   'des_airport_id': 'SYX',
#   'stops': 0},
#  {'index': 857,
#   'airline_id': '3U',
#   'dep_airport_id': 'NNG',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 858,
#   'airline_id': '3U',
#   'dep_airport_id': 'NNG',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 859,
#   'airline_id': '3U',
#   'dep_airport_id': 'NNG',
#   'des_airport_id': 'SGN',
#   'stops': 0},
#  {'index': 860,
#   'airline_id': '3U',
#   'dep_airport_id': 'NNG',
#   'des_airport_id': 'WUH',
#   'stops': 0},
#  {'index': 861,
#   'airline_id': '3U',
#   'dep_airport_id': 'NTG',
#   'des_airport_id': 'WUH',
#   'stops': 0},
#  {'index': 862,
#   'airline_id': '3U',
#   'dep_airport_id': 'NZH',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 863,
#   'airline_id': '3U',
#   'dep_airport_id': 'PEK',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 864,
#   'airline_id': '3U',
#   'dep_airport_id': 'PEK',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 865,
#   'airline_id': '3U',
#   'dep_airport_id': 'PEK',
#   'des_airport_id': 'WXN',
#   'stops': 0},
#  {'index': 866,
#   'airline_id': '3U',
#   'dep_airport_id': 'PEK',
#   'des_airport_id': 'ZHY',
#   'stops': 0},
#  {'index': 867,
#   'airline_id': '3U',
#   'dep_airport_id': 'PVG',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 868,
#   'airline_id': '3U',
#   'dep_airport_id': 'PVG',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 869,
#   'airline_id': '3U',
#   'dep_airport_id': 'PVG',
#   'des_airport_id': 'SPN',
#   'stops': 0},
#  {'index': 870,
#   'airline_id': '3U',
#   'dep_airport_id': 'PZI',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 871,
#   'airline_id': '3U',
#   'dep_airport_id': 'PZI',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 872,
#   'airline_id': '3U',
#   'dep_airport_id': 'SGN',
#   'des_airport_id': 'NNG',
#   'stops': 0},
#  {'index': 873,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'CSX',
#   'stops': 0},
#  {'index': 874,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 875,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'DSN',
#   'stops': 0},
#  {'index': 876,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'NGB',
#   'stops': 0},
#  {'index': 877,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'TYN',
#   'stops': 0},
#  {'index': 878,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'XUZ',
#   'stops': 0},
#  {'index': 879,
#   'airline_id': '3U',
#   'dep_airport_id': 'SHE',
#   'des_airport_id': 'YVR',
#   'stops': 0},
#  {'index': 880,
#   'airline_id': '3U',
#   'dep_airport_id': 'SJW',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 881,
#   'airline_id': '3U',
#   'dep_airport_id': 'SJW',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 882,
#   'airline_id': '3U',
#   'dep_airport_id': 'SJW',
#   'des_airport_id': 'KWL',
#   'stops': 0},
#  {'index': 883,
#   'airline_id': '3U',
#   'dep_airport_id': 'SPN',
#   'des_airport_id': 'CAN',
#   'stops': 0},
#  {'index': 884,
#   'airline_id': '3U',
#   'dep_airport_id': 'SPN',
#   'des_airport_id': 'PVG',
#   'stops': 0},
#  {'index': 885,
#   'airline_id': '3U',
#   'dep_airport_id': 'SWA',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 886,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYD',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 887,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 888,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 889,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'KWE',
#   'stops': 0},
#  {'index': 890,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'KWL',
#   'stops': 0},
#  {'index': 891,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'MIG',
#   'stops': 0},
#  {'index': 892,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'NGB',
#   'stops': 0},
#  {'index': 893,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'NKG',
#   'stops': 0},
#  {'index': 894,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'TNA',
#   'stops': 0},
#  {'index': 895,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'WNZ',
#   'stops': 0},
#  {'index': 896,
#   'airline_id': '3U',
#   'dep_airport_id': 'SYX',
#   'des_airport_id': 'YBP',
#   'stops': 0},
#  {'index': 897,
#   'airline_id': '3U',
#   'dep_airport_id': 'SZX',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 898,
#   'airline_id': '3U',
#   'dep_airport_id': 'SZX',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 899,
#   'airline_id': '3U',
#   'dep_airport_id': 'SZX',
#   'des_airport_id': 'WXN',
#   'stops': 0},
#  {'index': 900,
#   'airline_id': '3U',
#   'dep_airport_id': 'TAO',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 901,
#   'airline_id': '3U',
#   'dep_airport_id': 'TAO',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 902,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'CGQ',
#   'stops': 0},
#  {'index': 903,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 904,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 905,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'DLC',
#   'stops': 0},
#  {'index': 906,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 907,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 908,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'SYX',
#   'stops': 0},
#  {'index': 909,
#   'airline_id': '3U',
#   'dep_airport_id': 'TNA',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 910,
#   'airline_id': '3U',
#   'dep_airport_id': 'TPE',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 911,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSA',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 912,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSA',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 913,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'CGQ',
#   'stops': 0},
#  {'index': 914,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 915,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 916,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'HGH',
#   'stops': 0},
#  {'index': 917,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 918,
#   'airline_id': '3U',
#   'dep_airport_id': 'TSN',
#   'des_airport_id': 'LHW',
#   'stops': 0},
#  {'index': 919,
#   'airline_id': '3U',
#   'dep_airport_id': 'TVS',
#   'des_airport_id': 'TYN',
#   'stops': 0},
#  {'index': 920,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 921,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 922,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'DAT',
#   'stops': 0},
#  {'index': 923,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'HGH',
#   'stops': 0},
#  {'index': 924,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'SHE',
#   'stops': 0},
#  {'index': 925,
#   'airline_id': '3U',
#   'dep_airport_id': 'TYN',
#   'des_airport_id': 'TVS',
#   'stops': 0},
#  {'index': 926,
#   'airline_id': '3U',
#   'dep_airport_id': 'URC',
#   'des_airport_id': 'CGO',
#   'stops': 0},
#  {'index': 927,
#   'airline_id': '3U',
#   'dep_airport_id': 'URC',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 928,
#   'airline_id': '3U',
#   'dep_airport_id': 'URC',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 929,
#   'airline_id': '3U',
#   'dep_airport_id': 'URC',
#   'des_airport_id': 'KHG',
#   'stops': 0},
#  {'index': 930,
#   'airline_id': '3U',
#   'dep_airport_id': 'URC',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 931,
#   'airline_id': '3U',
#   'dep_airport_id': 'UYN',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 932,
#   'airline_id': '3U',
#   'dep_airport_id': 'WNZ',
#   'des_airport_id': 'CSX',
#   'stops': 0},
#  {'index': 933,
#   'airline_id': '3U',
#   'dep_airport_id': 'WNZ',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 934,
#   'airline_id': '3U',
#   'dep_airport_id': 'WNZ',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 935,
#   'airline_id': '3U',
#   'dep_airport_id': 'WNZ',
#   'des_airport_id': 'KWE',
#   'stops': 0},
#  {'index': 936,
#   'airline_id': '3U',
#   'dep_airport_id': 'WNZ',
#   'des_airport_id': 'SYX',
#   'stops': 0},
#  {'index': 937,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 938,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 939,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 940,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'JJN',
#   'stops': 0},
#  {'index': 941,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'NNG',
#   'stops': 0},
#  {'index': 942,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUH',
#   'des_airport_id': 'NTG',
#   'stops': 0},
#  {'index': 943,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUX',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 944,
#   'airline_id': '3U',
#   'dep_airport_id': 'WUX',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 945,
#   'airline_id': '3U',
#   'dep_airport_id': 'WXN',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 946,
#   'airline_id': '3U',
#   'dep_airport_id': 'WXN',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 947,
#   'airline_id': '3U',
#   'dep_airport_id': 'WXN',
#   'des_airport_id': 'PEK',
#   'stops': 0},
#  {'index': 948,
#   'airline_id': '3U',
#   'dep_airport_id': 'WXN',
#   'des_airport_id': 'SZX',
#   'stops': 0},
#  {'index': 949,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIC',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 950,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'BHY',
#   'stops': 0},
#  {'index': 951,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 952,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 953,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'FOC',
#   'stops': 0},
#  {'index': 954,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'GXH',
#   'stops': 0},
#  {'index': 955,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 956,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 957,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'LXA',
#   'stops': 0},
#  {'index': 958,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'LYI',
#   'stops': 0},
#  {'index': 959,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'TNA',
#   'stops': 0},
#  {'index': 960,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'URC',
#   'stops': 0},
#  {'index': 961,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'UYN',
#   'stops': 0},
#  {'index': 962,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'XMN',
#   'stops': 0},
#  {'index': 963,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'XNN',
#   'stops': 0},
#  {'index': 964,
#   'airline_id': '3U',
#   'dep_airport_id': 'XIY',
#   'des_airport_id': 'YBP',
#   'stops': 0},
#  {'index': 965,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'CSX',
#   'stops': 0},
#  {'index': 966,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 967,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'CZX',
#   'stops': 0},
#  {'index': 968,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 969,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'KOW',
#   'stops': 0},
#  {'index': 970,
#   'airline_id': '3U',
#   'dep_airport_id': 'XMN',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 971,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 972,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 973,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'LXA',
#   'stops': 0},
#  {'index': 974,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'MIG',
#   'stops': 0},
#  {'index': 975,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 976,
#   'airline_id': '3U',
#   'dep_airport_id': 'XNN',
#   'des_airport_id': 'ZHY',
#   'stops': 0},
#  {'index': 977,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 978,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'DLC',
#   'stops': 0},
#  {'index': 979,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'HRB',
#   'stops': 0},
#  {'index': 980,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'KMG',
#   'stops': 0},
#  {'index': 981,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'KWE',
#   'stops': 0},
#  {'index': 982,
#   'airline_id': '3U',
#   'dep_airport_id': 'XUZ',
#   'des_airport_id': 'SHE',
#   'stops': 0},
#  {'index': 983,
#   'airline_id': '3U',
#   'dep_airport_id': 'YBP',
#   'des_airport_id': 'SYX',
#   'stops': 0},
#  {'index': 984,
#   'airline_id': '3U',
#   'dep_airport_id': 'YBP',
#   'des_airport_id': 'XIY',
#   'stops': 0},
#  {'index': 985,
#   'airline_id': '3U',
#   'dep_airport_id': 'YIH',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 986,
#   'airline_id': '3U',
#   'dep_airport_id': 'YIH',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 987,
#   'airline_id': '3U',
#   'dep_airport_id': 'YIH',
#   'des_airport_id': 'HKG',
#   'stops': 0},
#  {'index': 988,
#   'airline_id': '3U',
#   'dep_airport_id': 'YTY',
#   'des_airport_id': 'CTU',
#   'stops': 0},
#  {'index': 989,
#   'airline_id': '3U',
#   'dep_airport_id': 'YVR',
#   'des_airport_id': 'SHE',
#   'stops': 0},
#  {'index': 990,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZHA',
#   'des_airport_id': 'CKG',
#   'stops': 0},
#  {'index': 991,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZHA',
#   'des_airport_id': 'HKG',
#   'stops': 0},
#  {'index': 992,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZHY',
#   'des_airport_id': 'PEK',
#   'stops': 0},
#  {'index': 993,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZHY',
#   'des_airport_id': 'XNN',
#   'stops': 0},
#  {'index': 994,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZUH',
#   'des_airport_id': 'CZX',
#   'stops': 0},
#  {'index': 995,
#   'airline_id': '3U',
#   'dep_airport_id': 'ZUH',
#   'des_airport_id': 'HAK',
#   'stops': 0},
#  {'index': 996,
#   'airline_id': '4B',
#   'dep_airport_id': 'LAS',
#   'des_airport_id': 'LAX',
#   'stops': 0},
#  {'index': 997,
#   'airline_id': '4B',
#   'dep_airport_id': 'LAX',
#   'des_airport_id': 'LAS',
#   'stops': 0},
#  {'index': 998,
#   'airline_id': '4D',
#   'dep_airport_id': 'CAI',
#   'des_airport_id': 'TLV',
#   'stops': 0},
#  {'index': 999,
#   'airline_id': '4D',
#   'dep_airport_id': 'TLV',
#   'des_airport_id': 'CAI',
#   'stops': 0},
#  ...]

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
